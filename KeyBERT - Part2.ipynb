# %%
# !pip install -U deep-translator
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: deep-translator in /usr/local/lib/python3.9/dist-packages (1.10.1)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in /usr/local/lib/python3.9/dist-packages (from deep-translator) (4.11.2)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in /usr/local/lib/python3.9/dist-packages (from deep-translator) (2.25.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator) (2.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2022.12.7)

# %%
# !pip3 install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu116

# %%
# !pip3 install googletrans==4.0.0-rc1 --user
# Out:
# Requirement already satisfied: googletrans==4.0.0-rc1 in c:\programdata\anaconda3\lib\site-packages (4.0.0rc1)
# Requirement already satisfied: httpx==0.13.3 in c:\programdata\anaconda3\lib\site-packages (from googletrans==4.0.0-rc1) (0.13.3)
# Requirement already satisfied: sniffio in c:\programdata\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.3.0)
# Requirement already satisfied: idna==2.* in c:\programdata\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2.8)
# Requirement already satisfied: hstspreload in c:\programdata\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2023.1.1)
# Requirement already satisfied: rfc3986<2,>=1.3 in c:\programdata\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in c:\programdata\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.1)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2019.9.11)
# Requirement already satisfied: chardet==3.* in c:\programdata\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.4)
# Requirement already satisfied: h2==3.* in c:\programdata\anaconda3\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.2.0)
# Requirement already satisfied: h11<0.10,>=0.8 in c:\programdata\anaconda3\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in c:\programdata\anaconda3\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in c:\programdata\anaconda3\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.0)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (c:\programdata\anaconda3\lib\site-packages)

# %%
# !pip3 install git+https://github.com/huggingface/transformers --user
# Out:
# Collecting git+https://github.com/huggingface/transformers
#   Cloning https://github.com/huggingface/transformers to c:\users\xykong\appdata\local\temp\pip-req-build-wp6dlic9
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting huggingface-hub<1.0,>=0.11.0 (from transformers==4.27.0.dev0)
#   Using cached https://files.pythonhosted.org/packages/f8/54/2d9880819fb75ae169eb3f985af00e5c00657885554ef1f0cb0a9bcb9681/huggingface_hub-0.13.1-py3-none-any.whl
# Collecting filelock (from transformers==4.27.0.dev0)
#   Using cached https://files.pythonhosted.org/packages/14/4c/b201d0292ca4e0950f0741212935eac9996f69cd66b92a3587e594999163/filelock-3.9.0-py3-none-any.whl
# Collecting regex!=2019.12.17 (from transformers==4.27.0.dev0)
#   Using cached https://files.pythonhosted.org/packages/1f/f3/895ba11bc0243becd38f8b7560d2e329c465ead247cfb815611c347d7fc1/regex-2022.10.31-cp38-cp38-win_amd64.whl
# Collecting numpy>=1.17 (from transformers==4.27.0.dev0)
#   Using cached https://files.pythonhosted.org/packages/bf/8c/3d36cef521739bd481e9a5b30e5c0f9faf8b7fe7b904238368908a9d149d/numpy-1.24.2-cp38-cp38-win_amd64.whl
# Collecting requests (from transformers==4.27.0.dev0)
#   Using cached https://files.pythonhosted.org/packages/d2/f4/274d1dbe96b41cf4e0efb70cbced278ffd61b5c7bb70338b62af94ccb25b/requests-2.28.2-py3-none-any.whl
# Collecting packaging>=20.0 (from transformers==4.27.0.dev0)
#   Using cached https://files.pythonhosted.org/packages/ed/35/a31aed2993e398f6b09a790a181a7927eb14610ee8bbf02dc14d31677f1c/packaging-23.0-py3-none-any.whl
# Collecting tqdm>=4.27 (from transformers==4.27.0.dev0)
#   Using cached https://files.pythonhosted.org/packages/e6/02/a2cff6306177ae6bc73bc0665065de51dfb3b9db7373e122e2735faf0d97/tqdm-4.65.0-py3-none-any.whl
# Collecting pyyaml>=5.1 (from transformers==4.27.0.dev0)
#   Using cached https://files.pythonhosted.org/packages/a8/5b/c4d674846ea4b07ee239fbf6010bcc427c4e4552ba5655b446e36b9a40a7/PyYAML-6.0-cp38-cp38-win_amd64.whl
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers==4.27.0.dev0)
#   Using cached https://files.pythonhosted.org/packages/94/93/e459652043471e51337fb4837a973386ccd1ee6fc9104679ec4e5f8de11a/tokenizers-0.13.2-cp38-cp38-win_amd64.whl
# Collecting typing-extensions>=3.7.4.3 (from huggingface-hub<1.0,>=0.11.0->transformers==4.27.0.dev0)
#   Using cached https://files.pythonhosted.org/packages/31/25/5abcd82372d3d4a3932e1fa8c3dbf9efac10cc7c0d16e78467460571b404/typing_extensions-4.5.0-py3-none-any.whl
# Collecting urllib3<1.27,>=1.21.1 (from requests->transformers==4.27.0.dev0)
#   Using cached https://files.pythonhosted.org/packages/fe/ca/466766e20b767ddb9b951202542310cba37ea5f2d792dae7589f1741af58/urllib3-1.26.14-py2.py3-none-any.whl
# Collecting idna<4,>=2.5 (from requests->transformers==4.27.0.dev0)
#   Using cached https://files.pythonhosted.org/packages/fc/34/3030de6f1370931b9dbb4dad48f6ab1015ab1d32447850b9fc94e60097be/idna-3.4-py3-none-any.whl
# Collecting certifi>=2017.4.17 (from requests->transformers==4.27.0.dev0)
#   Using cached https://files.pythonhosted.org/packages/71/4c/3db2b8021bd6f2f0ceb0e088d6b2d49147671f25832fb17970e9b583d742/certifi-2022.12.7-py3-none-any.whl
# Collecting charset-normalizer<4,>=2 (from requests->transformers==4.27.0.dev0)
#   Using cached https://files.pythonhosted.org/packages/26/20/83e1804a62b25891c4e770c94d9fd80233bbb3f2a51c4fadee7a196e5a5b/charset_normalizer-3.1.0-cp38-cp38-win_amd64.whl
# Collecting colorama; platform_system == "Windows" (from tqdm>=4.27->transformers==4.27.0.dev0)
#   Using cached https://files.pythonhosted.org/packages/d1/d6/3965ed04c63042e047cb6a3e6ed1a63a35087b6a609aa3a15ed8ac56c221/colorama-0.4.6-py2.py3-none-any.whl
# Building wheels for collected packages: transformers
#   Building wheel for transformers (PEP 517): started
#   Building wheel for transformers (PEP 517): finished with status 'done'
#   Created wheel for transformers: filename=transformers-4.27.0.dev0-cp38-none-any.whl size=6708159 sha256=2526378a4ca54014c0694b2454ff7420142e80fd588b7f56e4d4c282fe3fc095
#   Stored in directory: C:\Users\xykong\AppData\Local\Temp\pip-ephem-wheel-cache-wfshx8zf\wheels\70\d3\52\b3fa4f8b8ef04167ac62e5bb2accb62ae764db2a378247490e
# Successfully built transformers
# Installing collected packages: colorama, tqdm, filelock, packaging, urllib3, idna, certifi, charset-normalizer, requests, typing-extensions, pyyaml, huggingface-hub, regex, numpy, tokenizers, transformers
# Successfully installed certifi-2022.12.7 charset-normalizer-3.1.0 colorama-0.4.6 filelock-3.9.0 huggingface-hub-0.13.1 idna-3.4 numpy-1.24.2 packaging-23.0 pyyaml-6.0 regex-2022.10.31 requests-2.28.2 tokenizers-0.13.2 tqdm-4.65.0 transformers-4.27.0.dev0 typing-extensions-4.5.0 urllib3-1.26.14
#   Running command git clone -q https://github.com/huggingface/transformers 'C:\Users\xykong\AppData\Local\Temp\pip-req-build-wp6dlic9'
#   WARNING: The script tqdm.exe is installed in 'C:\Users\xykong\AppData\Roaming\Python\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script normalizer.exe is installed in 'C:\Users\xykong\AppData\Roaming\Python\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script huggingface-cli.exe is installed in 'C:\Users\xykong\AppData\Roaming\Python\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script f2py.exe is installed in 'C:\Users\xykong\AppData\Roaming\Python\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script transformers-cli.exe is installed in 'C:\Users\xykong\AppData\Roaming\Python\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: You are using pip version 19.2.3, however version 23.0.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import pandas as pd
from googletrans import Translator
import time

# %%
import spacy

# %%
from deep_translator import GoogleTranslator

# %%
data = pd.read_csv("https://github.com/winfreykong/BERT-Poem/blob/main/Data/With%20GPU/keyword_poems.csv?raw=true").drop(columns=['Unnamed: 0'])
data.head()
# Out:
#    ID         poem_author   language  \
# 0   1         Halyna Kruk  Ukrainian
# 1   2     Ostap Slyvynsky  Ukrainian
# 2   3     Osip Mandelstam    Russian
# 3   4    Boris Khersonsky    Russian
# 4   5  Oleksandr Irvanets  Ukrainian
#
#                                        original_poem  \
# 0  ***\ncказати собі чесно, якомога чесніше,\nтак...
# 1  ХАЙКУ З МАЙДАНУ\nДим у рукавах.\nНіби йдеш з ц...
# 2  (О.М.)\nНе мучнистой бабочкою белой\nВ землю я...
# 3  ***\n"Союз нерушимый" сыграют и хором споют.\n...
# 4  ***\nЦей рік, який почався з середи - \nКуди в...
#
#                                     light_clean_poem  \
# 0  *** cказати собі чесно, якомога чесніше, так н...
# 1  ХАЙКУ З МАЙДАНУ Дим у рукавах. Ніби йдеш з цим...
# 2   Не мучнистой бабочкою белой В землю я заемный...
# 3  *** "Союз нерушимый" сыграют и хором споют. В ...
# 4  *** Цей рік, який почався з середи -  Куди він...
#
#                                                theme  \
# 0     {'ukraine', 'maidan', 'revolution', 'protest'}
# 1  {'revolution', 'poetic form', 'maidan', 'haiku...
# 2               {'time', 'twentieth century', 'war'}
# 3     {'food', 'soviet union', 'morphine', 'anthem'}
# 4                    {'time', 'new year', 'seasons'}
#
#                                             keywords
# 0  [('покладаючись', 0.3382), ('патріотичних', 0....
# 1  [('пообіцяти', 0.4741), ('пустимо', 0.3054), (...
# 2  [('восклицанья', 0.3814), ('мыслящее', 0.2992)...
# 3  [('проснусь', 0.3366), ('нерушимый', 0.331), (...
# 4  [('наступний', 0.4395), ('четверга', 0.2653), ...

# %%
data.shape
# Out:
# (1010, 7)

# %%
data = data.assign(keywords_ori = data['keywords'].apply(lambda x: [i[0] if (isinstance(i[0], str) and not i[0].isdigit()) else '' for i in eval(x)]))
data.head()
# Out:
#    ID         poem_author   language  \
# 0   1         Halyna Kruk  Ukrainian
# 1   2     Ostap Slyvynsky  Ukrainian
# 2   3     Osip Mandelstam    Russian
# 3   4    Boris Khersonsky    Russian
# 4   5  Oleksandr Irvanets  Ukrainian
#
#                                        original_poem  \
# 0  ***\ncказати собі чесно, якомога чесніше,\nтак...
# 1  ХАЙКУ З МАЙДАНУ\nДим у рукавах.\nНіби йдеш з ц...
# 2  (О.М.)\nНе мучнистой бабочкою белой\nВ землю я...
# 3  ***\n"Союз нерушимый" сыграют и хором споют.\n...
# 4  ***\nЦей рік, який почався з середи - \nКуди в...
#
#                                     light_clean_poem  \
# 0  *** cказати собі чесно, якомога чесніше, так н...
# 1  ХАЙКУ З МАЙДАНУ Дим у рукавах. Ніби йдеш з цим...
# 2   Не мучнистой бабочкою белой В землю я заемный...
# 3  *** "Союз нерушимый" сыграют и хором споют. В ...
# 4  *** Цей рік, який почався з середи -  Куди він...
#
#                                                theme  \
# 0     {'ukraine', 'maidan', 'revolution', 'protest'}
# 1  {'revolution', 'poetic form', 'maidan', 'haiku...
# 2               {'time', 'twentieth century', 'war'}
# 3     {'food', 'soviet union', 'morphine', 'anthem'}
# 4                    {'time', 'new year', 'seasons'}
#
#                                             keywords  \
# 0  [('покладаючись', 0.3382), ('патріотичних', 0....
# 1  [('пообіцяти', 0.4741), ('пустимо', 0.3054), (...
# 2  [('восклицанья', 0.3814), ('мыслящее', 0.2992)...
# 3  [('проснусь', 0.3366), ('нерушимый', 0.331), (...
# 4  [('наступний', 0.4395), ('четверга', 0.2653), ...
#
#                                         keywords_ori
# 0  [покладаючись, патріотичних, втікаючи, хочу, м...
# 1  [пообіцяти, пустимо, вистоїмо, лісистим, хребтом]
# 2  [восклицанья, мыслящее, молчаливо, позвоночное...
# 3  [проснусь, нерушимый, скрывать, подсыхает, кус...
# 4  [наступний, четверга, кочерга, почнеться, прямим]

# %%
def translate(text):
    translator = Translator()
    return translator.translate(text, dest='en').text

# %%
def translate_v2(text):
    translator = GoogleTranslator(source='auto', target='en')
    return translator.translate_batch(text)

# %%
data[:5]['keywords_ori']
# Out:
# 0    [покладаючись, патріотичних, втікаючи, хочу, м...
# 1    [пообіцяти, пустимо, вистоїмо, лісистим, хребтом]
# 2    [восклицанья, мыслящее, молчаливо, позвоночное...
# 3    [проснусь, нерушимый, скрывать, подсыхает, кус...
# 4    [наступний, четверга, кочерга, почнеться, прямим]
# Name: keywords_ori, dtype: object

# %%
translate('покладаючись')
# Out:
# 'relying'

# %%
# %%timeit
data[:10]['keywords_ori'].apply(lambda x: [translate(i) for i in x])
# Out:
# The slowest run took 6.35 times longer than the fastest. This could mean that an intermediate result is being cached.
# 11.5 s ± 8.57 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
data[:10]['keywords_ori'].apply(translate_v2)
# Out:
# 6.07 s ± 1.12 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
keywords_eng = data['keywords_ori'].apply(translate_v2)

# %%
data = data.assign(keywords_eng=keywords_eng)
data.to_csv('keyword_eng_poems.csv')

# %%
data.head()
# Out:
#    ID         poem_author   language  \
# 0   1         Halyna Kruk  Ukrainian
# 1   2     Ostap Slyvynsky  Ukrainian
# 2   3     Osip Mandelstam    Russian
# 3   4    Boris Khersonsky    Russian
# 4   5  Oleksandr Irvanets  Ukrainian
#
#                                        original_poem  \
# 0  ***\ncказати собі чесно, якомога чесніше,\nтак...
# 1  ХАЙКУ З МАЙДАНУ\nДим у рукавах.\nНіби йдеш з ц...
# 2  (О.М.)\nНе мучнистой бабочкою белой\nВ землю я...
# 3  ***\n"Союз нерушимый" сыграют и хором споют.\n...
# 4  ***\nЦей рік, який почався з середи - \nКуди в...
#
#                                     light_clean_poem  \
# 0  *** cказати собі чесно, якомога чесніше, так н...
# 1  ХАЙКУ З МАЙДАНУ Дим у рукавах. Ніби йдеш з цим...
# 2   Не мучнистой бабочкою белой В землю я заемный...
# 3  *** "Союз нерушимый" сыграют и хором споют. В ...
# 4  *** Цей рік, який почався з середи -  Куди він...
#
#                                                theme  \
# 0     {'ukraine', 'maidan', 'revolution', 'protest'}
# 1  {'revolution', 'poetic form', 'maidan', 'haiku...
# 2               {'time', 'twentieth century', 'war'}
# 3     {'food', 'soviet union', 'morphine', 'anthem'}
# 4                    {'time', 'new year', 'seasons'}
#
#                                             keywords  \
# 0  [('покладаючись', 0.3382), ('патріотичних', 0....
# 1  [('пообіцяти', 0.4741), ('пустимо', 0.3054), (...
# 2  [('восклицанья', 0.3814), ('мыслящее', 0.2992)...
# 3  [('проснусь', 0.3366), ('нерушимый', 0.331), (...
# 4  [('наступний', 0.4395), ('четверга', 0.2653), ...
#
#                                         keywords_ori  \
# 0  [покладаючись, патріотичних, втікаючи, хочу, м...
# 1  [пообіцяти, пустимо, вистоїмо, лісистим, хребтом]
# 2  [восклицанья, мыслящее, молчаливо, позвоночное...
# 3  [проснусь, нерушимый, скрывать, подсыхает, кус...
# 4  [наступний, четверга, кочерга, почнеться, прямим]
#
#                                         keywords_eng
# 0  [relying on, patriotic, running away, Want, sm...
# 1  [to promise, let's go, let's stand, wooded, sp...
# 2  [exclamations, thinking, silently, vertebrate,...
# 3  [wake up, indestructible, hide, dries up, a pi...
# 4   [following, Thursday, poker, will begin, direct]

# %% [markdown]
# ## Generating theme (topic modelling) based on english keywords

# %%
import pandas as pd
import re
import numpy as np
import time

# %%
data = pd.read_csv("keyword_eng_poems.csv").drop(columns=['Unnamed: 0'])

# %%
data.shape
# Out:
# (1010, 9)

# %%
data
# Out:
#         ID         poem_author   language  \
# 0        1         Halyna Kruk  Ukrainian
# 1        2     Ostap Slyvynsky  Ukrainian
# 2        3     Osip Mandelstam    Russian
# 3        4    Boris Khersonsky    Russian
# 4        5  Oleksandr Irvanets  Ukrainian
# ...    ...                 ...        ...
# 1005  1201       Oleh Kotsarev  Ukrainian
# 1006  1202     Olena Huseinova  Ukrainian
# 1007  1203     Pavlo Korobchuk  Ukrainian
# 1008  1204    Victoria Amelina  Ukrainian
# 1009  1205            Iya Kiva  Ukrainian
#
#                                           original_poem  \
# 0     ***\ncказати собі чесно, якомога чесніше,\nтак...
# 1     ХАЙКУ З МАЙДАНУ\nДим у рукавах.\nНіби йдеш з ц...
# 2     (О.М.)\nНе мучнистой бабочкою белой\nВ землю я...
# 3     ***\n"Союз нерушимый" сыграют и хором споют.\n...
# 4     ***\nЦей рік, який почався з середи - \nКуди в...
# ...                                                 ...
# 1005  СВІТ САМШИТ\n\nСвіте!\nХиткий самшите!\nГладжу...
# 1006  Дорога Halyna Kruk :\nале з кожною розповіддю ...
# 1007  - у мене закінчуються сили, я не в ресурсі\n- ...
# 1008  *\nдивне пекуче літо\nповне людей із моря\nїхн...
# 1009  тримати у роті голку мовчання\nзшивати слова б...
#
#                                        light_clean_poem  \
# 0     *** cказати собі чесно, якомога чесніше, так н...
# 1     ХАЙКУ З МАЙДАНУ Дим у рукавах. Ніби йдеш з цим...
# 2      Не мучнистой бабочкою белой В землю я заемный...
# 3     *** "Союз нерушимый" сыграют и хором споют. В ...
# 4     *** Цей рік, який почався з середи -  Куди він...
# ...                                                 ...
# 1005  СВІТ САМШИТ  Світе! Хиткий самшите! Гладжу теб...
# 1006  Дорога Halyna Kruk : але з кожною розповіддю м...
# 1007  - у мене закінчуються сили, я не в ресурсі - а...
# 1008  * дивне пекуче літо повне людей із моря їхні с...
# 1009  тримати у роті голку мовчання зшивати слова бі...
#
#                                                   theme  \
# 0        {'ukraine', 'maidan', 'revolution', 'protest'}
# 1     {'revolution', 'poetic form', 'maidan', 'haiku...
# 2                  {'time', 'twentieth century', 'war'}
# 3        {'food', 'soviet union', 'morphine', 'anthem'}
# 4                       {'time', 'new year', 'seasons'}
# ...                                                 ...
# 1005                                  {'nature', 'art'}
# 1006  {'poetry', 'lazarus', 'religion', 'ukraine', '...
# 1007  {'ukraine', 'reportage', 'war', 'ammunition', ...
# 1008  {'mariupol', 'souvenirs', 'archive', 'summer',...
# 1009            {'needle', 'speech', 'silence', 'pain'}
#
#                                                keywords  \
# 0     [('покладаючись', 0.3382), ('патріотичних', 0....
# 1     [('пообіцяти', 0.4741), ('пустимо', 0.3054), (...
# 2     [('восклицанья', 0.3814), ('мыслящее', 0.2992)...
# 3     [('проснусь', 0.3366), ('нерушимый', 0.331), (...
# 4     [('наступний', 0.4395), ('четверга', 0.2653), ...
# ...                                                 ...
# 1005  [('обганяємо', 0.4533), ('порозкуйовдити', 0.4...
# 1006  [('літературу', 0.3972), ('розповіддю', 0.3832...
# 1007  [('багатомільйонного', 0.4426), ('настільки', ...
# 1008  [('маріуполя', 0.2747), ('прокурори', 0.2465),...
# 1009  [('дірявому', 0.2262), ('білими', 0.2193), ('ц...
#
#                                            keywords_ori  \
# 0     ['покладаючись', 'патріотичних', 'втікаючи', '...
# 1     ['пообіцяти', 'пустимо', 'вистоїмо', 'лісистим...
# 2     ['восклицанья', 'мыслящее', 'молчаливо', 'позв...
# 3     ['проснусь', 'нерушимый', 'скрывать', 'подсыха...
# 4     ['наступний', 'четверга', 'кочерга', 'почнетьс...
# ...                                                 ...
# 1005  ['обганяємо', 'порозкуйовдити', 'невпіймані', ...
# 1006  ['літературу', 'розповіддю', 'проповідуючи', '...
# 1007  ['багатомільйонного', 'настільки', 'щовечора',...
# 1008  ['маріуполя', 'прокурори', 'майбутніх', 'журна...
# 1009  ['дірявому', 'білими', 'церувати', 'називатись...
#
#                                            keywords_eng
# 0     ['relying on', 'patriotic', 'running away', 'W...
# 1     ['to promise', "let's go", "let's stand", 'woo...
# 2     ['exclamations', 'thinking', 'silently', 'vert...
# 3     ['wake up', 'indestructible', 'hide', 'dries u...
# 4     ['following', 'Thursday', 'poker', 'will begin...
# ...                                                 ...
# 1005  ['overtaking', 'untangle', 'uncaught', 'want t...
# 1006  ['literature', 'a story', 'preaching', 'the go...
# 1007  ['multi-million', 'so', 'every evening', 'Kher...
# 1008  ['Mariupol', 'prosecutors', 'future', 'journal...
# 1009  ['leaky', 'white', 'to caress', 'be called', '...
#
# [1010 rows x 9 columns]

# %% [markdown]
# ### Let's start with performing a quick test

# %%
from transformers import pipeline
classifier = pipeline("zero-shot-classification",
                      model="facebook/bart-large-mnli")

# %%
sequence_to_classify = "patriotic" 
candidate_labels = ['nation', 'time', 'revolution']
classifier(sequence_to_classify, candidate_labels) #expect "nation"
# Out:
# {'sequence': 'patriotic',
#  'labels': ['nation', 'time', 'revolution'],
#  'scores': [0.9161605834960938, 0.0708652064204216, 0.012974199838936329]}

# %%
sequence_to_classify = "will begin" 
candidate_labels = ['nation', 'time', 'revolution']
classifier(sequence_to_classify, candidate_labels) #expect "time"
# Out:
# {'sequence': 'will begin',
#  'labels': ['time', 'nation', 'revolution'],
#  'scores': [0.7398016452789307, 0.15727007389068604, 0.1029282808303833]}

# %%
sequence_to_classify = "mental health" 
candidate_labels = ['nation', 'time', 'revolution', 'psychology']
classifier(sequence_to_classify, candidate_labels) #expect "psychology"
# Out:
# {'sequence': 'mental health',
#  'labels': ['psychology', 'time', 'nation', 'revolution'],
#  'scores': [0.8121060132980347,
#   0.08897802233695984,
#   0.0651412159204483,
#   0.0337747260928154]}

# %%
sequence_to_classify = "aging" 
candidate_labels = ['nation', 'time', 'revolution', 'psychology']
classifier(sequence_to_classify, candidate_labels) #expect "time"
# Out:
# {'sequence': 'aging',
#  'labels': ['time', 'nation', 'psychology', 'revolution'],
#  'scores': [0.8773593306541443,
#   0.08302872627973557,
#   0.024532590061426163,
#   0.015079350210726261]}

# %% [markdown]
# #### Seems to be working pretty well!

# %% [markdown]
# ### Task breakdown:
#
# Run zero-shot-classification on the "keywords_eng" column (a list of english-translated keywords) with labels being the big themes defined in "Cleaning & KeyBERT Part1"!
# - Set score threshold, say 0.70

# %%
# Big theme list from "Cleaning & KeyBERT Part1"
big_theme = ['war', 'religion', 'nation', 'death', 'time',
             'protest', 'geography', 'season', 'family', 'language',
             'maidan','memory', 'animal', 'nature', 'love', 'poetry',   
             'psychology', 'politics', 'life', 'fruit', 'gender', 'mythology']

# %%
def get_big_theme(keywords_list, big_theme_list, classifier):
    results = []
    for i in keywords_list:
      # if keyword is not None and keyword not ""
        if i and len(i) != 0:
            out = classifier(i, big_theme_list)
            out['scores'] = out['scores'][:3] #getting only the top3
            out['labels'] = out['labels'][:3] #getting only the top3
            results.append(out)
    return results

# %%
eval(data.iloc[3].keywords_eng)
# Out:
# ['wake up', 'indestructible', 'hide', 'dries up', 'a piece']

# %%
t1 = get_big_theme(eval(data.iloc[3].keywords_eng), big_theme, classifier)

# %%
t1
# Out:
# [{'sequence': 'wake up',
#   'labels': ['time', 'protest', 'life'],
#   'scores': [0.37131044268608093, 0.13614800572395325, 0.09478017687797546]},
#  {'sequence': 'indestructible',
#   'labels': ['maidan', 'nature', 'life'],
#   'scores': [0.13711203634738922, 0.13091972470283508, 0.11104417592287064]},
#  {'sequence': 'hide',
#   'labels': ['time', 'maidan', 'family'],
#   'scores': [0.11117197573184967, 0.10484229028224945, 0.09301237761974335]},
#  {'sequence': 'dries up',
#   'labels': ['time', 'maidan', 'season'],
#   'scores': [0.24253885447978973, 0.09031683951616287, 0.08095249533653259]},
#  {'sequence': 'a piece',
#   'labels': ['maidan', 'time', 'language'],
#   'scores': [0.13270139694213867, 0.10248517245054245, 0.07310601323843002]}]

# %%
# Edge case 1: row that contains None entry in list of keywords (probably due to failure to translate)
# We want to make sure that our function is able to skip those "None" entries and run properly
data[data['ID']==776]['keywords_eng'].apply(lambda x: get_big_theme(eval(x), big_theme, classifier))
# Out:
# 689    [{'sequence': 'eighteen years old', 'labels': ...
# Name: keywords_eng, dtype: object

# %%
# Edge case 2: row that contains empty string, i.e. "" in the list of keywords
eg2 = data[data['ID']==270]['keywords_eng'].apply(lambda x: get_big_theme(eval(x), big_theme, classifier))
eg2
# Out:
# 250    [{'sequence': 'April Fool's Day', 'labels': ['...
# Name: keywords_eng, dtype: object

# %%
eg2.values
# Out:
# array([list([{'sequence': "April Fool's Day", 'labels': ['time', 'language', 'protest'], 'scores': [0.26816195249557495, 0.10589686781167984, 0.08920233696699142]}, {'sequence': 'guard', 'labels': ['maidan', 'protest', 'time'], 'scores': [0.11082840710878372, 0.10774733871221542, 0.08480575680732727]}, {'sequence': 'a joke', 'labels': ['language', 'maidan', 'gender'], 'scores': [0.2668316066265106, 0.15200957655906677, 0.08019862323999405]}, {'sequence': 'a joke', 'labels': ['language', 'maidan', 'gender'], 'scores': [0.2668316066265106, 0.15200957655906677, 0.08019862323999405]}, {'sequence': 'a joke', 'labels': ['language', 'maidan', 'gender'], 'scores': [0.2668316066265106, 0.15200957655906677, 0.08019862323999405]}])],
#       dtype=object)

# %%
# Test on a sample of 10 (top 10 rows) and get the run time
start = time.time()
data['keywords_eng'][:10].apply(lambda x: get_big_theme(eval(x), big_theme, classifier))
end = time.time()
end-start
# Out:
# 507.5755834579468

# %% [markdown]
# #### Around 270 seconds (4.5 minutes) to process 10 rows

# %%
# On average, we have 5 keywords for each poem
np.mean(data['keywords_eng'].apply(lambda x: len(eval(x))))
# Out:
# 4.9970297029702975

# %%
start = time.time()

keyword_eng_theme = []
for i in data['keywords_eng']:
    try:
        keyword_eng_theme.append(get_big_theme(eval(i), big_theme, classifier))
    except Exception:
        keyword_eng_theme.append([])
        print(i)
        
end = time.time()
end-start

# %%
start = time.time()
keyword_eng_theme = data['keywords_eng'].apply(lambda x: get_big_theme(eval(x), big_theme, classifier))
end = time.time()
end-start

# %%
keyword_eng_theme
# Out:
# [[{'sequence': 'relying on',
#    'labels': ['maidan', 'family', 'nation'],
#    'scores': [0.12305205315351486, 0.10531776398420334, 0.0666816458106041]},
#   {'sequence': 'patriotic',
#    'labels': ['nation', 'maidan', 'language'],
#    'scores': [0.4591561555862427, 0.1214393675327301, 0.08682616800069809]},
#   {'sequence': 'running away',
#    'labels': ['protest', 'time', 'animal'],
#    'scores': [0.1631479114294052, 0.15938355028629303, 0.12018370628356934]},
#   {'sequence': 'Want',
#    'labels': ['protest', 'maidan', 'language'],
#    'scores': [0.1297539621591568, 0.11201462894678116, 0.08314479887485504]},
#   {'sequence': 'small town',
#    'labels': ['maidan', 'life', 'geography'],
#    'scores': [0.2456987351179123, 0.15827718377113342, 0.15817879140377045]}],
#  [{'sequence': 'to promise',
#    'labels': ['language', 'maidan', 'time'],
#    'scores': [0.2872653603553772, 0.10143814235925674, 0.06584929674863815]},
#   {'sequence': "let's go",
#    'labels': ['time', 'life', 'language'],
#    'scores': [0.21661138534545898, 0.1257409006357193, 0.08529472351074219]},
#   {'sequence': "let's stand",
#    'labels': ['protest', 'time', 'nation'],
#    'scores': [0.3522397577762604, 0.11887581646442413, 0.08053457736968994]},
#   {'sequence': 'wooded',
#    'labels': ['nature', 'language', 'maidan'],
#    'scores': [0.5490893721580505, 0.06557222455739975, 0.04317203164100647]},
#   {'sequence': 'spine',
#    'labels': ['animal', 'nature', 'maidan'],
#    'scores': [0.4310818314552307, 0.14208805561065674, 0.05569325014948845]}],
#  [{'sequence': 'exclamations',
#    'labels': ['language', 'protest', 'time'],
#    'scores': [0.38348162174224854, 0.1578855663537979, 0.05406763032078743]},
#   {'sequence': 'thinking',
#    'labels': ['time', 'maidan', 'family'],
#    'scores': [0.13226047158241272, 0.12042302638292313, 0.10343992710113525]},
#   {'sequence': 'silently',
#    'labels': ['time', 'maidan', 'family'],
#    'scores': [0.16071048378944397, 0.10812174528837204, 0.08939341455698013]},
#   {'sequence': 'vertebrate',
#    'labels': ['animal', 'nature', 'life'],
#    'scores': [0.475246399641037, 0.23216025531291962, 0.07402254641056061]},
#   {'sequence': 'continue',
#    'labels': ['family', 'time', 'life'],
#    'scores': [0.11006183922290802, 0.10680105537176132, 0.10387644916772842]}],
#  [{'sequence': 'wake up',
#    'labels': ['time', 'protest', 'life'],
#    'scores': [0.37131068110466003, 0.13614755868911743, 0.09478013217449188]},
#   {'sequence': 'indestructible',
#    'labels': ['maidan', 'nature', 'life'],
#    'scores': [0.1371118575334549, 0.13091962039470673, 0.11104416102170944]},
#   {'sequence': 'hide',
#    'labels': ['time', 'maidan', 'family'],
#    'scores': [0.11117211729288101, 0.10484220087528229, 0.09301242977380753]},
#   {'sequence': 'dries up',
#    'labels': ['time', 'maidan', 'season'],
#    'scores': [0.24253877997398376, 0.09031697362661362, 0.0809524729847908]},
#   {'sequence': 'a piece',
#    'labels': ['maidan', 'time', 'language'],
#    'scores': [0.13270114362239838, 0.10248550772666931, 0.07310590147972107]}],
#  [{'sequence': 'following',
#    'labels': ['family', 'time', 'language'],
#    'scores': [0.12112607806921005, 0.11603859812021255, 0.09735027700662613]},
#   {'sequence': 'Thursday',
#    'labels': ['time', 'season', 'life'],
#    'scores': [0.344619482755661, 0.11825773119926453, 0.07664293795824051]},
#   {'sequence': 'poker',
#    'labels': ['gender', 'maidan', 'time'],
#    'scores': [0.18222513794898987, 0.08973335474729538, 0.0825454518198967]},
#   {'sequence': 'will begin',
#    'labels': ['time', 'life', 'language'],
#    'scores': [0.21587787568569183, 0.14104656875133514, 0.07019010931253433]},
#   {'sequence': 'direct',
#    'labels': ['maidan', 'family', 'language'],
#    'scores': [0.10579157620668411, 0.10252086818218231, 0.08518341183662415]}],
#  [{'sequence': 'breakfast',
#    'labels': ['maidan', 'family', 'time'],
#    'scores': [0.2532058656215668, 0.12396979331970215, 0.09448268264532089]},
#   {'sequence': 'poem',
#    'labels': ['poetry', 'language', 'maidan'],
#    'scores': [0.5128980875015259, 0.28219684958457947, 0.02858973853290081]},
#   {'sequence': 'Dedushka',
#    'labels': ['gender', 'animal', 'language'],
#    'scores': [0.19345100224018097, 0.1523815393447876, 0.12944352626800537]},
#   {'sequence': 'hello',
#    'labels': ['language', 'family', 'maidan'],
#    'scores': [0.37265416979789734, 0.08800989389419556, 0.08750000596046448]},
#   {'sequence': 'vocabulary',
#    'labels': ['language', 'geography', 'maidan'],
#    'scores': [0.6827423572540283, 0.05286013334989548, 0.023858046159148216]}],
#  [{'sequence': 'you inhale',
#    'labels': ['life', 'time', 'maidan'],
#    'scores': [0.136193186044693, 0.1251991242170334, 0.10714958608150482]},
#   {'sequence': 'the deafest',
#    'labels': ['maidan', 'animal', 'protest'],
#    'scores': [0.18361496925354004, 0.14437052607536316, 0.10118328779935837]},
#   {'sequence': 'half lowered',
#    'labels': ['time', 'maidan', 'family'],
#    'scores': [0.17455431818962097, 0.12869103252887726, 0.07742428034543991]},
#   {'sequence': 'actually',
#    'labels': ['family', 'maidan', 'nature'],
#    'scores': [0.11062140762805939, 0.0969562903046608, 0.08123138546943665]},
#   {'sequence': 'ice shelf',
#    'labels': ['nature', 'time', 'season'],
#    'scores': [0.1829470992088318, 0.12004808336496353, 0.08607003092765808]}],
#  [{'sequence': 'actually',
#    'labels': ['family', 'maidan', 'nature'],
#    'scores': [0.11062140762805939, 0.0969562903046608, 0.08123138546943665]},
#   {'sequence': 'renaissance',
#    'labels': ['season', 'life', 'nation'],
#    'scores': [0.18720592558383942, 0.13923195004463196, 0.12685036659240723]},
#   {'sequence': 'disassemble',
#    'labels': ['protest', 'language', 'maidan'],
#    'scores': [0.23256048560142517, 0.09996873885393143, 0.0957677811384201]},
#   {'sequence': 'call',
#    'labels': ['language', 'family', 'protest'],
#    'scores': [0.29155728220939636, 0.08809400349855423, 0.07231095433235168]},
#   {'sequence': 'wants',
#    'labels': ['language', 'protest', 'gender'],
#    'scores': [0.16667339205741882, 0.1652522087097168, 0.10147564113140106]}],
#  [{'sequence': 'Europeans',
#    'labels': ['nation', 'family', 'geography'],
#    'scores': [0.7070019841194153, 0.047716397792100906, 0.028483962640166283]},
#   {'sequence': 'better',
#    'labels': ['maidan', 'family', 'time'],
#    'scores': [0.1300741732120514, 0.11884818971157074, 0.07317052036523819]},
#   {'sequence': 'sit',
#    'labels': ['time', 'family', 'language'],
#    'scores': [0.1842717081308365, 0.09606470912694931, 0.0860121101140976]},
#   {'sequence': 'diggers',
#    'labels': ['gender', 'maidan', 'animal'],
#    'scores': [0.17452946305274963, 0.13412101566791534, 0.13043199479579926]},
#   {'sequence': 'slightly',
#    'labels': ['maidan', 'time', 'family'],
#    'scores': [0.11799196898937225, 0.1148514598608017, 0.08080146461725235]}],
#  [{'sequence': "we'll make it",
#    'labels': ['life', 'time', 'family'],
#    'scores': [0.19158466160297394, 0.17608503997325897, 0.11999577283859253]},
#   {'sequence': 'week',
#    'labels': ['time', 'season', 'life'],
#    'scores': [0.4754425883293152, 0.12557972967624664, 0.05437059700489044]},
#   {'sequence': 'get tired',
#    'labels': ['time', 'maidan', 'life'],
#    'scores': [0.2760874032974243, 0.08885156363248825, 0.08366721868515015]},
#   {'sequence': 'maybe',
#    'labels': ['maidan', 'family', 'time'],
#    'scores': [0.11853589862585068, 0.10289011150598526, 0.07937285304069519]},
#   {'sequence': 'weekends',
#    'labels': ['time', 'season', 'life'],
#    'scores': [0.2318512201309204, 0.16752134263515472, 0.0870266780257225]}],
#  [{'sequence': 'happier',
#    'labels': ['family', 'maidan', 'time'],
#    'scores': [0.11489153653383255, 0.10811620205640793, 0.0877603143453598]},
#   {'sequence': 'collar',
#    'labels': ['family', 'gender', 'maidan'],
#    'scores': [0.11674433201551437, 0.10721861571073532, 0.09078547358512878]},
#   {'sequence': 'All',
#    'labels': ['life', 'family', 'maidan'],
#    'scores': [0.15295244753360748, 0.13342101871967316, 0.0939776822924614]},
#   {'sequence': 'look around',
#    'labels': ['maidan', 'time', 'nature'],
#    'scores': [0.11629334092140198, 0.11184428632259369, 0.09534713625907898]},
#   {'sequence': 'omnipotent',
#    'labels': ['nation', 'maidan', 'gender'],
#    'scores': [0.1398821324110031, 0.1319897174835205, 0.08026596158742905]}],
#  [{'sequence': 'you will find',
#    'labels': ['life', 'maidan', 'family'],
#    'scores': [0.11426755040884018, 0.09925015270709991, 0.09245394170284271]},
#   {'sequence': 'kostrubata',
#    'labels': ['animal', 'language', 'nature'],
#    'scores': [0.2853010892868042, 0.1498597115278244, 0.12715503573417664]},
#   {'sequence': 'construction workers',
#    'labels': ['maidan', 'gender', 'time'],
#    'scores': [0.2739129066467285, 0.14765851199626923, 0.1328485757112503]},
#   {'sequence': 'decadent',
#    'labels': ['maidan', 'language', 'time'],
#    'scores': [0.15949270129203796, 0.10885602980852127, 0.09664959460496902]},
#   {'sequence': 'hell',
#    'labels': ['death', 'language', 'protest'],
#    'scores': [0.545376718044281, 0.06940396875143051, 0.05738076567649841]}],
#  [{'sequence': 'dying',
#    'labels': ['death', 'time', 'maidan'],
#    'scores': [0.8218708038330078, 0.042125970125198364, 0.0168321393430233]},
#   {'sequence': 'conversations',
#    'labels': ['language', 'maidan', 'time'],
#    'scores': [0.20919108390808105, 0.12784890830516815, 0.08289625495672226]},
#   {'sequence': 'non-existence',
#    'labels': ['protest', 'death', 'maidan'],
#    'scores': [0.2578105926513672, 0.20090343058109283, 0.07790986448526382]},
#   {'sequence': 'squinting',
#    'labels': ['time', 'maidan', 'family'],
#    'scores': [0.10692790895700455, 0.1039394661784172, 0.09277999401092529]},
#   {'sequence': 'looking',
#    'labels': ['maidan', 'time', 'family'],
#    'scores': [0.11383286863565445, 0.10498687624931335, 0.10045485943555832]}],
#  [{'sequence': 'adultery',
#    'labels': ['maidan', 'gender', 'death'],
#    'scores': [0.18613293766975403, 0.16586585342884064, 0.10203239321708679]},
#   {'sequence': 'is revealed',
#    'labels': ['maidan', 'family', 'time'],
#    'scores': [0.10640495270490646, 0.08164415508508682, 0.07846466451883316]},
#   {'sequence': 'psychiatrists',
#    'labels': ['psychology', 'time', 'maidan'],
#    'scores': [0.8596020936965942, 0.021857254207134247, 0.015299932099878788]},
#   {'sequence': 'cleaner',
#    'labels': ['maidan', 'time', 'family'],
#    'scores': [0.18181346356868744, 0.10998248308897018, 0.10043837875127792]},
#   {'sequence': 'psychiatrists',
#    'labels': ['psychology', 'time', 'maidan'],
#    'scores': [0.8596020936965942,
#     0.021857254207134247,
#     0.015299932099878788]}],
#  [{'sequence': 'I saw',
#    'labels': ['time', 'maidan', 'nature'],
#    'scores': [0.17858397960662842, 0.11465202271938324, 0.09006989002227783]},
#   {'sequence': 'the border',
#    'labels': ['geography', 'maidan', 'protest'],
#    'scores': [0.655805766582489, 0.05008292198181152, 0.03477879986166954]},
#   {'sequence': 'swallows',
#    'labels': ['animal', 'nature', 'gender'],
#    'scores': [0.6376767158508301, 0.1672581136226654, 0.048845984041690826]},
#   {'sequence': 'twelve',
#    'labels': ['time', 'gender', 'family'],
#    'scores': [0.2988120913505554, 0.08466242253780365, 0.08430416882038116]},
#   {'sequence': 'convalescent',
#    'labels': ['time', 'season', 'life'],
#    'scores': [0.13924840092658997, 0.11146502941846848, 0.11043675243854523]}],
#  [{'sequence': "New Year's",
#    'labels': ['time', 'season', 'nation'],
#    'scores': [0.33623215556144714, 0.19945697486400604, 0.0692969337105751]},
#   {'sequence': 'gets up',
#    'labels': ['time', 'life', 'protest'],
#    'scores': [0.18505270779132843, 0.1115705668926239, 0.09208612143993378]},
#   {'sequence': 'continues',
#    'labels': ['family', 'life', 'time'],
#    'scores': [0.11398127675056458, 0.10094624757766724, 0.09912542998790741]},
#   {'sequence': 'country',
#    'labels': ['nation', 'geography', 'nature'],
#    'scores': [0.5358908176422119, 0.22249989211559296, 0.03201356530189514]},
#   {'sequence': 'song',
#    'labels': ['language', 'maidan', 'poetry'],
#    'scores': [0.3518376052379608, 0.09652543067932129, 0.08369512856006622]}],
#  [{'sequence': 'sturdy',
#    'labels': ['maidan', 'time', 'nation'],
#    'scores': [0.1715087592601776, 0.11285947263240814, 0.0890885591506958]},
#   {'sequence': 'Christmas',
#    'labels': ['season', 'family', 'nation'],
#    'scores': [0.843000590801239, 0.06481526046991348, 0.017769530415534973]},
#   {'sequence': 'are going',
#    'labels': ['time', 'life', 'maidan'],
#    'scores': [0.13442116975784302, 0.11737831681966782, 0.0865357294678688]},
#   {'sequence': 'will bear',
#    'labels': ['animal', 'fruit', 'life'],
#    'scores': [0.7941433191299438, 0.039075419306755066, 0.0353831984102726]},
#   {'sequence': 'haiku',
#    'labels': ['language', 'poetry', 'gender'],
#    'scores': [0.36675190925598145, 0.23052501678466797, 0.06043657287955284]}],
#  [{'sequence': 'proclaim',
#    'labels': ['protest', 'language', 'poetry'],
#    'scores': [0.32673805952072144, 0.2521013021469116, 0.05600520595908165]},
#   {'sequence': 'grace',
#    'labels': ['family', 'life', 'love'],
#    'scores': [0.16859214007854462, 0.11877407878637314, 0.09616576880216599]},
#   {'sequence': 'look',
#    'labels': ['maidan', 'time', 'family'],
#    'scores': [0.1044454276561737, 0.09723807871341705, 0.09467566758394241]},
#   {'sequence': 'hang up',
#    'labels': ['time', 'maidan', 'protest'],
#    'scores': [0.25168874859809875, 0.09938263893127441, 0.09201951324939728]},
#   {'sequence': 'salvation',
#    'labels': ['life', 'maidan', 'language'],
#    'scores': [0.27537214756011963, 0.10516569763422012, 0.07721774280071259]}],
#  [{'sequence': 'wake up',
#    'labels': ['time', 'protest', 'life'],
#    'scores': [0.37131068110466003, 0.13614755868911743, 0.09478013217449188]},
#   {'sequence': 'getting prettier',
#    'labels': ['time', 'maidan', 'season'],
#    'scores': [0.13986091315746307, 0.12526090443134308, 0.08518563210964203]},
#   {'sequence': 'rise up',
#    'labels': ['protest', 'life', 'time'],
#    'scores': [0.2783675789833069, 0.11480751633644104, 0.10299157351255417]},
#   {'sequence': 'think',
#    'labels': ['family', 'maidan', 'time'],
#    'scores': [0.1117548942565918, 0.103605255484581, 0.10029155761003494]},
#   {'sequence': 'unprecedented',
#    'labels': ['nation', 'protest', 'maidan'],
#    'scores': [0.1877141296863556, 0.10744154453277588, 0.10461970418691635]}],
#  [{'sequence': 'sculptures',
#    'labels': ['maidan', 'gender', 'season'],
#    'scores': [0.18629367649555206, 0.12293168157339096, 0.06697876751422882]},
#   {'sequence': 'straight ahead',
#    'labels': ['time', 'life', 'maidan'],
#    'scores': [0.11949706077575684, 0.11476035416126251, 0.09296459704637527]},
#   {'sequence': 'triune',
#    'labels': ['language', 'time', 'nature'],
#    'scores': [0.23643335700035095, 0.1063268706202507, 0.06157844513654709]},
#   {'sequence': 'flawless',
#    'labels': ['maidan', 'life', 'family'],
#    'scores': [0.1405152827501297, 0.10644450038671494, 0.09473837167024612]},
#   {'sequence': 'girls',
#    'labels': ['gender', 'maidan', 'family'],
#    'scores': [0.8410283327102661, 0.04387185350060463, 0.043330442160367966]}],
#  [{'sequence': 'meets',
#    'labels': ['maidan', 'time', 'family'],
#    'scores': [0.1443348526954651, 0.11674853414297104, 0.09938892722129822]},
#   {'sequence': 'bears',
#    'labels': ['animal', 'gender', 'family'],
#    'scores': [0.8494221568107605, 0.05905796214938164, 0.026721343398094177]},
#   {'sequence': 'christmas eve',
#    'labels': ['season', 'family', 'time'],
#    'scores': [0.7054977416992188, 0.06371458619832993, 0.043358057737350464]},
#   {'sequence': 'age-old',
#    'labels': ['time', 'gender', 'death'],
#    'scores': [0.4410302937030792, 0.14596110582351685, 0.08295048028230667]},
#   {'sequence': 'extinguish',
#    'labels': ['death', 'protest', 'language'],
#    'scores': [0.3852015435695648, 0.09487452358007431, 0.08416891098022461]}],
#  [{'sequence': 'everyday',
#    'labels': ['life', 'time', 'maidan'],
#    'scores': [0.416288822889328, 0.21262076497077942, 0.06733044981956482]},
#   {'sequence': 'fragrance',
#    'labels': ['language', 'protest', 'maidan'],
#    'scores': [0.23861417174339294, 0.11268028616905212, 0.07446189969778061]},
#   {'sequence': 'will return',
#    'labels': ['time', 'life', 'family'],
#    'scores': [0.1686721295118332, 0.16370120644569397, 0.08154822885990143]},
#   {'sequence': 'will return',
#    'labels': ['time', 'life', 'family'],
#    'scores': [0.1686721295118332, 0.16370120644569397, 0.08154822885990143]},
#   {'sequence': 'will open',
#    'labels': ['time', 'maidan', 'life'],
#    'scores': [0.12152217328548431, 0.10767824947834015, 0.082169309258461]}],
#  [{'sequence': 'we will overcome',
#    'labels': ['life', 'nation', 'time'],
#    'scores': [0.27068766951560974, 0.1385694444179535, 0.0823967233300209]},
#   {'sequence': 'will deceive',
#    'labels': ['maidan', 'language', 'time'],
#    'scores': [0.11561388522386551, 0.0943790152668953, 0.07083393633365631]},
#   {'sequence': 'slag',
#    'labels': ['maidan', 'language', 'time'],
#    'scores': [0.2528485655784607, 0.14339995384216309, 0.08556289970874786]},
#   {'sequence': 'to smuggle',
#    'labels': ['maidan', 'language', 'nation'],
#    'scores': [0.18648721277713776, 0.1102367639541626, 0.10831359028816223]},
#   {'sequence': 'mood',
#    'labels': ['psychology', 'maidan', 'language'],
#    'scores': [0.4000140428543091, 0.12832079827785492, 0.04870975390076637]}],
#  [{'sequence': 'you wake up',
#    'labels': ['time', 'life', 'maidan'],
#    'scores': [0.3068546652793884, 0.20202653110027313, 0.06573347002267838]},
#   {'sequence': 'coast',
#    'labels': ['geography', 'time', 'nature'],
#    'scores': [0.32579004764556885, 0.07669287919998169, 0.06056572496891022]},
#   {'sequence': 'from inside',
#    'labels': ['family', 'maidan', 'time'],
#    'scores': [0.14749988913536072, 0.11768127977848053, 0.07867433875799179]},
#   {'sequence': 'danger',
#    'labels': ['maidan', 'nation', 'death'],
#    'scores': [0.1597154289484024, 0.08761335909366608, 0.07641777396202087]},
#   {'sequence': 'I weigh',
#    'labels': ['gender', 'time', 'maidan'],
#    'scores': [0.14796225726604462, 0.13964839279651642, 0.08616356551647186]}],
#  [{'sequence': 'Christmas',
#    'labels': ['season', 'family', 'nation'],
#    'scores': [0.843000590801239, 0.06481526046991348, 0.017769530415534973]},
#   {'sequence': 'camels',
#    'labels': ['animal', 'nature', 'gender'],
#    'scores': [0.916431725025177, 0.0381290577352047, 0.007693846710026264]},
#   {'sequence': 'camel',
#    'labels': ['animal', 'nature', 'gender'],
#    'scores': [0.9331141710281372, 0.018830610439181328, 0.008213984780013561]},
#   {'sequence': 'pushed apart',
#    'labels': ['protest', 'maidan', 'time'],
#    'scores': [0.17479684948921204, 0.10289608687162399, 0.08263184130191803]},
#   {'sequence': 'camel',
#    'labels': ['animal', 'nature', 'gender'],
#    'scores': [0.9331141710281372,
#     0.018830610439181328,
#     0.008213984780013561]}],
#  [{'sequence': 'actually',
#    'labels': ['family', 'maidan', 'nature'],
#    'scores': [0.11062140762805939, 0.0969562903046608, 0.08123138546943665]},
#   {'sequence': 'christmas eve',
#    'labels': ['season', 'family', 'time'],
#    'scores': [0.7054977416992188, 0.06371458619832993, 0.043358057737350464]},
#   {'sequence': 'shepherds',
#    'labels': ['religion', 'gender', 'animal'],
#    'scores': [0.35082313418388367, 0.19132043421268463, 0.06784520298242569]},
#   {'sequence': 'shop windows',
#    'labels': ['maidan', 'season', 'time'],
#    'scores': [0.24820281565189362, 0.11779643595218658, 0.10284194350242615]},
#   {'sequence': 'Christmas',
#    'labels': ['season', 'family', 'nation'],
#    'scores': [0.843000590801239, 0.06481526046991348, 0.017769530415534973]}],
#  [{'sequence': 'deity',
#    'labels': ['religion', 'gender', 'family'],
#    'scores': [0.3712380528450012, 0.35431110858917236, 0.05880672112107277]},
#   {'sequence': 'glorifies',
#    'labels': ['language', 'maidan', 'gender'],
#    'scores': [0.16130967438220978, 0.12948478758335114, 0.09471569955348969]},
#   {'sequence': 'something',
#    'labels': ['family', 'maidan', 'time'],
#    'scores': [0.09090808779001236, 0.08183640986680984, 0.08038108795881271]},
#   {'sequence': 'yataka',
#    'labels': ['gender', 'language', 'mythology'],
#    'scores': [0.2150498926639557, 0.20417658984661102, 0.19300809502601624]},
#   {'sequence': 'river',
#    'labels': ['nature', 'maidan', 'family'],
#    'scores': [0.22309161722660065, 0.09243427962064743, 0.076084665954113]}],
#  [{'sequence': 'fades',
#    'labels': ['time', 'death', 'maidan'],
#    'scores': [0.23945209383964539, 0.08264598250389099, 0.08250391483306885]},
#   {'sequence': 'stick',
#    'labels': ['maidan', 'protest', 'family'],
#    'scores': [0.12303897738456726, 0.1065831184387207, 0.09192530065774918]},
#   {'sequence': 'ornaments',
#    'labels': ['nature', 'language', 'animal'],
#    'scores': [0.6448447108268738, 0.060153860598802567, 0.05495617911219597]},
#   {'sequence': 'Christmas',
#    'labels': ['season', 'family', 'nation'],
#    'scores': [0.843000590801239, 0.06481526046991348, 0.017769530415534973]},
#   {'sequence': 'wet',
#    'labels': ['maidan', 'time', 'gender'],
#    'scores': [0.12971699237823486, 0.11592769622802734, 0.10173904150724411]}],
#  [{'sequence': 'enabled',
#    'labels': ['family', 'maidan', 'time'],
#    'scores': [0.14672714471817017, 0.11255057901144028, 0.0752122700214386]},
#   {'sequence': 'are checking',
#    'labels': ['time', 'maidan', 'family'],
#    'scores': [0.15181179344654083, 0.11027690023183823, 0.09200833737850189]},
#   {'sequence': 'purgatory',
#    'labels': ['protest', 'death', 'gender'],
#    'scores': [0.4746463894844055, 0.14419648051261902, 0.0520273894071579]},
#   {'sequence': 'looking around',
#    'labels': ['time', 'maidan', 'nature'],
#    'scores': [0.13971644639968872, 0.13330627977848053, 0.08499525487422943]},
#   {'sequence': 'amber',
#    'labels': ['gender', 'maidan', 'family'],
#    'scores': [0.20160065591335297, 0.20136970281600952, 0.1145036369562149]}],
#  [{'sequence': 'trust',
#    'labels': ['maidan', 'family', 'time'],
#    'scores': [0.1541501134634018, 0.12796835601329803, 0.09482340514659882]},
#   {'sequence': 'genitalia',
#    'labels': ['gender', 'nature', 'family'],
#    'scores': [0.5031560063362122, 0.3486979603767395, 0.02002163603901863]},
#   {'sequence': 'embroidery',
#    'labels': ['gender', 'maidan', 'family'],
#    'scores': [0.15496784448623657, 0.11763110756874084, 0.09482531994581223]},
#   {'sequence': 'kisses',
#    'labels': ['family', 'love', 'maidan'],
#    'scores': [0.21279391646385193, 0.20354360342025757, 0.11659448593854904]},
#   {'sequence': 'trust',
#    'labels': ['maidan', 'family', 'time'],
#    'scores': [0.1541501134634018, 0.12796835601329803, 0.09482340514659882]}],
#  [{'sequence': 'domestic',
#    'labels': ['gender', 'family', 'language'],
#    'scores': [0.4070879817008972, 0.3246014714241028, 0.06577548384666443]},
#   {'sequence': 'hangover',
#    'labels': ['time', 'maidan', 'life'],
#    'scores': [0.2866963744163513, 0.12090686708688736, 0.11581306904554367]},
#   {'sequence': 'future',
#    'labels': ['maidan', 'family', 'time'],
#    'scores': [0.11157085001468658, 0.10567982494831085, 0.08545757830142975]},
#   {'sequence': 'you say',
#    'labels': ['language', 'maidan', 'family'],
#    'scores': [0.5384773015975952, 0.062356431037187576, 0.051157139241695404]},
#   {'sequence': "let's get together",
#    'labels': ['time', 'family', 'maidan'],
#    'scores': [0.3614688217639923, 0.13813351094722748, 0.06202292442321777]}],
#  [{'sequence': 'happy',
#    'labels': ['family', 'maidan', 'nation'],
#    'scores': [0.1419079303741455, 0.1321963518857956, 0.09510079026222229]},
#   {'sequence': 'dopey',
#    'labels': ['maidan', 'language', 'gender'],
#    'scores': [0.18086449801921844, 0.1473744958639145, 0.12142457813024521]},
#   {'sequence': 'scratch',
#    'labels': ['animal', 'protest', 'maidan'],
#    'scores': [0.20743952691555023, 0.1256897747516632, 0.10855025053024292]},
#   {'sequence': 'stutter',
#    'labels': ['time', 'protest', 'language'],
#    'scores': [0.20105445384979248, 0.1565794199705124, 0.14204290509223938]},
#   {'sequence': 'gape',
#    'labels': ['geography', 'gender', 'protest'],
#    'scores': [0.476985365152359, 0.14535601437091827, 0.07874750345945358]}],
#  [{'sequence': 'from time immemorial',
#    'labels': ['time', 'memory', 'family'],
#    'scores': [0.6454444527626038, 0.09432736784219742, 0.0453273206949234]},
#   {'sequence': 'infinity',
#    'labels': ['nature', 'family', 'nation'],
#    'scores': [0.12855230271816254, 0.10776771605014801, 0.08231324702501297]},
#   {'sequence': 'lulls',
#    'labels': ['time', 'language', 'nature'],
#    'scores': [0.21711792051792145, 0.1652299016714096, 0.08209066838026047]},
#   {'sequence': "let's grow",
#    'labels': ['life', 'time', 'maidan'],
#    'scores': [0.19196918606758118, 0.1268230825662613, 0.07607866078615189]},
#   {'sequence': 'hateful',
#    'labels': ['language', 'maidan', 'nation'],
#    'scores': [0.3873218297958374, 0.12072163820266724, 0.06749433279037476]}],
#  [{'sequence': 'did not look back',
#    'labels': ['time', 'life', 'memory'],
#    'scores': [0.2426901012659073, 0.10281915962696075, 0.09567941725254059]},
#   {'sequence': 'call back',
#    'labels': ['time', 'language', 'memory'],
#    'scores': [0.2138703465461731, 0.1757490634918213, 0.10935444384813309]},
#   {'sequence': 'poems',
#    'labels': ['poetry', 'language', 'maidan'],
#    'scores': [0.6763935685157776, 0.09012549370527267, 0.03973894938826561]},
#   {'sequence': 'courtesans',
#    'labels': ['gender', 'language', 'protest'],
#    'scores': [0.26379308104515076, 0.14941567182540894, 0.12546730041503906]},
#   {'sequence': 'stretch',
#    'labels': ['language', 'maidan', 'time'],
#    'scores': [0.12371353805065155, 0.10642238706350327, 0.1049959734082222]}],
#  [{'sequence': 'seventies',
#    'labels': ['season', 'time', 'memory'],
#    'scores': [0.3897436261177063, 0.3447490930557251, 0.03222370892763138]},
#   {'sequence': 'will return',
#    'labels': ['time', 'life', 'family'],
#    'scores': [0.1686721295118332, 0.16370120644569397, 0.08154822885990143]},
#   {'sequence': 'an immigrant',
#    'labels': ['maidan', 'nation', 'life'],
#    'scores': [0.3408467769622803, 0.12419836968183517, 0.104129858314991]},
#   {'sequence': 'post-war',
#    'labels': ['time', 'war', 'nation'],
#    'scores': [0.39311712980270386, 0.1565263271331787, 0.07183486223220825]},
#   {'sequence': 'you exhale',
#    'labels': ['time', 'maidan', 'language'],
#    'scores': [0.21042729914188385, 0.09643319249153137, 0.08342587947845459]}],
#  [{'sequence': 'whatever',
#    'labels': ['language', 'family', 'time'],
#    'scores': [0.09250234067440033, 0.08205872774124146, 0.08074094355106354]},
#   {'sequence': 'What',
#    'labels': ['language', 'maidan', 'family'],
#    'scores': [0.17555606365203857, 0.08133639395236969, 0.07037228345870972]},
#   {'sequence': 'be',
#    'labels': ['maidan', 'language', 'family'],
#    'scores': [0.09885483235120773, 0.09235622733831406, 0.0822337418794632]},
#   {'sequence': 'All',
#    'labels': ['life', 'family', 'maidan'],
#    'scores': [0.15295244753360748, 0.13342101871967316, 0.0939776822924614]},
#   {'sequence': 'batey',
#    'labels': ['gender', 'language', 'protest'],
#    'scores': [0.3036491274833679, 0.17397476732730865, 0.11713661253452301]}],
#  [{'sequence': 'Monday',
#    'labels': ['time', 'season', 'life'],
#    'scores': [0.3033740520477295, 0.1590326875448227, 0.0972333550453186]},
#   {'sequence': 'snow',
#    'labels': ['season', 'nature', 'maidan'],
#    'scores': [0.49485233426094055, 0.21931740641593933, 0.03761898726224899]},
#   {'sequence': 'ahead',
#    'labels': ['time', 'maidan', 'family'],
#    'scores': [0.15758252143859863, 0.10765471309423447, 0.09550508111715317]},
#   {'sequence': 'tired',
#    'labels': ['time', 'maidan', 'nation'],
#    'scores': [0.49005696177482605, 0.0669708177447319, 0.053040266036987305]},
#   {'sequence': 'could',
#    'labels': ['language', 'family', 'maidan'],
#    'scores': [0.11418183147907257, 0.09436585009098053, 0.08455420285463333]}],
#  [{'sequence': 'identification',
#    'labels': ['gender', 'maidan', 'family'],
#    'scores': [0.13809117674827576, 0.10756156593561172, 0.08876176178455353]},
#   {'sequence': 'are returning',
#    'labels': ['time', 'family', 'season'],
#    'scores': [0.15848632156848907, 0.1361430585384369, 0.10015665739774704]},
#   {'sequence': 'half life',
#    'labels': ['time', 'life', 'death'],
#    'scores': [0.34962865710258484, 0.18596050143241882, 0.06968177855014801]},
#   {'sequence': 'nested',
#    'labels': ['family', 'nation', 'maidan'],
#    'scores': [0.7489833235740662, 0.04421008378267288, 0.03082283027470112]},
#   {'sequence': 'twitch',
#    'labels': ['time', 'maidan', 'protest'],
#    'scores': [0.15843598544597626, 0.11121496558189392, 0.08403558284044266]}],
#  [{'sequence': 'Far Eastern',
#    'labels': ['geography', 'nation', 'nature'],
#    'scores': [0.3708277940750122, 0.1521698385477066, 0.07090325653553009]},
#   {'sequence': 'Armenian',
#    'labels': ['nation', 'language', 'family'],
#    'scores': [0.5341680645942688, 0.21450573205947876, 0.08833612501621246]},
#   {'sequence': 'unrestrained',
#    'labels': ['protest', 'life', 'maidan'],
#    'scores': [0.19626690447330475, 0.1006728932261467, 0.09303952008485794]},
#   {'sequence': 'each',
#    'labels': ['family', 'time', 'nation'],
#    'scores': [0.12384284287691116, 0.10182613879442215, 0.0930631160736084]},
#   {'sequence': 'font',
#    'labels': ['family', 'maidan', 'nation'],
#    'scores': [0.1251813918352127, 0.10737103968858719, 0.07830149680376053]}],
#  [{'sequence': 'specimens',
#    'labels': ['animal', 'nature', 'gender'],
#    'scores': [0.22045408189296722, 0.17671246826648712, 0.07573583722114563]},
#   {'sequence': 'natives',
#    'labels': ['nature', 'nation', 'family'],
#    'scores': [0.3953101634979248, 0.3270425498485565, 0.07401171326637268]},
#   {'sequence': 'recognize',
#    'labels': ['family', 'maidan', 'memory'],
#    'scores': [0.11673200130462646, 0.10451216250658035, 0.08282525837421417]},
#   {'sequence': 'territory',
#    'labels': ['geography', 'time', 'season'],
#    'scores': [0.5189669728279114, 0.057939205318689346, 0.057401400059461594]},
#   {'sequence': 'page by page',
#    'labels': ['time', 'maidan', 'family'],
#    'scores': [0.12889429926872253, 0.11968065053224564, 0.0965781882405281]}],
#  [{'sequence': 'marriage',
#    'labels': ['love', 'maidan', 'family'],
#    'scores': [0.3315499424934387, 0.16724729537963867, 0.08057106286287308]},
#   {'sequence': 'hurry up',
#    'labels': ['time', 'maidan', 'language'],
#    'scores': [0.4465908706188202, 0.08084920793771744, 0.0669838935136795]},
#   {'sequence': 'lonely',
#    'labels': ['time', 'language', 'gender'],
#    'scores': [0.12279606610536575, 0.11118150502443314, 0.10812908411026001]},
#   {'sequence': 'makes it difficult',
#    'labels': ['maidan', 'time', 'protest'],
#    'scores': [0.1138615682721138, 0.11182713508605957, 0.08514240384101868]},
#   {'sequence': 'myself',
#    'labels': ['gender', 'maidan', 'life'],
#    'scores': [0.24403828382492065, 0.12117759883403778, 0.10146764665842056]}],
#  [{'sequence': 'towards',
#    'labels': ['time', 'protest', 'maidan'],
#    'scores': [0.1339893788099289, 0.11444728821516037, 0.08943280577659607]},
#   {'sequence': 'will meet',
#    'labels': ['life', 'family', 'maidan'],
#    'scores': [0.16725850105285645, 0.10251832753419876, 0.08621875196695328]},
#   {'sequence': 'pristine',
#    'labels': ['nature', 'maidan', 'nation'],
#    'scores': [0.45322564244270325, 0.05670008435845375, 0.05241386592388153]},
#   {'sequence': 'tailored',
#    'labels': ['maidan', 'language', 'time'],
#    'scores': [0.17517979443073273, 0.10735727101564407, 0.10504669696092606]},
#   {'sequence': 'ice hole',
#    'labels': ['nature', 'protest', 'time'],
#    'scores': [0.12814581394195557, 0.09850894659757614, 0.09496767073869705]}],
#  [{'sequence': 'fighters',
#    'labels': ['war', 'animal', 'gender'],
#    'scores': [0.31260234117507935, 0.20778048038482666, 0.0933246836066246]},
#   {'sequence': 'tricolor',
#    'labels': ['language', 'gender', 'time'],
#    'scores': [0.1853574514389038, 0.1705205738544464, 0.07816465198993683]},
#   {'sequence': 'grace',
#    'labels': ['family', 'life', 'love'],
#    'scores': [0.16859214007854462, 0.11877407878637314, 0.09616576880216599]},
#   {'sequence': 'cruciform',
#    'labels': ['animal', 'nature', 'death'],
#    'scores': [0.7553761601448059, 0.08822327107191086, 0.027700109407305717]},
#   {'sequence': 'nostril',
#    'labels': ['nature', 'nation', 'animal'],
#    'scores': [0.2632584869861603, 0.14024733006954193, 0.11271064728498459]}],
#  [{'sequence': 'fighters',
#    'labels': ['war', 'animal', 'gender'],
#    'scores': [0.31260234117507935, 0.20778048038482666, 0.0933246836066246]},
#   {'sequence': 'tricolor',
#    'labels': ['language', 'gender', 'time'],
#    'scores': [0.1853574514389038, 0.1705205738544464, 0.07816465198993683]},
#   {'sequence': 'grace',
#    'labels': ['family', 'life', 'love'],
#    'scores': [0.16859214007854462, 0.11877407878637314, 0.09616576880216599]},
#   {'sequence': 'cruciform',
#    'labels': ['animal', 'nature', 'death'],
#    'scores': [0.7553761601448059, 0.08822327107191086, 0.027700109407305717]},
#   {'sequence': 'nostril',
#    'labels': ['nature', 'nation', 'animal'],
#    'scores': [0.2632584869861603, 0.14024733006954193, 0.11271064728498459]}],
#  [{'sequence': 'infinity',
#    'labels': ['nature', 'family', 'nation'],
#    'scores': [0.12855230271816254, 0.10776771605014801, 0.08231324702501297]},
#   {'sequence': 'observatories',
#    'labels': ['time', 'maidan', 'nature'],
#    'scores': [0.175089493393898, 0.14840225875377655, 0.11759591102600098]},
#   {'sequence': 'burning',
#    'labels': ['death', 'protest', 'maidan'],
#    'scores': [0.2316424548625946, 0.10282077640295029, 0.09586028754711151]},
#   {'sequence': 'magical',
#    'labels': ['maidan', 'family', 'mythology'],
#    'scores': [0.18949361145496368, 0.10181913524866104, 0.09301222115755081]},
#   {'sequence': 'galaxies',
#    'labels': ['geography', 'gender', 'maidan'],
#    'scores': [0.6086574196815491, 0.2524760961532593, 0.02709098532795906]}],
#  [{'sequence': 'art',
#    'labels': ['maidan', 'time', 'gender'],
#    'scores': [0.15507304668426514, 0.09563678503036499, 0.07401465624570847]},
#   {'sequence': 'cold',
#    'labels': ['time', 'maidan', 'family'],
#    'scores': [0.13333134353160858, 0.11359891295433044, 0.08498616516590118]},
#   {'sequence': 'strengthens',
#    'labels': ['maidan', 'family', 'nation'],
#    'scores': [0.11277300864458084, 0.09219232201576233, 0.0748683288693428]},
#   {'sequence': 'zhadan',
#    'labels': ['language', 'gender', 'maidan'],
#    'scores': [0.18539780378341675, 0.16307596862316132, 0.10109732300043106]},
#   {'sequence': 'hryvnias',
#    'labels': ['nation', 'language', 'gender'],
#    'scores': [0.17570728063583374, 0.14655303955078125, 0.14040830731391907]}],
#  [{'sequence': 'scraps',
#    'labels': ['maidan', 'protest', 'time'],
#    'scores': [0.13391105830669403, 0.1084916815161705, 0.09229539334774017]},
#   {'sequence': 'dense earth',
#    'labels': ['nature', 'geography', 'maidan'],
#    'scores': [0.702802836894989, 0.05118972063064575, 0.04587753489613533]},
#   {'sequence': 'we dare',
#    'labels': ['protest', 'language', 'nation'],
#    'scores': [0.3860289752483368, 0.08351796120405197, 0.08236689865589142]},
#   {'sequence': 'I love',
#    'labels': ['love', 'family', 'maidan'],
#    'scores': [0.7248654961585999, 0.05453718826174736, 0.031042801216244698]},
#   {'sequence': 'alphabet',
#    'labels': ['language', 'maidan', 'animal'],
#    'scores': [0.21106314659118652, 0.09235869348049164, 0.06443805992603302]}],
#  [{'sequence': 'Monday',
#    'labels': ['time', 'season', 'life'],
#    'scores': [0.3033740520477295, 0.1590326875448227, 0.0972333550453186]},
#   {'sequence': 'eurocatsaps',
#    'labels': ['animal', 'language', 'protest'],
#    'scores': [0.5180113315582275, 0.09450950473546982, 0.07559170573949814]},
#   {'sequence': 'Europeans',
#    'labels': ['nation', 'family', 'geography'],
#    'scores': [0.7070019841194153, 0.047716397792100906, 0.028483962640166283]},
#   {'sequence': 'heard',
#    'labels': ['family', 'time', 'maidan'],
#    'scores': [0.12212231755256653, 0.1032620444893837, 0.09304413944482803]},
#   {'sequence': 'the lungs',
#    'labels': ['life', 'maidan', 'animal'],
#    'scores': [0.5361999273300171, 0.05294836685061455, 0.05197514593601227]}],
#  [{'sequence': 'Kiselyov',
#    'labels': ['language', 'nation', 'family'],
#    'scores': [0.1931278258562088, 0.15996132791042328, 0.11706528812646866]},
#   {'sequence': 'Netherlands',
#    'labels': ['nation', 'geography', 'language'],
#    'scores': [0.7849001884460449, 0.05810897797346115, 0.034637242555618286]},
#   {'sequence': 'I bow',
#    'labels': ['maidan', 'gender', 'family'],
#    'scores': [0.1832210272550583, 0.17940297722816467, 0.11351102590560913]},
#   {'sequence': 'tulips',
#    'labels': ['fruit', 'nature', 'protest'],
#    'scores': [0.795573890209198, 0.03553863614797592, 0.023865722119808197]},
#   {'sequence': 'liberals',
#    'labels': ['protest', 'time', 'maidan'],
#    'scores': [0.17355865240097046, 0.09907907247543335, 0.09756669402122498]}],
#  [{'sequence': 'short film',
#    'labels': ['time', 'maidan', 'family'],
#    'scores': [0.3023945391178131, 0.0945306345820427, 0.06315537542104721]},
#   {'sequence': 'centipede',
#    'labels': ['animal', 'gender', 'nature'],
#    'scores': [0.829509437084198, 0.048611465841531754, 0.03369103744626045]},
#   {'sequence': 'frozen',
#    'labels': ['time', 'nature', 'language'],
#    'scores': [0.2634437382221222, 0.09792886674404144, 0.06855498254299164]},
#   {'sequence': 'ebbs away',
#    'labels': ['time', 'animal', 'maidan'],
#    'scores': [0.14309073984622955, 0.12073731422424316, 0.08297538012266159]},
#   {'sequence': 'rhyme',
#    'labels': ['language', 'poetry', 'maidan'],
#    'scores': [0.549927294254303, 0.17731867730617523, 0.03964929282665253]}],
#  [{'sequence': 'pop up',
#    'labels': ['maidan', 'family', 'time'],
#    'scores': [0.10721731930971146, 0.10640056431293488, 0.09906303137540817]},
#   {'sequence': 'lattice',
#    'labels': ['language', 'geography', 'time'],
#    'scores': [0.5245746374130249, 0.06168888509273529, 0.05454430356621742]},
#   {'sequence': 'shoulder',
#    'labels': ['maidan', 'language', 'gender'],
#    'scores': [0.11840561777353287, 0.11509720236063004, 0.09800100326538086]},
#   {'sequence': 'criminals',
#    'labels': ['maidan', 'time', 'gender'],
#    'scores': [0.18804332613945007, 0.13974107801914215, 0.08963849395513535]},
#   {'sequence': 'back streets',
#    'labels': ['geography', 'maidan', 'time'],
#    'scores': [0.4313274621963501, 0.09849880635738373, 0.07915502786636353]}],
#  [{'sequence': 'tires',
#    'labels': ['maidan', 'protest', 'time'],
#    'scores': [0.13572129607200623, 0.1035819724202156, 0.1032281294465065]},
#   {'sequence': 'cost',
#    'labels': ['maidan', 'family', 'nation'],
#    'scores': [0.1521328091621399, 0.11290838569402695, 0.0700625628232956]},
#   {'sequence': 'arches',
#    'labels': ['animal', 'maidan', 'geography'],
#    'scores': [0.1293562650680542, 0.11402580142021179, 0.07921472936868668]},
#   {'sequence': 'bureaucratic',
#    'labels': ['language', 'time', 'maidan'],
#    'scores': [0.17394155263900757, 0.1271488070487976, 0.11376529932022095]},
#   {'sequence': 'good',
#    'labels': ['maidan', 'family', 'time'],
#    'scores': [0.1362832635641098, 0.12427055090665817, 0.07792983949184418]}],
#  [{'sequence': 'palpitation',
#    'labels': ['politics', 'psychology', 'protest'],
#    'scores': [0.3158479630947113, 0.28451627492904663, 0.15231993794441223]},
#   {'sequence': 'paint',
#    'labels': ['maidan', 'gender', 'time'],
#    'scores': [0.1856832206249237, 0.09828643500804901, 0.08905696868896484]},
#   {'sequence': 'medical',
#    'labels': ['maidan', 'time', 'gender'],
#    'scores': [0.11941667646169662, 0.11933080106973648, 0.093631811439991]},
#   {'sequence': 'things',
#    'labels': ['nature', 'life', 'maidan'],
#    'scores': [0.128165140748024, 0.0950528085231781, 0.0832010880112648]},
#   {'sequence': 'travel',
#    'labels': ['time', 'geography', 'maidan'],
#    'scores': [0.2858324646949768, 0.1274169534444809, 0.09271586686372757]}],
#  [{'sequence': 'murderous',
#    'labels': ['death', 'maidan', 'language'],
#    'scores': [0.5536916255950928, 0.07171637564897537, 0.05727705731987953]},
#   {'sequence': 'perforated',
#    'labels': ['protest', 'time', 'maidan'],
#    'scores': [0.2305513620376587, 0.09090667963027954, 0.08983783423900604]},
#   {'sequence': 'shoots',
#    'labels': ['nature', 'protest', 'animal'],
#    'scores': [0.18828555941581726, 0.1587429642677307, 0.15862572193145752]},
#   {'sequence': 'after asking',
#    'labels': ['time', 'language', 'maidan'],
#    'scores': [0.14812985062599182, 0.10669460147619247, 0.09401454031467438]},
#   {'sequence': 'knocking out',
#    'labels': ['death', 'time', 'maidan'],
#    'scores': [0.19544033706188202, 0.14104975759983063, 0.0994761511683464]}],
#  [{'sequence': 'palpitation',
#    'labels': ['politics', 'psychology', 'protest'],
#    'scores': [0.3158479630947113, 0.28451627492904663, 0.15231993794441223]},
#   {'sequence': 'paint',
#    'labels': ['maidan', 'gender', 'time'],
#    'scores': [0.1856832206249237, 0.09828643500804901, 0.08905696868896484]},
#   {'sequence': 'medical',
#    'labels': ['maidan', 'time', 'gender'],
#    'scores': [0.11941667646169662, 0.11933080106973648, 0.093631811439991]},
#   {'sequence': 'things',
#    'labels': ['nature', 'life', 'maidan'],
#    'scores': [0.128165140748024, 0.0950528085231781, 0.0832010880112648]},
#   {'sequence': 'travel',
#    'labels': ['time', 'geography', 'maidan'],
#    'scores': [0.2858324646949768, 0.1274169534444809, 0.09271586686372757]}],
#  [{'sequence': 'the strongest',
#    'labels': ['maidan', 'nation', 'protest'],
#    'scores': [0.12026089429855347, 0.08614498376846313, 0.07242438942193985]},
#   {'sequence': 'we will win',
#    'labels': ['nation', 'life', 'family'],
#    'scores': [0.176788792014122, 0.09827495366334915, 0.09620294719934464]},
#   {'sequence': 'I promise',
#    'labels': ['maidan', 'family', 'time'],
#    'scores': [0.13169647753238678, 0.10515490919351578, 0.09092177450656891]},
#   {'sequence': 'you know',
#    'labels': ['family', 'life', 'memory'],
#    'scores': [0.11448899656534195, 0.11319766938686371, 0.09701741486787796]},
#   {'sequence': 'gain',
#    'labels': ['family', 'maidan', 'time'],
#    'scores': [0.13773323595523834, 0.11650882661342621, 0.09338407963514328]}],
#  [{'sequence': 'aquarium',
#    'labels': ['animal', 'nature', 'life'],
#    'scores': [0.7424951791763306, 0.06102338805794716, 0.0348321758210659]},
#   {'sequence': "let's go out",
#    'labels': ['time', 'life', 'nation'],
#    'scores': [0.3043704330921173, 0.10386461764574051, 0.07589932531118393]},
#   {'sequence': "let's come",
#    'labels': ['time', 'nation', 'life'],
#    'scores': [0.31931641697883606, 0.09962872415781021, 0.08202605694532394]},
#   {'sequence': 'window',
#    'labels': ['family', 'maidan', 'time'],
#    'scores': [0.12121796607971191, 0.10661105066537857, 0.08652930706739426]},
#   {'sequence': 'fulfilled',
#    'labels': ['family', 'maidan', 'life'],
#    'scores': [0.14005133509635925, 0.12512797117233276, 0.11575469374656677]}],
#  [{'sequence': 'rips off',
#    'labels': ['time', 'maidan', 'protest'],
#    'scores': [0.14527972042560577, 0.10479261726140976, 0.0729404166340828]},
#   {'sequence': 'sniper',
#    'labels': ['gender', 'war', 'maidan'],
#    'scores': [0.15521284937858582, 0.1250765323638916, 0.09308246523141861]},
#   {'sequence': 'intertwine',
#    'labels': ['family', 'language', 'time'],
#    'scores': [0.12797580659389496, 0.1279304325580597, 0.0933125913143158]},
#   {'sequence': 'rested',
#    'labels': ['time', 'family', 'maidan'],
#    'scores': [0.4032737612724304, 0.07641199976205826, 0.06813174486160278]},
#   {'sequence': 'snow',
#    'labels': ['season', 'nature', 'maidan'],
#    'scores': [0.49485233426094055, 0.21931740641593933, 0.03761898726224899]}],
#  [{'sequence': 'tremble',
#    'labels': ['time', 'language', 'protest'],
#    'scores': [0.43530282378196716, 0.1212063804268837, 0.09934068471193314]},
#   {'sequence': 'love',
#    'labels': ['love', 'family', 'maidan'],
#    'scores': [0.590686023235321, 0.10285763442516327, 0.049728550016880035]},
#   {'sequence': 'unworthy',
#    'labels': ['protest', 'maidan', 'language'],
#    'scores': [0.17660078406333923, 0.1540493369102478, 0.07900212705135345]},
#   {'sequence': 'silence',
#    'labels': ['time', 'language', 'maidan'],
#    'scores': [0.25655707716941833, 0.09655630588531494, 0.08153567463159561]},
#   {'sequence': 'the worst',
#    'labels': ['maidan', 'nation', 'animal'],
#    'scores': [0.11600995808839798, 0.10026068240404129, 0.07240147143602371]}],
#  [{'sequence': 'blindness',
#    'labels': ['nation', 'maidan', 'death'],
#    'scores': [0.13055558502674103, 0.1267145723104477, 0.12500712275505066]},
#   {'sequence': 'silence',
#    'labels': ['time', 'language', 'maidan'],
#    'scores': [0.25655707716941833, 0.09655630588531494, 0.08153567463159561]},
#   {'sequence': 'vanishing',
#    'labels': ['time', 'maidan', 'protest'],
#    'scores': [0.1396375596523285, 0.10568075627088547, 0.08626126497983932]},
#   {'sequence': 'blindness',
#    'labels': ['nation', 'maidan', 'death'],
#    'scores': [0.13055558502674103, 0.1267145723104477, 0.12500712275505066]},
#   {'sequence': 'hello',
#    'labels': ['language', 'family', 'maidan'],
#    'scores': [0.37265416979789734, 0.08800989389419556, 0.08750000596046448]}],
#  [{'sequence': 'knowledgeable',
#    'labels': ['maidan', 'time', 'family'],
#    'scores': [0.15028099715709686, 0.10177628695964813, 0.08070819079875946]},
#   {'sequence': 'mother-of-pearl',
#    'labels': ['family', 'gender', 'nature'],
#    'scores': [0.34116411209106445, 0.24016600847244263, 0.12279544770717621]},
#   {'sequence': 'jelly-like',
#    'labels': ['gender', 'maidan', 'animal'],
#    'scores': [0.11488305777311325, 0.10931701958179474, 0.0897708386182785]},
#   {'sequence': 'pearl',
#    'labels': ['language', 'gender', 'maidan'],
#    'scores': [0.18918852508068085, 0.08838963508605957, 0.08020550012588501]},
#   {'sequence': 'multiplying',
#    'labels': ['maidan', 'time', 'family'],
#    'scores': [0.13522042334079742, 0.10910942405462265, 0.08414243161678314]}],
#  [{'sequence': 'the poor',
#    'labels': ['maidan', 'protest', 'life'],
#    'scores': [0.21936042606830597, 0.1665899008512497, 0.11625169217586517]},
#   {'sequence': 'successfully',
#    'labels': ['family', 'maidan', 'time'],
#    'scores': [0.14103446900844574, 0.11626960337162018, 0.10630030930042267]},
#   {'sequence': 'today',
#    'labels': ['time', 'life', 'maidan'],
#    'scores': [0.5080797672271729, 0.10123087465763092, 0.04588950797915459]},
#   {'sequence': 'take a walk',
#    'labels': ['time', 'nature', 'life'],
#    'scores': [0.4040974974632263, 0.2182377576828003, 0.07556721568107605]},
#   {'sequence': 'our',
#    'labels': ['nation', 'family', 'language'],
#    'scores': [0.36431998014450073, 0.14659330248832703, 0.0584566555917263]}],
#  [{'sequence': 'good',
#    'labels': ['maidan', 'family', 'time'],
#    'scores': [0.1362832635641098, 0.12427055090665817, 0.07792983949184418]},
#   {'sequence': 'staring',
#    'labels': ['time', 'protest', 'maidan'],
#    'scores': [0.27635645866394043, 0.10317391902208328, 0.07842396199703217]},
#   {'sequence': 'will hear',
#    'labels': ['language', 'family', 'time'],
#    'scores': [0.11229755729436874, 0.10677851736545563, 0.08469437807798386]},
#   {'sequence': 'say',
#    'labels': ['language', 'family', 'maidan'],
#    'scores': [0.3976426422595978, 0.0710594579577446, 0.07051873952150345]},
#   {'sequence': 'heaven',
#    'labels': ['religion', 'love', 'life'],
#    'scores': [0.20203427970409393, 0.11898499727249146, 0.11085847020149231]}],
#  [{'sequence': 'it stinks',
#    'labels': ['maidan', 'animal', 'language'],
#    'scores': [0.09729745239019394, 0.09688727557659149, 0.09453423321247101]},
#   {'sequence': 'bandages',
#    'labels': ['maidan', 'gender', 'protest'],
#    'scores': [0.26582732796669006, 0.09756544977426529, 0.07557351887226105]},
#   {'sequence': 'blessing',
#    'labels': ['love', 'maidan', 'family'],
#    'scores': [0.19954071938991547, 0.13266411423683167, 0.11000623553991318]},
#   {'sequence': 'bending over',
#    'labels': ['time', 'maidan', 'protest'],
#    'scores': [0.1395517885684967, 0.1286727786064148, 0.09375256299972534]},
#   {'sequence': 'friends',
#    'labels': ['maidan', 'family', 'time'],
# ...
#    'labels': ['maidan', 'time', 'language'],
#    'scores': [0.14898358285427094, 0.1352958083152771, 0.10801154375076294]}],
#  [{'sequence': 'pulling',
#    'labels': ['protest', 'time', 'maidan'],
#    'scores': [0.13691432774066925, 0.12719164788722992, 0.08872558176517487]},
#   {'sequence': 'indomitability',
#    'labels': ['nature', 'time', 'life'],
#    'scores': [0.6917389035224915, 0.06067527458071709, 0.0545843243598938]},
#   {'sequence': 'claw',
#    'labels': ['animal', 'family', 'protest'],
#    'scores': [0.33420854806900024, 0.09626433253288269, 0.0634830966591835]},
#   {'sequence': 'camels',
#    'labels': ['animal', 'nature', 'gender'],
#    'scores': [0.916431725025177, 0.0381290577352047, 0.007693846710026264]},
#   {'sequence': 'feel',
#    'labels': ['family', 'maidan', 'time'],
#    'scores': [0.11156083643436432, 0.11006738990545273, 0.08369816839694977]}],
#  [{'sequence': 'name',
#    'labels': ['gender', 'language', 'maidan'],
#    'scores': [0.19978412985801697, 0.1776530146598816, 0.07637181133031845]},
#   {'sequence': 'PR',
#    'labels': ['protest', 'language', 'politics'],
#    'scores': [0.2504119575023651, 0.09835148602724075, 0.07398687303066254]},
#   {'sequence': 'fanaticism',
#    'labels': ['religion', 'maidan', 'animal'],
#    'scores': [0.26379916071891785, 0.1386568546295166, 0.07653770595788956]},
#   {'sequence': 'previous',
#    'labels': ['time', 'family', 'memory'],
#    'scores': [0.3677113950252533, 0.08225349336862564, 0.0712859258055687]},
#   {'sequence': 'blamed',
#    'labels': ['language', 'maidan', 'time'],
#    'scores': [0.24341563880443573, 0.10548064112663269, 0.0723530501127243]}],
#  [{'sequence': 'internally displaced',
#    'labels': ['life', 'time', 'maidan'],
#    'scores': [0.14862942695617676, 0.14274059236049652, 0.13242365419864655]},
#   {'sequence': 'literary',
#    'labels': ['language', 'life', 'maidan'],
#    'scores': [0.5691866874694824, 0.10410947352647781, 0.056492287665605545]},
#   {'sequence': 'externally unstable',
#    'labels': ['maidan', 'protest', 'time'],
#    'scores': [0.10894007235765457, 0.08364243805408478, 0.07383721321821213]},
#   {'sequence': 'literary',
#    'labels': ['language', 'life', 'maidan'],
#    'scores': [0.5691866874694824, 0.10410947352647781, 0.056492287665605545]},
#   {'sequence': 'the most important',
#    'labels': ['maidan', 'family', 'nation'],
#    'scores': [0.11598455905914307, 0.10175764560699463, 0.07750789821147919]}],
#  [{'sequence': 'prefrontal',
#    'labels': ['protest', 'language', 'time'],
#    'scores': [0.46190449595451355, 0.12390054017305374, 0.09028217196464539]},
#   {'sequence': 'ambiguity',
#    'labels': ['language', 'maidan', 'protest'],
#    'scores': [0.15958017110824585, 0.11762487143278122, 0.1076689139008522]},
#   {'sequence': 'spontaneity',
#    'labels': ['time', 'life', 'nature'],
#    'scores': [0.13910239934921265, 0.11869066208600998, 0.11037757247686386]},
#   {'sequence': 'lightness',
#    'labels': ['maidan', 'life', 'family'],
#    'scores': [0.1474153995513916, 0.09704887121915817, 0.09131034463644028]},
#   {'sequence': 'genius',
#    'labels': ['gender', 'maidan', 'nation'],
#    'scores': [0.41986238956451416, 0.12082841992378235, 0.08086324483156204]}],
#  [{'sequence': 'incomprehensible',
#    'labels': ['maidan', 'protest', 'time'],
#    'scores': [0.12140246480703354, 0.11422867327928543, 0.08889102190732956]},
#   {'sequence': 'uncaught',
#    'labels': ['time', 'maidan', 'nation'],
#    'scores': [0.16160978376865387, 0.10135237127542496, 0.08298412710428238]},
#   {'sequence': 'inexorable',
#    'labels': ['death', 'maidan', 'protest'],
#    'scores': [0.12678493559360504, 0.1247473731637001, 0.11528585106134415]},
#   {'sequence': 'elusive',
#    'labels': ['language', 'maidan', 'time'],
#    'scores': [0.14618231356143951, 0.13865485787391663, 0.13483983278274536]},
#   {'sequence': 'frying pan',
#    'labels': ['maidan', 'gender', 'time'],
#    'scores': [0.19860795140266418, 0.11122726649045944, 0.10669019818305969]}],
#  [{'sequence': 'despair',
#    'labels': ['maidan', 'language', 'protest'],
#    'scores': [0.14288507401943207, 0.1261157989501953, 0.0856805145740509]},
#   {'sequence': 'you want',
#    'labels': ['maidan', 'family', 'language'],
#    'scores': [0.10864903032779694, 0.09111624211072922, 0.08238466084003448]},
#   {'sequence': 'returns',
#    'labels': ['time', 'family', 'maidan'],
#    'scores': [0.120728999376297, 0.11468399316072464, 0.0955469161272049]},
#   {'sequence': 'targets',
#    'labels': ['maidan', 'animal', 'time'],
#    'scores': [0.10246679186820984, 0.08551047742366791, 0.08499035984277725]},
#   {'sequence': 'be wrong',
#    'labels': ['protest', 'maidan', 'time'],
#    'scores': [0.14133742451667786, 0.08850640803575516, 0.07345574349164963]}],
#  [{'sequence': 'actually',
#    'labels': ['family', 'maidan', 'nature'],
#    'scores': [0.11062140762805939, 0.0969562903046608, 0.08123138546943665]},
#   {'sequence': 'logic',
#    'labels': ['language', 'time', 'maidan'],
#    'scores': [0.32697150111198425, 0.08473397046327591, 0.08443743735551834]},
#   {'sequence': 'hostile',
#    'labels': ['protest', 'maidan', 'language'],
#    'scores': [0.21725884079933167, 0.11877579241991043, 0.09048695862293243]},
#   {'sequence': 'you heal',
#    'labels': ['time', 'life', 'family'],
#    'scores': [0.30743658542633057, 0.1432461440563202, 0.09349440038204193]},
#   {'sequence': 'pretending',
#    'labels': ['protest', 'maidan', 'language'],
#    'scores': [0.2418026626110077, 0.12621036171913147, 0.10941404104232788]}],
#  [{'sequence': "I'm coming back",
#    'labels': ['time', 'memory', 'life'],
#    'scores': [0.4047921597957611, 0.20727290213108063, 0.09078891575336456]},
#   {'sequence': 'you calm down',
#    'labels': ['time', 'maidan', 'family'],
#    'scores': [0.2732253074645996, 0.08520999550819397, 0.08234436810016632]},
#   {'sequence': 'so',
#    'labels': ['language', 'time', 'maidan'],
#    'scores': [0.19781234860420227, 0.09520100802183151, 0.08244436234235764]},
#   {'sequence': 'magnets',
#    'labels': ['maidan', 'geography', 'gender'],
#    'scores': [0.26255208253860474, 0.07995674014091492, 0.07472445070743561]},
#   {'sequence': 'magnets',
#    'labels': ['maidan', 'geography', 'gender'],
#    'scores': [0.26255208253860474, 0.07995674014091492, 0.07472445070743561]}],
#  [{'sequence': 'shot at',
#    'labels': ['maidan', 'death', 'time'],
#    'scores': [0.13426116108894348, 0.11091083288192749, 0.09023388475179672]},
#   {'sequence': 'you offer',
#    'labels': ['maidan', 'language', 'life'],
#    'scores': [0.13136570155620575, 0.1244124248623848, 0.09596515446901321]},
#   {'sequence': 'actually',
#    'labels': ['family', 'maidan', 'nature'],
#    'scores': [0.11062140762805939, 0.0969562903046608, 0.08123138546943665]},
#   {'sequence': 'you know',
#    'labels': ['family', 'life', 'memory'],
#    'scores': [0.11448899656534195, 0.11319766938686371, 0.09701741486787796]},
#   {'sequence': 'disguised',
#    'labels': ['maidan', 'language', 'protest'],
#    'scores': [0.16704411804676056, 0.08904847502708435, 0.08749455958604813]}],
#  [{'sequence': 'cracked',
#    'labels': ['time', 'maidan', 'protest'],
#    'scores': [0.12994317710399628, 0.10439568758010864, 0.08289141952991486]},
#   {'sequence': 'landscapes',
#    'labels': ['geography', 'nature', 'maidan'],
#    'scores': [0.45748308300971985, 0.42666172981262207, 0.02754868008196354]},
#   {'sequence': 'reddish',
#    'labels': ['maidan', 'gender', 'protest'],
#    'scores': [0.10977387428283691, 0.09241285175085068, 0.08921094238758087]},
#   {'sequence': 'wet',
#    'labels': ['maidan', 'time', 'gender'],
#    'scores': [0.12971699237823486, 0.11592769622802734, 0.10173904150724411]},
#   {'sequence': 'sit down',
#    'labels': ['time', 'maidan', 'gender'],
#    'scores': [0.36121833324432373, 0.10391484200954437, 0.0732206404209137]}],
#  [{'sequence': 'Sorry',
#    'labels': ['maidan', 'protest', 'language'],
#    'scores': [0.1303035467863083, 0.11642733216285706, 0.114214226603508]},
#   {'sequence': 'poems',
#    'labels': ['poetry', 'language', 'maidan'],
#    'scores': [0.6763935685157776, 0.09012549370527267, 0.03973894938826561]},
#   {'sequence': 'shelter',
#    'labels': ['maidan', 'gender', 'time'],
#    'scores': [0.14412188529968262, 0.11940339207649231, 0.08770635724067688]},
#   {'sequence': 'surgical',
#    'labels': ['maidan', 'gender', 'time'],
#    'scores': [0.11340416967868805, 0.11078636348247528, 0.08215431123971939]},
#   {'sequence': 'picked up',
#    'labels': ['maidan', 'time', 'family'],
#    'scores': [0.12142670154571533, 0.0976739451289177, 0.07855987548828125]}],
#  [{'sequence': 'meet',
#    'labels': ['family', 'maidan', 'life'],
#    'scores': [0.15008395910263062, 0.1405421793460846, 0.08105653524398804]},
#   {'sequence': 'messages',
#    'labels': ['language', 'maidan', 'time'],
#    'scores': [0.22708840668201447, 0.12911605834960938, 0.07438033074140549]},
#   {'sequence': 'literary',
#    'labels': ['language', 'life', 'maidan'],
#    'scores': [0.5691866874694824, 0.10410947352647781, 0.056492287665605545]},
#   {'sequence': 'literary',
#    'labels': ['language', 'life', 'maidan'],
#    'scores': [0.5691866874694824, 0.10410947352647781, 0.056492287665605545]},
#   {'sequence': 'dissemination',
#    'labels': ['language', 'protest', 'maidan'],
#    'scores': [0.13062039017677307, 0.12029005587100983, 0.08363264799118042]}],
#  [{'sequence': 'scattered',
#    'labels': ['maidan', 'time', 'language'],
#    'scores': [0.13605405390262604, 0.12220460176467896, 0.10038439929485321]},
#   {'sequence': 'carnation',
#    'labels': ['animal', 'nature', 'fruit'],
#    'scores': [0.4940682351589203, 0.1953732818365097, 0.12021717429161072]},
#   {'sequence': 'deadly',
#    'labels': ['death', 'maidan', 'life'],
#    'scores': [0.8346065878868103, 0.022153282538056374, 0.021546101197600365]},
#   {'sequence': 'cool down',
#    'labels': ['time', 'season', 'maidan'],
#    'scores': [0.3978871703147888, 0.08565539121627808, 0.08512487262487411]},
#   {'sequence': 'hyacinth',
#    'labels': ['nature', 'life', 'maidan'],
#    'scores': [0.4854368269443512, 0.0647362694144249, 0.04876500368118286]}],
#  [{'sequence': 'midnight_verses',
#    'labels': ['time', 'language', 'gender'],
#    'scores': [0.26737508177757263, 0.14086951315402985, 0.09769503027200699]},
#   {'sequence': 'fleeting',
#    'labels': ['language', 'time', 'maidan'],
#    'scores': [0.11556850373744965, 0.10806246846914291, 0.10499338805675507]},
#   {'sequence': 'recognize',
#    'labels': ['family', 'maidan', 'memory'],
#    'scores': [0.11673200130462646, 0.10451216250658035, 0.08282525837421417]},
#   {'sequence': 'summer',
#    'labels': ['season', 'time', 'life'],
#    'scores': [0.7128074765205383, 0.10045885294675827, 0.03138766437768936]},
#   {'sequence': 'covers',
#    'labels': ['geography', 'maidan', 'family'],
#    'scores': [0.3396408259868622, 0.08547120541334152, 0.06510414928197861]}],
#  [{'sequence': 'you find yourself',
#    'labels': ['life', 'time', 'maidan'],
#    'scores': [0.26179078221321106, 0.08939601480960846, 0.08439788967370987]},
#   {'sequence': 'ambiguity',
#    'labels': ['language', 'maidan', 'protest'],
#    'scores': [0.15958017110824585, 0.11762487143278122, 0.1076689139008522]},
#   {'sequence': 'singing over',
#    'labels': ['language', 'time', 'poetry'],
#    'scores': [0.2838791012763977, 0.12233877182006836, 0.09784924983978271]},
#   {'sequence': 'enter',
#    'labels': ['family', 'maidan', 'time'],
#    'scores': [0.1349528729915619, 0.1061878427863121, 0.08856874704360962]},
#   {'sequence': 'knocking',
#    'labels': ['protest', 'maidan', 'time'],
#    'scores': [0.16494500637054443, 0.14588427543640137, 0.11614169925451279]}],
#  [{'sequence': 'calculation',
#    'labels': ['time', 'maidan', 'family'],
#    'scores': [0.16438990831375122, 0.150034099817276, 0.07965592294931412]},
#   {'sequence': 'misunderstanding',
#    'labels': ['maidan', 'language', 'protest'],
#    'scores': [0.1203870102763176, 0.10372643917798996, 0.0974927693605423]},
#   {'sequence': 'thermal imagers',
#    'labels': ['season', 'time', 'gender'],
#    'scores': [0.10489314794540405, 0.10046866536140442, 0.08865830302238464]},
#   {'sequence': 'thermal imager',
#    'labels': ['time', 'season', 'maidan'],
#    'scores': [0.1438944935798645, 0.10916373133659363, 0.08291158825159073]},
#   {'sequence': 'confused',
#    'labels': ['maidan', 'protest', 'nation'],
#    'scores': [0.11792930215597153, 0.09398069232702255, 0.08940568566322327]}],
#  [{'sequence': 'interlocutors',
#    'labels': ['time', 'language', 'protest'],
#    'scores': [0.1538611352443695, 0.144379124045372, 0.1118876188993454]},
#   {'sequence': 'painkillers',
#    'labels': ['maidan', 'nation', 'gender'],
#    'scores': [0.1517665833234787, 0.11872438341379166, 0.08035848289728165]},
#   {'sequence': 'interlocutors',
#    'labels': ['time', 'language', 'protest'],
#    'scores': [0.1538611352443695, 0.144379124045372, 0.1118876188993454]},
#   {'sequence': 'damaged',
#    'labels': ['maidan', 'time', 'nation'],
#    'scores': [0.17042508721351624, 0.09812495112419128, 0.0821058452129364]},
#   {'sequence': 'future',
#    'labels': ['maidan', 'family', 'time'],
#    'scores': [0.11157085001468658, 0.10567982494831085, 0.08545757830142975]}],
#  [{'sequence': 'will be cut',
#    'labels': ['time', 'maidan', 'life'],
#    'scores': [0.12265068292617798, 0.09358146786689758, 0.08783286809921265]},
#   {'sequence': 'will stumble',
#    'labels': ['life', 'maidan', 'time'],
#    'scores': [0.19616423547267914, 0.1025979146361351, 0.09724448621273041]},
#   {'sequence': 'unlived',
#    'labels': ['death', 'time', 'protest'],
#    'scores': [0.35855475068092346, 0.11770927906036377, 0.07737530767917633]},
#   {'sequence': 'unchangeable',
#    'labels': ['protest', 'maidan', 'language'],
#    'scores': [0.11793506145477295, 0.10869424790143967, 0.07789407670497894]},
#   {'sequence': 'artifact',
#    'labels': ['maidan', 'nature', 'language'],
#    'scores': [0.16694265604019165, 0.10847586393356323, 0.06632343679666519]}],
#  [{'sequence': 'pre-war_poems',
#    'labels': ['poetry', 'time', 'language'],
#    'scores': [0.49674949049949646, 0.10826706141233444, 0.07236813008785248]},
#   {'sequence': 'airs out',
#    'labels': ['time', 'protest', 'death'],
#    'scores': [0.2153773009777069, 0.1754073053598404, 0.12261370569467545]},
#   {'sequence': 'grumble',
#    'labels': ['protest', 'language', 'maidan'],
#    'scores': [0.24268753826618195, 0.22732345759868622, 0.07898691296577454]},
#   {'sequence': 'get crowded',
#    'labels': ['life', 'time', 'maidan'],
#    'scores': [0.17755606770515442, 0.12176238000392914, 0.10968436300754547]},
#   {'sequence': 'we bake',
#    'labels': ['maidan', 'time', 'nation'],
#    'scores': [0.1780482828617096, 0.14397726953029633, 0.1410570591688156]}],
#  [{'sequence': 'pre-war_poems',
#    'labels': ['poetry', 'time', 'language'],
#    'scores': [0.49674949049949646, 0.10826706141233444, 0.07236813008785248]},
#   {'sequence': 'understandable',
#    'labels': ['language', 'maidan', 'life'],
#    'scores': [0.12813980877399445, 0.1138918548822403, 0.09307865798473358]},
#   {'sequence': 'strangers',
#    'labels': ['maidan', 'protest', 'language'],
#    'scores': [0.16468000411987305, 0.11409836262464523, 0.10806455463171005]},
#   {'sequence': 'unfamiliar',
#    'labels': ['maidan', 'nation', 'time'],
#    'scores': [0.12458854913711548, 0.10598631948232651, 0.09127442538738251]},
#   {'sequence': 'return',
#    'labels': ['family', 'time', 'maidan'],
#    'scores': [0.12615926563739777, 0.10602409392595291, 0.08906832337379456]}],
#  [{'sequence': 'pre-war_poems',
#    'labels': ['poetry', 'time', 'language'],
#    'scores': [0.49674949049949646, 0.10826706141233444, 0.07236813008785248]},
#   {'sequence': 'giggle',
#    'labels': ['gender', 'family', 'language'],
#    'scores': [0.16364288330078125, 0.12408114224672318, 0.10952847450971603]},
#   {'sequence': 'rustling',
#    'labels': ['protest', 'maidan', 'time'],
#    'scores': [0.1513471007347107, 0.11569473892450333, 0.10382314026355743]},
#   {'sequence': 'spin',
#    'labels': ['family', 'maidan', 'time'],
#    'scores': [0.10139507800340652, 0.09528063982725143, 0.09493796527385712]},
#   {'sequence': 'yours',
#    'labels': ['gender', 'family', 'nation'],
#    'scores': [0.3529314398765564, 0.1943797767162323, 0.08752801269292831]}],
#  ...]

# %%
data = data.assign(keyword_eng_theme=keyword_eng_theme)
data.to_csv("keyword_eng_theme.csv")

# %% [markdown]
# ## Generating themes based on sentence containing keyword

# %% [markdown]
# ### Task breakdown:
# 1. Extract the line that contains the keyword from the original text
# 2. Translate the line to english
# 3. Run zero-shot-classification on the english-translated line to match our previously defined big themes!

# %% [markdown]
# #### Small example

# %%
test_poem = data.iloc[4].original_poem
test_keywords = data.iloc[4].keywords_ori
print(data.iloc[4].original_poem)
# Out:
# ***
# Цей рік, який почався з середи -
# Куди він заведе нас всіх, куди?
# Чи буде він прямим, як кочерга?
# Але наступний рік почнеться з четверга...

# %%
test_keywords
# Out:
# "['наступний', 'четверга', 'кочерга', 'почнеться', 'прямим']"

# %%
test_poem.split("\n")
# Out:
# ['***',
#  'Цей рік, який почався з середи - ',
#  'Куди він заведе нас всіх, куди? ',
#  'Чи буде він прямим, як кочерга? ',
#  'Але наступний рік почнеться з четверга...']

# %%
# Naive for-looping
sentence_set = []
sentence_set_translated = []
for i in eval(test_keywords):
    for j in test_poem.split("\n"):
        if i in j:
            print(i, j)
            sentence_set.append(j)
set(sentence_set)
# Out:
# наступний Але наступний рік почнеться з четверга...
# четверга Але наступний рік почнеться з четверга...
# кочерга Чи буде він прямим, як кочерга?
# почнеться Але наступний рік почнеться з четверга...
# прямим Чи буде він прямим, як кочерга?
# {'Але наступний рік почнеться з четверга...',
#  'Чи буде він прямим, як кочерга? '}

# %%
# A better data structure for efficient search would be a sentence dictionary and word dictionary
# Sentence dictionary will have the number of sentence as key, and text sentence itself as value
sentence_dict = dict((idx, sentence) for idx, sentence in enumerate(test_poem.split("\n")))

# %%
# A word dictionary will have the word of each sentence as key, and the index of the sentence the word is found as value
word_dict = {}
for i in sentence_dict:
    words = re.sub(r'[\.\,\?\:\;\!\*\-\+\&\@\<\>]', '', sentence_dict[i]).split()
    word_dict.update(dict(zip(words, [i]*len(words))))
word_dict
# Out:
# {'Цей': 1,
#  'рік': 4,
#  'який': 1,
#  'почався': 1,
#  'з': 4,
#  'середи': 1,
#  'Куди': 2,
#  'він': 3,
#  'заведе': 2,
#  'нас': 2,
#  'всіх': 2,
#  'куди': 2,
#  'Чи': 3,
#  'буде': 3,
#  'прямим': 3,
#  'як': 3,
#  'кочерга': 3,
#  'Але': 4,
#  'наступний': 4,
#  'почнеться': 4,
#  'четверга': 4}

# %%
key_sentence = set()
for i in eval(test_keywords):
    sentence_id = word_dict[i]
    key_sentence.add(sentence_dict[sentence_id])
key_sentence
# Out:
# {'Але наступний рік почнеться з четверга...',
#  'Чи буде він прямим, як кочерга? '}

# %%
translated = translate_v2(list(key_sentence))
translated
# Out:
# ['Will it be straight as a poker?', 'But next year starts on Thursday...']

# %%
# Big theme list from "Cleaning & KeyBERT Part1"
big_theme = ['war', 'religion', 'nation', 'death', 'time',
             'protest', 'geography', 'season', 'family', 'language',
             'maidan','memory', 'animal', 'nature', 'love', 'poetry',   
             'psychology', 'politics', 'life', 'fruit', 'gender', 'mythology']

# %%
sequence_to_classify = translated[0]
classifier(sequence_to_classify, big_theme)
# Out:
# {'sequence': 'Will it be straight as a poker?',
#  'labels': ['language',
#   'maidan',
#   'nation',
#   'protest',
#   'time',
#   'gender',
#   'life',
#   'psychology',
#   'family',
#   'nature',
#   'animal',
#   'politics',
#   'memory',
#   'season',
#   'geography',
#   'mythology',
#   'death',
#   'war',
#   'love',
#   'fruit',
#   'religion',
#   'poetry'],
#  'scores': [0.10203450173139572,
#   0.09321364760398865,
#   0.08782705664634705,
#   0.0771658793091774,
#   0.071766197681427,
#   0.07138112187385559,
#   0.06894007325172424,
#   0.05154707655310631,
#   0.04916727542877197,
#   0.04896628484129906,
#   0.04168234393000603,
#   0.03305824100971222,
#   0.03008979558944702,
#   0.028898190706968307,
#   0.028502605855464935,
#   0.02457469329237938,
#   0.0215385090559721,
#   0.020195934921503067,
#   0.015201226808130741,
#   0.014040797017514706,
#   0.01124081015586853,
#   0.008967776782810688]}

# %%
sequence_to_classify = translated[1]
classifier(sequence_to_classify, big_theme)
# Out:
# {'sequence': 'But next year starts on Thursday...',
#  'labels': ['time',
#   'season',
#   'life',
#   'nation',
#   'maidan',
#   'language',
#   'family',
#   'protest',
#   'gender',
#   'animal',
#   'memory',
#   'geography',
#   'psychology',
#   'nature',
#   'death',
#   'mythology',
#   'politics',
#   'religion',
#   'love',
#   'poetry',
#   'war',
#   'fruit'],
#  'scores': [0.23022563755512238,
#   0.18337371945381165,
#   0.10486763715744019,
#   0.06838299334049225,
#   0.06712408363819122,
#   0.061745576560497284,
#   0.0528094507753849,
#   0.032620519399642944,
#   0.027655236423015594,
#   0.02519214153289795,
#   0.024064823985099792,
#   0.015775084495544434,
#   0.014748132787644863,
#   0.013392467983067036,
#   0.013248588889837265,
#   0.013135777786374092,
#   0.012663420289754868,
#   0.010304717347025871,
#   0.008389896713197231,
#   0.007602411322295666,
#   0.006375987082719803,
#   0.006301686633378267]}

# %% [markdown]
# #### Subset of data

# %%
subset = data[:20]['original_poem']
subset
# Out:
# 0     ***\ncказати собі чесно, якомога чесніше,\nтак...
# 1     ХАЙКУ З МАЙДАНУ\nДим у рукавах.\nНіби йдеш з ц...
# 2     (О.М.)\nНе мучнистой бабочкою белой\nВ землю я...
# 3     ***\n"Союз нерушимый" сыграют и хором споют.\n...
# 4     ***\nЦей рік, який почався з середи - \nКуди в...
# 5     ВІРШИК НА 1 СІЧНЯ \n(Обережно, жорстка лексика...
# 6     У найпершу ніч льодоставу до тебе прибився,\nп...
# 7     ПОВЕРНЕННЯ\n\nМісто L – так близько до міста N...
# 8     В ЄВРОПІ КРАЩЕ, НІЖ У...\n***\nА все ж таки в ...
# 9     А ХІБА НІ? \n***\nЗа тиждень цих суцільних вих...
# 10    Тадеуш Хабровський\nПортрет із сімома пальцями...
# 11    3 СІЧНЯ \n***\nРядки мої важкі та кострубаті, ...
# 12    Здесь разговоры\nА там на рынке\nСвиные головы...
# 13    Тадеуш Хабровський\nВуді Аллен каже\nбо в злі ...
# 14    Тадеуш Хабровський\nПори року\nКолінкую на зор...
# 15    А СВЯТО ТРИВАЄ...\n***\nНоворічна пісня рине \...
# 16    ХАЙКУ З МАЙДАНУ (завершення)\nІдуть на площу.\...
# 17    Спиричуэл\n\nЗапиши в тетрадку\nцифры по поряд...
# 18    ***\n\nПробудитесь, цари! Поднимайтесь скорей!...
# 19    ***\nВ еротичних снах приходить \nДо закоханих...
# Name: original_poem, dtype: object

# %%
def generate_sentence_dict(poem):
    return dict((idx, sentence) for idx, sentence in enumerate(poem.split("\n")))

def generate_word_dict(sentence_dict):
    word_dict = {}
    for i in sentence_dict:
        words = re.sub(r'[\.\,\?\:\;\!\*\-\+\&\@\<\>]', '', sentence_dict[i]).split()
        word_dict.update(dict(zip(words, [i]*len(words))))
    return word_dict

def get_key_sentence(keywords, word_dict, sentence_dict):
    key_sentence = set()
    for i in eval(keywords):
        try:
            sentence_id = word_dict[i]
            key_sentence.add(sentence_dict[sentence_id])
        except KeyError:
            continue
    return key_sentence

# %%
data[:10]
# Out:
#    ID         poem_author   language  \
# 0   1         Halyna Kruk  Ukrainian
# 1   2     Ostap Slyvynsky  Ukrainian
# 2   3     Osip Mandelstam    Russian
# 3   4    Boris Khersonsky    Russian
# 4   5  Oleksandr Irvanets  Ukrainian
# 5   6  Oleksandr Irvanets  Ukrainian
# 6   7    Kateryna Kalytko  Ukrainian
# 7   8       Oleh Kotsarev  Ukrainian
# 8   9  Oleksandr Irvanets  Ukrainian
# 9  10  Oleksandr Irvanets  Ukrainian
#
#                                        original_poem  \
# 0  ***\ncказати собі чесно, якомога чесніше,\nтак...
# 1  ХАЙКУ З МАЙДАНУ\nДим у рукавах.\nНіби йдеш з ц...
# 2  (О.М.)\nНе мучнистой бабочкою белой\nВ землю я...
# 3  ***\n"Союз нерушимый" сыграют и хором споют.\n...
# 4  ***\nЦей рік, який почався з середи - \nКуди в...
# 5  ВІРШИК НА 1 СІЧНЯ \n(Обережно, жорстка лексика...
# 6  У найпершу ніч льодоставу до тебе прибився,\nп...
# 7  ПОВЕРНЕННЯ\n\nМісто L – так близько до міста N...
# 8  В ЄВРОПІ КРАЩЕ, НІЖ У...\n***\nА все ж таки в ...
# 9  А ХІБА НІ? \n***\nЗа тиждень цих суцільних вих...
#
#                                     light_clean_poem  \
# 0  *** cказати собі чесно, якомога чесніше, так н...
# 1  ХАЙКУ З МАЙДАНУ Дим у рукавах. Ніби йдеш з цим...
# 2   Не мучнистой бабочкою белой В землю я заемный...
# 3  *** "Союз нерушимый" сыграют и хором споют. В ...
# 4  *** Цей рік, який почався з середи -  Куди він...
# 5  ВІРШИК НА 1 СІЧНЯ   *** Здрастуй, Дєдушка Боду...
# 6  У найпершу ніч льодоставу до тебе прибився, пе...
# 7  ПОВЕРНЕННЯ  Місто L – так близько до міста N, ...
# 8  В ЄВРОПІ КРАЩЕ, НІЖ У... *** А все ж таки в Єв...
# 9  А ХІБА НІ?  *** За тиждень цих суцільних вихід...
#
#                                                theme  \
# 0     {'ukraine', 'maidan', 'revolution', 'protest'}
# 1  {'revolution', 'poetic form', 'maidan', 'haiku...
# 2               {'time', 'twentieth century', 'war'}
# 3     {'food', 'soviet union', 'morphine', 'anthem'}
# 4                    {'time', 'new year', 'seasons'}
# 5                        {'grandpa bodun', 'family'}
# 6                     {'winter', 'death', 'animals'}
# 7                             {'', 'city', 'return'}
# 8                            {'geography', 'europe'}
# 9                                {'weekend', 'time'}
#
#                                             keywords  \
# 0  [('покладаючись', 0.3382), ('патріотичних', 0....
# 1  [('пообіцяти', 0.4741), ('пустимо', 0.3054), (...
# 2  [('восклицанья', 0.3814), ('мыслящее', 0.2992)...
# 3  [('проснусь', 0.3366), ('нерушимый', 0.331), (...
# 4  [('наступний', 0.4395), ('четверга', 0.2653), ...
# 5  [('сніданок', 0.4183), ('дєдушка', 0.4019), ('...
# 6  [('вдихаєш', 0.4907), ('найглухішої', 0.4699),...
# 7  [('насправді', 0.3842), ('ренесансовий', 0.344...
# 8  [('європоньці', 0.3633), ('краще', 0.262), ('с...
# 9  [('встигнемо', 0.419), ('тиждень', 0.3152), ('...
#
#                                         keywords_ori  \
# 0  ['покладаючись', 'патріотичних', 'втікаючи', '...
# 1  ['пообіцяти', 'пустимо', 'вистоїмо', 'лісистим...
# 2  ['восклицанья', 'мыслящее', 'молчаливо', 'позв...
# 3  ['проснусь', 'нерушимый', 'скрывать', 'подсыха...
# 4  ['наступний', 'четверга', 'кочерга', 'почнетьс...
# 5  ['сніданок', 'дєдушка', 'віршик', 'здрастуй', ...
# 6  ['вдихаєш', 'найглухішої', 'напівопустивши', '...
# 7  ['насправді', 'ренесансовий', 'розібрати', 'дз...
# 8  ['європоньці', 'краще', 'сидіти', 'копанці', '...
# 9  ['встигнемо', 'тиждень', 'втомитися', 'хіба', ...
#
#                                         keywords_eng
# 0  ['relying on', 'patriotic', 'running away', 'W...
# 1  ['to promise', "let's go", "let's stand", 'woo...
# 2  ['exclamations', 'thinking', 'silently', 'vert...
# 3  ['wake up', 'indestructible', 'hide', 'dries u...
# 4  ['following', 'Thursday', 'poker', 'will begin...
# 5  ['breakfast', 'Dedushka', 'poem', 'hello', 'i ...
# 6  ['you inhale', 'the deafest', 'half lowered', ...
# 7  ['actually', 'renaissance', 'disassemble', 'ca...
# 8  ['Europeans', 'better', 'sit', 'diggers', 'sli...
# 9  ["we'll make it", 'week', 'get tired', 'maybe'...

# %%
start = time.time()
key_sentences = []
for index, row in data.iterrows():
    ori_poem = row['original_poem']
    key = row['keywords_ori']
    sentence_dict = generate_sentence_dict(ori_poem)
    word_dict = generate_word_dict(sentence_dict)
    key_sentences.append(get_key_sentence(key, word_dict, sentence_dict))
end = time.time()
end-start
# Out:
# 0.3419203758239746

# %%
len(key_sentences)
# Out:
# 1010

# %%
key_sentences
# Out:
# [{'ми надто довго жили, покладаючись на інших -',
#   'не вистачить сіл і містечок, щоб кожна хата скраю,',
#   'я не хочу, щоб ми довіку ходили такими глухими шляхами,',
#   'як по хусточку для патріотичних сліз і соплів, не втікаючи у тужливу пісню.'},
#  {'лісистим хребтом.', 'ми вистоїмо.', 'пообіцяти.', 'пустимо качу – хай їм'},
#  {'Кто же будет продолжать за них?',
#   'Пронесла пехота молчаливо',
#   'Я хочу, чтоб мыслящее тело'},
#  {'Неужели им всем есть о чем подумать и что скрывать?',
#   'Подсыхает кусочек торта, оставленный для меня.'},
#  {'Але наступний рік почнеться з четверга...',
#   'Чи буде він прямим, як кочерга? '},
#  {'А піду блю....', 'На сніданок не піду, '},
#  {'І собака сказав: насправді ти не обираєш',
#   'У найпершу ніч льодоставу до тебе прибився,',
#   'вдихаєш – і видихаєш, доки в світі є місце на видих.',
#   'вийде один і дивиться, напівопустивши повіки,'},
#  {'знову порожній двір ренесансовий з баштою',
#   'й хоче дзвонити з мого чужого тут телефона,',
#   'та насправді все вічне',
#   'і не зміг розібрати колір очей напевно,'},
#  {'Та трохи краще, ніж сидіти в копанці...'},
#  {'За тиждень цих суцільних вихідних ', 'Ми встигнемо втомитися від них!..'},
#  {'jest szczęśliwszy w życiu, rozdaje światu wszystko',
#   'z łyżeczki do herbaty wyprofilować maszt,',
#   'що можна роздивитися веснянки на шкірі;'},
#  {'І сенсу в них не знайдеш ти в момент. ',
#   'Рядки мої важкі та кострубаті, ',
#   'Так, я служив. Між іншим - у стройбаті. ',
#   'Який же я у біса декадент?'},
#  {'Здесь разговоры',
#   'На нас глядят',
#   'От солнца щурясь',
#   'С предсмертными улыбками'},
#  {'często psychiatrzy w szpitalu plączą druty,',
#   'jest oskarżony przez hotelową sprzątaczkę',
#   'jest pozwany przed sąd biskupi za cudzołóstwo;',
#   'ніж озлоблення розкривається в кишені.',
#   'і психіатри в лікарні нерідко плутають дроти,'},
#  {'Jako rekonwalescent ledwie poruszam palcami lewej stopy,',
#   'ale wzrok mam dobry i razem z jaskółkami krzyczę',
#   'głośno o tym, co widziałem.',
#   'один із дванадцяти немічних місяців.',
#   'у березні – в облямівку плаща Венери,'},
#  {'І встає моя країна ', 'Новорічна пісня рине '},
#  {'обпалений і міцний.'},
#  {'в небеса посмотри,',
#   'возвещаем всем,',
#   'игрушки на елке пора развесить,',
#   'снизошла благодать,'},
#  {'Как подумаешь - жалкий, пустынный клочок,',
#   'детвора хорошеет собою.',
#   'небывалые пышные всходы.'},
#  {'В нього форми бездоганні, ',
#   'До закоханих дівчат, ',
#   'Як у гречеських скульптур,'},
#  {'Святвечір мене зустрічає в дорозі.',
#   'Спогад про тебе згасити не в змозі.',
#   'як вікопомну звізду не забуду.'},
#  {'Волхвы иным путем возвратятся в страну свою.',
#   'Иосиф вернется к старинному плотницкому ремеслу.',
#   'Харчевни откроют двери страннику и пришлецу.'},
#  {'Й ми здолаємо шлях!',
#   'Не обдурить нас Ірод - ',
#   'Швидше трафить го шляк. '},
#  {'Ти в цей час прокидаєшся й виходиш із дому,',
#   'зважую все, залишаю, але не зважаю.',
#   'лише збирати підлітків при небезпеці',
#   'розтинає зсередини вологі волокна світу,',
#   'узбережжя в цей час слідкує за твоєю ходою.'},
#  {'в пучці шерсті верблюжій діоптрій звізди',
#   'світло бризнуло їм молоком верблюдиць',
#   'хоч з верблюжої шерсті одежа на них',
#   'і розсунуті межі і срібло води'},
#  {'Тут мене ловили вітрини, брами. ',
#   'бо насправді нема яскині, нині ',
#   'пастушків, ягнят, як і всі предмети, — '},
#  {'Чи інше божество, що зветься "Руб Бумажний"...',
#   'Щось замілка колядників ріка, '},
#  {'Різдво на мокрій сторінці підручника історії:',
#   'й попереду щось тьмяніє –',
#   'на туман прилипають,',
#   'хоч якимись прикрасами'},
#  {'в якомусь моєму чистилищі',
#   'наливається зерно бурштину,',
#   'ніби лампа, ненадовго увімкнена',
#   'роздивляючись власну долоню,',
#   'як перевіряють, чи вимкнули праску,'},
#  {'Коротка пісня про любов і довіру, про довіру без любові і любов без довіри',
#   'Люба моя, спали вишиванки мої,',
#   'Про цілунки забудь і про форму моїх геніталій.'},
#  {'В майбутнє оцю вину?!',
#   'Велика і вітчизняна.',
#   'Змивай новорічне похмілля.',
#   'Що скажеш ти синові, доньці, '},
#  {'Чеше Гепа гепу Допі,'},
#  {'з-під якого ми зростимо',
#   'це чужа нескінченність, якої тобі не пізнати.',
#   'і число, що вколисує жінку,'},
#  {'А навколо цвіли куртизанки, і гейші, й монашки, ',
#   'Але я ще надовго її розтягну - ',
#   'Телефон і мені задзвонить...',
#   'Як не в друзів, то в кого ж цупить віршів обрубки?! '},
#  {'бо він уже не повернеться навіть коли захоче ',
#   'коли останнє ім’я видихуєш разом з повітрям',
#   'плач повоєнна європо хай будуть тобі мов закид ',
#   'імміґрант зонг '},
#  {'Всё, что угодно...', 'Не может быть.'},
#  {'І попереду довга зима!',
#   'А у нас в Ірпені - перший сніг! ',
#   'Я ж бо втримати радість не зміг, '},
#  {'Кожне коліно зламане, в кожному угніздилася',
#   'Опік – пароль, впізнавання своїх, що вийшли.',
#   'Тиждень за півжиття, дай напитися, Єреміє.',
#   'загубившись безвісти, повертаються.',
#   'нервом сіпнеться світла '},
#  {'Он, кто армянское небо назвал близоруким,',
#   'и при стуке в дверь впадал в беспробудный ступор,',
#   'кого телячий вагон вез к могиле дальневосточной,',
#   'с бледным шрифтом, каждое слово запоминая, '},
#  {'з історії територій на яких нам бути',
#   'поділені на автохтонів і на меншини',
#   'розташовані посторінково попарно',
#   'упізнавати знаки вогню і диму',
#   'і на щасливі й рідкісні екземпляри'},
#  {'Но никто не торопится.',
#   'Тогда она думает о новом замужестве.',
#   'Это затрудняет поиск.',
#   'она чувствует себя одинокой.'},
#  {'Душе навстречу плывет, не спеша,',
#   'и если не встретит ее душа,',
#   'над прорубью славу петь.',
#   'первозданная чернота,',
#   'плохо скроен, да крепко сшит.'},
#  {'в крестообразной проруби, с трехцветным флагом в руке,',
#   'кто верит в то, что народ благодать обрел,',
#   'летать по небу на легких истребителях типа МИГ,',
#   'скакать по степи на конях с огнем в глазах и ноздрях,'},
#  {'в крестообразной проруби, с трехцветным флагом в руке,',
#   'кто верит в то, что народ благодать обрел,',
#   'летать по небу на легких истребителях типа МИГ,',
#   'скакать по степи на конях с огнем в глазах и ноздрях,'},
#  {'Человек искал бесконечности. Наконец-то нашел, что искал.',
#   'если есть только детство, парк, по тропкам топочущие ежи,',
#   'и волшебные щуки - хватит на всех Емель,',
#   'или пустот, отраженных в обсерваториях, в тысячах страшных зеркал.',
#   'тем более - формы и частностей, вроде галактик или ближних планет,'},
#  {"Народна творчість. And a photo of a 1 Hrivnia note, with the following in Zhadan's handwriting: це влада посилюе/у мені любов/до холодноі зброі... С. ЖАДАН"},
#  {'бо ж я люблю словесні витребеньки:',
#   'дивами вабимося в давній альфабеті',
#   'чубатий космос густоземляний'},
#  {'Бо почули: "Вставай і йди". ',
#   "Ми на повні легені п'ємо",
#   'Стоїмо тепер тут - ми єврохохли, '},
#  {'І щиро вклоняюся їм до землі.',
#   'Сири і тюльпани, й поля коноплі.',
#   'Твоїх лібералів вітаю і ґеїв,'},
#  {'весна короткометражка',
#   'осень сороконожка',
#   'стишок:',
#   'то отхлынет',
#   'то подмерзнет'},
#  {'Кто не любит свободу, те обычно - плечом к плечу,',
#   'и спешат уголовнички по уголовным делам.',
#   'по закоулочкам и осколочки по углам, ',
#   'сам ставит решетку в доме своем на окно,'},
#  {'А раньше мы не глядели, все думали - обойдется,',
#   'На черной площади жечь черные автопокрышки.',
#   'ни за посулы хорошей жизни и легкой работы,',
#   'ни за чиновное кресло, ни за долю в неправом деле.',
#   'трется о ногу тирана, выгибает спину,'},
#  {'кожна з її речей,',
#   'фарба довкола очей,',
#   'її медичні картки,',
#   'її проїзні квитки,',
#   'її серцебиття,'},
#  {'всім убієнним пам’ять і слава',
#   'падає сніг в продірявлену рану',
#   'перепросивши себе і святих',
#   'снайпер стріляє січневого ранку',
#   'хай барабани вистукують марші'},
#  {'кожна з її речей,',
#   'фарба довкола очей,',
#   'її медичні картки,',
#   'її проїзні квитки,',
#   'її серцебиття,'},
#  {'І з здобутком, безмежно цінним,', 'Але, знаєш, тут кожен сяє: '},
#  {'двері відчиняються і зачиняються',
#   'то ми виходимо з хати',
#   'то ми приходимо до хати',
#   'і дивиться пташка крізь вікно в акваріум хати'},
#  {'відшматовує кисті рук',
#   'куля снайпера навідліг',
#   'куля снайпера як жива',
#   'та сплітаються сотні рук',
#   'шелест снігу як кожен сніг'},
#  {'Когда Учитель в молчании',
#   'Хуже тот, которого любят.',
#   'Хуже тот, перед кем трепещут.',
#   'недостоин доверия.'},
#  {'Крошатся, как лёд, исчезающий дымом под ними,',
#   'Не бельма, но всё же: незрячесть подобна войне.',
#   'Не більма, та все ж: ця незрячість подібна війні.',
#   'Приникая к безмолвию, пить изначальный холод.'},
#  {'але пітьми знавіснілої духи',
#   'в перламутровых буднях с песком на зубах',
#   'желеобразным мозгом зверя',
#   'жемчуг наш – средь пустыни',
#   'множится бесится злая порода'},
#  {'Навіть погуляти не вдалосі...', 'Нашому бідосі у Давосі '},
#  {'А после того, как благую весть',
#   'нам скажут - вас не стояло здесь.',
#   'таращась во все глаза,',
#   'услышат они с небес,'},
#  {'І сяброў, і ворагаў сваіх”.',
#   'І, дабраславіўшы Украіну,',
#   'Белы сьнег перабінтуе рану.',
#   'Гэта Бог, схіліўшыся ў жалобе,',
#   'Чорны дым сьмярдзіць кублом паганым,'},
#  {'нічними рибами розпливаються по всьому тілі стигмати',
#   'підваживши двері, вдягнувши справжні обличчя,',
#   'склепіння церковного, молитва пече тобі,',
#   'тебе обплітають міцними стеблами спогади:'},
#  {'І знову усебе повіриш.',
#   'Або цей вірш.',
#   'Спокійно візьми й повтори',
#   'У жменю збери й розітри '},
#  {'Все звери мира живут в рукавичке,',
#   'Все люди мира стремятся куда-то',
#   'Умею грызть ногти, а не грызть - не могу.',
#   'мальчик не злой, но безумный чуток.'},
#  {'Не перепишешь набело - все равно никто не прочтет.',
#   'Хороша биография - неразборчивый черновик.'},
#  {'Стою, сжимаю кулаки. озираюсь по сторонам.', 'выкрутился, значит.'},
#  {'Предпоследний куплет, несчастливый билет,',
#   'вот навстречу друг другу толпа и толпа',
#   'с подъяремной, тюремной тоской.',
#   'это смех и проклятия вслед.'},
#  {'Де ви дівчата',
#   'На багрянистім горизонті',
#   'О дорогі розквітлі губи',
#   'Та біля водограю'},
#  {'и верховодка, за которой ты охотишься, снизу тебя не видит,',
#   'ты ловишь рыбу – поджидаешь неосмотрительную верховодку,',
#   'ты сидишь и не шелохнёшься, и я сижу и не шелохнусь,',
#   'ты уже, слышу, возвращаешься,',
#   'чтобы мы, те, кто видит, как ты встряхиваешься, думали, '},
#  {'Бо зрада – ти добре це знаєш, ще глибша за рану,',
#   'Бо смерть у прицілі найкраще відстежує світлих.',
#   'В пітьмі й у пожежі, та, зрозуміло, без каски,',
#   'Стоїш за плечима в синів найдорожчих – незримо –',
#   'Якщо тебе хтось не впізнає, дай знак, що ти свій,'},
#  {'І як тобі не хочеться, на жаль, ',
#   'Він понесе тебе від нас у синю даль!..',
#   'Сідай, гарант, на синього коня, '},
#  {'І до підданих приїхав, ',
#   'І морозить, і трясе, ',
#   'Він з-під крапельниці встав,',
#   'Той додому поповзе!"',
#   'Хто не так проголосує - '},
#  {'І знаєш, тут вніманіє до мене не прикуто.',
#   'Ну, ладно, Батя, как всігда, зустрінемся в Гаазі.',
#   'Тут добре, Батя... Бачив я актьора в сєрєбрянці.',
#   'Хоть полномочій тут нема, зате багато прав. '},
#  {'Але зверніть увагу на останню строфу. "Киевский, от крови красный торт"...',
#   'Дурнуватий віршик, я знаю. Але все справджується. Європа пасивна, відчуття невідворотності чогось поганого і неспроможність змінити (відіграти) ситуацію назад. '},
#  {'будь-який асоціативний ряд закінчується твоєю піхвою:',
#   'врешті знайти шнур, навести лад у шафі, викинути все непотрібне',
#   'саме тепер, цієї миті, коли ти, засинаючи, скручуєшся калачиком.',
#   'у салоні автомобіля, от не забути б зарядити плеєр,'},
#  {'І знаєш, тут вніманіє до мене не прикуто.',
#   'Ну, ладно, Батя, как всігда, зустрінемся в Гаазі.',
#   'Тут добре, Батя... Бачив я актьора в сєрєбрянці.',
#   'Хоть полномочій тут нема, зате багато прав. '},
#  {'Усе молодшає,',
#   'дзвінким ножем,',
#   'жовті вірші на снігу.',
#   'коли на Всьому заростають шрами,'},
#  {'Боже, врятуй переможців.',
#   'вечір. зима. дві тисячі чотирнадцятий рік.',
#   'ви назавжди зрозумієте, й істина ця проста –',
#   'ви просто потиснете руки й розбіжитеся до дружин.',
#   'найсердешніші люди – серед нас.'},
#  {'В останній серії він конче наїбнецця.',
#   'Простіть і вибачте за нецензурщину. Я поет. Я так бачу. 🙂',
#   'У нас відомо кожній наволочі й тварі,',
#   'Якщо у першій перший борт – на флайтрадарі,'},
#  {'- А слухай, завтра де зустрінемось?',
#   'Бліда красуня, революціонерка,',
#   'В медпункті чи при спаленім автобусі,',
#   'розігнані до сотень Фаренгейт.'},
#  {'Питання: я знайшла гіпофіз спокуси; що з ним чинити?',
#   'незгірш від співу півня',
#   'ой, не хочеться гинути',
#   'передсвітанкової',
#   'своєї перламутровості.'},
#  {'- да', '- и не говорите', '- нет', 'минимализм:'},
#  {'Але і послуги їхні коштують дорожче.',
#   'Життя - це веселе перетягання линви.',
#   'З одного боку її тягнуть янголи.',
#   'З іншого - адвокати.'},
#  {'Теперь есть дядя Клюев – ни дня без поцелуев,',
#   'Я был когда-то странной титушкой безымянной,'},
#  {'І, даруйте за натуралізм, ', 'Демонструє свій метаболізм.'},
#  {'відмикає довгу, як гуцульська колядка,',
#   'і все те, що затримується на сітківці ока,',
#   'і все те, що помічаєш периферійним зором: щоразу гладші митники,',
#   'і хоч птахи і далі літають безперешкодно високо,'},
#  {'Если гибель внутри, крокодил от смерти не уползет!',
#   'Но в одном крокодил дает нам урок прямой.',
#   'Фекалии крокодила возвращают людскую красу.',
#   'а нижняя - неподвижна. Крокодил проглотить готов',
#   'твой собственный пот это смоет, и вновь обретаешь ты'},
#  {'І не дійде згоди дотепер', 'Вішає лапшу й мозги запудрює, '},
#  {'А ведь мы тоже – миллионноглазая майданная рать –',
#   'Громыхая миокардом, как громогласным молотом.',
#   'Подлецами бываем – лживыми и прижимистыми.',
#   'Сердце Януковича-матери пучеглазо бдит,',
#   'Тихо плачет за сыновьями, лишь на мгновенье уснув.'},
#  {'А матері розрадити не вміє.',
#   'Не пропустити ні кивка, ні мови —',
#   'Розмили балку березневі води.',
#   'Син п’є понуро, все те розуміє,'},
#  {'Арбузов зовсім охрінів - '},
#  {'И голос к тебе вернется. И ты закричишь. И тогда',
#   'Не смотреть на волка - значит - не склоняться ко злу.',
#   'заповеди, помогающие хищника побороть.'},
#  {'Немов тятива напинається,',
#   'Тут мав би бути довгий вірш, але наразі - одна строфа:'},
#  {'Коли відійде супостат', 'Ударами наших сердець, '},
#  {'Владыка, со спокойствием и миром.',
#   'Но ныне отпускаешь Ты раба,',
#   'Я не привязан к людям и вещам,',
#   'посередине Храма, рядом с Девой',
#   'сошлось в одном Младенце бессловесном.'},
#  {'За дальним всхолмием. Пустыня.',
#   'Чтоб чаек шум и голос Понта',
#   'Щоб крик чаїний, стогін моря'},
#  {'Есть составные, сложные, двоящиеся существа.',
#   'благочестивы смиренны, но - Господь сохрани -',
#   'конская, в ней конская похоть и конская страсть.'},
#  {'Ну, починаємо!',
#   'в момент оголошення',
#   'перевернуте обличчя',
#   'різдвяна ялинка-вбивця,',
#   'що таємниць'},
#  {'Я в Острозі. Тут вже весна!', 'Я зовсім не послав вас на... '},
#  {'акварелью и карандашами дети расцветят раскраску',
#   'была нарядная ёлка и карнавал новогодний',
#   'веселые добрые маски обитателей преисподней',
#   'чем ужасней история тем она неподсудней'},
#  {'Агнец Божий, понесший грехи мира,', 'дай нам мир.', 'помилуй нас.'},
#  {'А вмираючи – воскресаємо до життя вічного!',
#   'Але сам навчається в покірливості духу;',
#   'Даруй мені ласку відродити надію в тих, хто у відчаї,',
#   'Не улюбленим, але люблячим.'},
#  {'Возгласы, взрывы... Казалось еще вчера,',
#   'Главная заповедь доктора "не повреди" -',
#   'прижигание, кровопускание, небытие...'},
#  {'Деякі більше не зможуть, Європо, не гнівайся, навіть руки тобі дати, (хіба що протези!), навіть торкнутись культури твоєї минулих віків.',
#   'Ти їм вибач, Європо, ти їм не дивуйся, ми всі тут як звірі - нас відстрілюють, наче скажених, патронами для вовків.',
#   'Чисть частіше Ютюби, щоб тутешня жорстокість не разила твоїх громадян.',
#   'Що ти, Європо, робила тим часом - звіряла пропалих і мертвих? мила руки? чекала підтверджень? ховалась як річ-у-собі?',
#   'прислухайся, на всякий пожежний, чи ми кричимо ще від ударів прикладів, армійських чобіт і кийків. Діти наші виростуть злими, Європо, не йнятимуть віри істеричним й слізливим новинам твоїм'},
#  {'А ми милуємось, як Ганна Герман-Стеців',
#   'Весь світ милується змаганнями атлетів,',
#   'Стрибками лижників, хокеєм, грою в керлінґ.'},
#  {'А кому молитву, молитву, остави наши долги?',
#   'А кому очки, очки, сквозь них не видать ни черта,',
#   'а кому жизни, жизни, смотри, останешься без.',
#   'хорошие, острые зубы, чтоб язык за ними держать?'},
#  {'враг торжествует',
#   'и непобедимы',
#   'насилие в Киеве',
#   'но он увлекается',
#   'хаосом'},
#  {'Але смерть мене не зупинила. ',
#   'Лиш не зупиняйтесь, вставайте, боріться,',
#   'Режим стріляє в потилиці й спини,',
#   'Цвітуть на Майдані смерті тюльпани,'},
#  {'наша же совесть у нас подаяния просит',
#   'но не будет теплой полной младенческой ложки',
#   'похоронят торжественно здесь на днепровских склонах',
#   'радуйтесь те кто выживет время раздела дележки'},
#  {'Гремят вагоны подземки в бесконечной норе.',
#   'Он будет пророчествовать обломкам, фрагментам, золе,',
#   'что праведник замер в добре, как муравей в янтаре...'},
#  {'Кто бы ни наступал, не поворачивайся спиной.',
#   'пришивают оторванные пуговицы от руки.',
#   'что их массово шьют, и на всех хватит портних - эти латают дыры, сшивают шейные позвонки,'},
#  {'А вот перевод из Василя Махно (оригинал ниже в ленте)наша муза – теперь медсестра',
#   'двухсотлетний Шевченко',
#   'и студент неподвижен лежит',
#   'на небесной постели',
#   'придержи медицинский зажим'},
#  {'а Бог питає ', 'живі поснулі', 'туди де вогонь і дим', 'і на майдані'},
#  {'в цій смертельній годині',
#   'вже в небесній перині',
#   'двохсотлітній Шевченко',
#   'на майданівських зимних вітрах',
#   'нині муза – оця медсестра'},
#  {'двухсотлетний Шевченко',
#   'кто-то высверкнул чем-то',
#   'на небесной перине',
#   'нынче муза - вон та медсестра',
#   'хоть чуть-чуть в медицине'},
#  {'Только вспомнятся выстрелы, взрывы, костры в ночи,',
#   'Ученик у доски не вспомнит ни дат, ни имен,',
#   'крики "слава!", тела убитых - страшно смотреть.'},
#  {'Это мое стихотворение 2007 года - их самых любимых Сегодня оно приобретает дополнительное звучание (или - значение).',
#   'Я был елдак, торчащий из выпуклости земной.',
#   'гремит на порогах, охватывает острова,'},
#  {'в кровавых расчесах белье',
#   'живьем незаметно для близких',
#   'приснилась небесная сотня',
#   'ты к спискам прокрался но в списках',
#   'ты спал неспокойно сегодня'},
#  {'- Мам... А тепер в нас буде хороший Янукович?',
#   '- Ні, ніяких януковичів нам більше не треба. Всі люди України порадяться, подумають і виберуть навесні разом нового президента.'},
#  {'він не повертався ', 'куди треба вітер дув ', 'та ще й посміхався.'},
#  {'В заключение - землетрясение, и руины смоет волна.',
#   'В океане город выгрузят на острова,',
#   'на прощание поцелуют, скажут ласковые слова,',
#   'наобещают с три короба, не сделают ни хрена.'},
#  {'Та все ж не настільки, Аби від крові сіпатись.',
#   'Я Батько також. Мій Син іграшкового'},
#  {'вийде вітер, і принесе вогонь, і удар навідліг,',
#   'виноградна, істинна поміж ребер Ісуса, ',
#   'королі кришталеві у коробках із ватою,',
#   'покладає долоню на продірявлене серце,',
#   'і в руках – закривавлені скіпетри та корони.'},
#  {'мов амплітуда яструба –',
#   'ось чому я люблю',
#   'та рішучого переможця.',
#   'тебе, нервова дівчино,'},
#  {'Світ на плястери покроївся ', 'Хтось насмішливо "куля в лоб". '},
#  {'вишептуючи і проговорюючи',
#   'громіздкі черепахи.',
#   'щоби не таким порожнім'},
#  {'О чем на Соборной площади напряженно гудит толпа? С неба под ноги сыпется ледяная крупа.',
#   'Что делает солнце за серой сплошной пеленой?',
#   'а мы отвечаем - Боже, терпеть уже нету сил.'},
#  {'І душа омивається небом, і п’є із нього.',
#   'І покликати просто, як кличуть дитину додому.',
#   'День і ніч -- у молитві. Відчувши живе тепло,',
#   'Немовлята у вірі, плачемо. Бог живий'},
#  {"Крешуть з них червоні блискавиці Революцій, бунтів і повстань. Україно! Ти для мене диво! І нехай пливе за роком рік, Буду, мамо горда і вродлива, З тебе дивуватися повік. Ради тебе перли в душі сію, Ради тебе мислю і творю — Хай мовчать Америки й Росії, Коли я з тобою говорю! Одійдіте, недруги лукаві! Друзі, зачекайте на путі! Маю я святе синівське право З матір'ю побуть на самоті. Рідко, нене, згадую про тебе, Дні занадто куці та малі, Ще не всі чорти втекли на небо, Ходить їх до біса по землі. Бачиш: з ними щогодини б'юся, Чуєш — битви споконвічний грюк! Як же я без друзів обійдуся, Без лобів їх, без очей і рук? Україно, ти моя молитва, Ти моя розлука вікова… Гримотить над світом люта битва За твоє життя, твої права. Хай палають хмари бурякові, Хай сичать образи — все одно Я проллюся крапелькою крові На твоє священне знамено. 26.XII.1961 Василь Симоненко"},
#  {'З Чернівців, із чарівного міста', 'Це така повільна куля в лоб...'},
#  {'Усяка страва врешті приїдається. ', 'Чи куштував хто земляного зайця?'},
#  {'Встретил русалку и зажил с ней',
#   'Парень приехал в Ростов на Дону.',
#   'проще чем раньше, зато - честней.'},
#  {'Унесет он все ягоды благочестия в злую свою страну.',
#   'всем игольчатым телом, всей колючей спиной,',
#   'попускаешь в свой виноградник диавола, как ежа, а он и рад!'},
#  {'Як зчорніла ніч –',
#   'безневинну січ.',
#   'врізали вам поля,',
#   'всіх їх розстріляли,',
#   'з мертвих насміхали,'},
#  {'Поймаешь, но не удержишь - выскользнет власть из рук.'},
#  {'ангели більше не носять уніформи',
#   'мій розчерк втікає вулицею',
#   'як всередині мішків зі снігом',
#   'які мене витягають із-під куль'},
#  {'з хребта виповзає',
#   'чи навпаки зраділа закохалася?',
#   'чуєш – у глеку тихенько співає'},
#  {'Не насякаймось психозом. ', 'Онукові зробимо '},
#  {'Наша важка і болісна ', 'Неначе весняні проліски, '},
#  {'Гімн кримськотатарського народу (переклад Лілі Буджурової):',
#   'Если ж я, поклявшись светом — и не вспыхну, не сгорю, ',
#   'Реки слёз пусть станут морем, превратившись в кровь мою.',
#   'Что мне жизнь… ведь будь я ханом, проживи хоть тыщу лет, ',
#   'Я поклялся, я дал слово за народ свой умереть! '},
#  {'Вставай на смертный бой',
#   'Вставай, страна огромная,',
#   'С проклятою ордой.',
#   'С российской силой тёмною,'},
#  {'Только вот идет ей хилый монашек навстречу - что ты',
#   'в крынку - скок, сметанку выел, распух, хочет вылезти - а никак.',
#   'вся скукожилась, нет ли страха, или какой заботы,',
#   'и, учуяв мрак, увязался дорогой за ней нечистый,',
#   'яко воск от лица огня, и мрак навсегда оставил'},
#  {'В поштовхах полум’я',
#   'Все продумано.',
#   'Жерстяна коробка з-під солодощів',
#   'Не вистрілили,',
#   'Не довечеряли.'},
#  {'Да, вовремя я вышел из запоя...',
#   'Да, впрочем, видит Бог, невелика потеря',
#   'Но ТАСС уполномочен заявить:'},
#  {'В цинковых гробиках ждёт своих ребят.'},
#  {'Вижу речку Амазонку, крокодилов вижу я...',
#   'Где бы я ни ехал в танке, всюду мой любимый край!'},
#  {'І коли роздирає ніч на бинти свою',
#   'А вона навчатиме піврозквітле дівча,',
#   'відчувати найгарячіше поміж співочих сердець;',
#   'свого батька та брата не зустрічати ніде.',
#   'світлу шкіру, а страх задушливо непідробний,'},
#  {'Квітень і серпень. Квітень і серпень. ',
#   'У серпні дозріють яблука. Саме в серпні.',
#   'Хотіла сказати ще зранку, але забула.'},
#  {'1.Радикал за радикала. ', '2.Радикал заради кала.'},
#  {'влитися у Дніпро – ув оборонну ріку',
#   'дощ нас усіх накриє і снігопад',
#   'кожен може тримати в руках автомат',
#   'що прикриває небо – землю в якій росте'},
#  {'Націонал-ліберальна партія сирійців ',
#   'Отримав повідомлення від нашого сирійського побратима на Eurolution.doc Ukraine on Maidan.',
#   'три глави банди, три міжнародних терористи, три демони ..відправляйтеся в пекло..'},
#  {'Я вырос в надгробном мире, над которым его рука',
#   'Я так ненавидел этого сухорукого старика,',
#   'незримо была простерта десятки лет.',
#   'плещет море, течет река, светит солнышко в небесах.',
#   'чтобы мог начаться мир надгробный, иной.'},
#  {'Их дядя Янукович к нам в гости пригласил.', 'Поэзия для детей'},
#  {'Волає розпечений мозок.'},
#  {'воинство твоей отчизны – летучий сад',
#   'каждое поколенье настигает своя война ',
#   'можно в Нью-Йорке жить – но повсюду ты',
#   'преисполнена света – но больше всего дерьма',
#   'сердце – единственный щит и бронежилет '},
#  {'2.Янукович не помер. ',
#   'Дві новини ранку, одна за одною: ',
#   'Я так і знав - він безсмертний.'},
#  {'На железном столе, под скальпелем и пинцетом,',
#   'Старость впадает в детство, а государство - в хаос.',
#   'чтобы проснуться и никогда не вспоминать об этом.'},
#  {'Муж подарил жене бриллиантово колье ',
#   'Пришел милицанер. Муж привлечен к суду.',
#   'пословице: подарки - не отдарки.',
#   'сиди, молчи, и огорчайся втайне.'},
#  {'І на гілці червоною квіткою розкривається Богоматір.',
#   'лабіринт і кардіограму, і я шепочу на вухо:',
#   'ми пустили коріння, нам боляче спопелятись.',
#   'хай стають наскрізними опіки, це краще, аніж не мати.'},
#  {'дощем прострочене',
#   'на трохи згорбленому',
#   'регулює автопробіг',
#   'це місто розлініяне в дощ',
#   'як поцілунок ворога'},
#  {'І виходять рішуче із ріки яничари,',
#   'лагумджі в підземеллях, тримайте списи, сипахи.',
#   'піднімайтеся, всі сеймени, топчу, делі,',
#   'розкришилися зуби, але загалом жива.'},
#  {'І на гілці червоною квіткою розкривається Богоматір.',
#   'по депо у більших; і коли кров’ю просякнуть',
#   'хай стають наскрізними опіки, це краще, аніж не мати.'},
#  {'не розсекретила звичку',
#   'покурюючи від рана',
#   'приглушеним голосом риби',
#   'шукати співзвучність рими'},
#  {'говорили эмульсия с примесью настоящего серебра',
#   'кто ловил сачком мотыльков в пионерском парке',
#   'нестроения демократии или угроза извне',
#   'нищий мир отснятый на трофейную фотопленку'},
#  {'Есть нечто в поступке жестоком,',
#   'И она огорчилась чрезмерно.',
#   'Не поздравил с Восьмым марта.'},
#  {'откуда у парня абхазская грусть',
#   'откуда у парня афганская грусть',
#   'откуда у парня ливийская грусть'},
#  {'Не подчиняюсь, "не корюся",',
#   'Но не люблю "брехню" и ложь,',
#   'ій Богу, зрозумій мене"'},
#  {'Присягаю діяти в інтересах своїх співвітчизників, співгромадян. ',
#   "Я, Маріанна Кіяновська, урочисто присягаю на вірність українському народові, робити все можливе для оборони України, для захисту її суверенітету, територіальної цілісності та недоторканності, сумлінно і чесно виконувати свій громадянський обов'язок, неухильно дотримуватися Конституції України та законів України, зберігати державну таємницю, . "},
#  {'"Ій Богу, зрозумій мене"',
#   'Не подчиняюсь, "не корюся",',
#   'Но не люблю "брехню" и ложь,'},
#  {'Сам по себе изо рта выдвинулся язык.',
#   'Сам по себе пищевод пробрался во мрак нутра.',
#   'мыслящий сей тростник.',
#   'обезьянку в кармашке несет.'},
#  {'Он был веселым, очень общительным человеком. В его доме собирались десятки людей. Иногда первый тост хозяин поднимал лично за Леонида Ильича Брежнева. Это означало: «Помалкивайте, среди нас стукач!». Он руководил архиерейским хором. Мне хотелось подарить ему дирижерскую палочку с надписью «И будешь пасти их жезлом железным».',
#   'Он же как-то говорил, что мать не советовала ему читать богословскую литературу, если он хочет сохранить веру.'},
#  {'Кто помнит детское ожидание ',
#   'Эти несколько мгновений, ',
#   'раската грома после вспышки молнии?'},
#  {'Вода выворачивала наизнанку деревья, выкорчевала пни.',
#   'И я видела, как разверзся огненный небосвод,',
#   'ливня и подглядывающим сатаной.'},
#  {'откуда у парня абхазская грусть',
#   'откуда у парня афганская грусть',
#   'откуда у парня ливийская грусть'},
#  {'І, неоплаканий своїми,', 'Чи хто згадає, чи забуде'},
#  {'Та щось такеє розмовляли.',
#   'є й такий Шевченко - людяний і чуйний, зболений і співчутливий, без пафосу, ярликів і перифразів: '},
#  {'Де залишали чарівну паличку увостаннє.',
#   'До стареньких фей у блакитному, що забули раптом ',
#   'Над жінками у вікнах, що вішають випрані штори,',
#   'Так зимова гума поспішає сухим асфальтом',
#   'Ще тільки зачинятимуться собори.'},
#  {'він врешті втік із цього міста',
#   'він йшов врочисто тихим містом',
#   'зітхнув поважно й непричетно',
#   'і в черешневій квітній піні'},
#  {'Типун тупому питону Путину.'},
#  {'Во поле стоит неподвижно несчетная рать.',
#   'Пугала или солдаты? сверху не разобрать.',
#   'Сколько злых голосов и навязчивых наваждений,',
#   'на голове у вороны просто для рифмы - корона.',
#   'сколько бреда вместится в птичьей одной голове.'},
#  {'в бомбосховищі, знаєте, діти, не вмикають опалення',
#   'за статтю, расою, віросповіданням',
#   'при вході до останнього бомбосховища?',
#   'слід спускатися в бомбосховище, уникаючи паніки,',
#   'які виноситимуть душі '},
#  {'Хтось грає на піаніно'},
#  {'Коль ты верховодишь огромной страной:',
#   'Признаться в пороке отнюдь не зазорно,',
#   'Смотрел я с Алиной немецкое порно'},
#  {'витоптуючи посіви збиваючи садовину',
#   'де насправді знаходиться зона бойових дій',
#   'старанно поливали придорожні кущі,',
#   'і в кожній краплі її дезинфікуючої слини',
#   'і ми слухали, як у горлі її перекочуються громи,'},
#  {'бісептол 480',
#   'коли не знаєш',
#   'навіть якщо це імунітет твоєї країни',
#   'ходьба покращує імунітет'},
#  {'...те, що зараз відчуваю',
#   'В тобі я втоплю свою весну.',
#   'Як би не було і як не боліла б твоя любов,'},
#  {'Коротка пісня, написана в японському жанрі хайку, в якій чомусь губиться контекст'},
#  {'варта твоїх розлук,',
#   'лише таємниці й дива,',
#   'хай безнадійно, хай,',
#   'це – ніч, це – течія,',
#   'шаленства та милосердь.'},
#  {'Козлиный, с нами заключить',
#   'Который должен исключить',
#   'Мечтавший развязать войну,'},
#  {'Шел казак в дремучий лес,', 'заблудился! Тут Россия', 'ухватила молодца.'},
#  {'Пантикапеи, Босфора. Тут в железную клетку',
#   'Утирает захватчица губы, поднимаясь с колен.',
#   'построенный генуэзцами в колокол бьет по утрам.'},
#  {'вночі. засвітла розбруньковується усе і до міста птахи вертаються: дроти',
#   'відсмикнуть завісу тіла й розкидають',
#   'живі огорожі повзуть у небо. офіціанти виносять столи',
#   'навіть земля під нігтями готова цвісти. і все-таки не',
#   'та бджоли виспівують лінолеум і килим вітру. повітря'},
#  {'Грешки людские ему сказали: Милости просим!',
#   'Поиграла с ним вволю, проглотила, не осквернилась,',
#   'в своих домах нечистого привечать.',
#   'ожившей варежке-кошке, облизывающей рот.',
#   'у окна, свернувшись, глядит во двор сквозь стекло.'},
#  {'В бочке пустой в Байкал',
#   'Введи к нам войска скорей',
#   'За амфорой проще нырять',
#   'всей мощью твоей руки.',
#   'и щуку легче удить.'},
#  {'В найтемнішому закутку мозку, де Крим і УПА',
#   'розминутись не можуть без бійки до першої крові, ',
#   'ти зірвешся, як тромб, щоб чимшвидше додому, додому,',
#   'чуюся геть безсилою і пригніченою від того, що ми не можемо захистити кримчан, які вважають себе громадянами України, від путінської агресії, чуюся відповідальною за те, що ми не можемо їх захистити в їхньому громадянському праві. '},
#  {'з якими вже можна обійтись без пояснень,',
#   'повернувся до мене обличчям, ',
#   'так і не впіймавши нічого.',
#   'і дивитись, як у тобі ненадовго гніздяться чайки,'},
#  {'С другими можно поспорить.',
#   'С некоторыми людьми можно согласиться.',
#   'С остальными лучше разойтись - земля просторна.',
#   'С третьими можно поговорить.'},
#  {'За нашу и вашу победу над нашей и вашей свободой.',
#   'За нашу и вашу свободу от нашей и вашей победы.'},
#  {'Не з днем ковбоя чи електрика -'},
#  {'І коли ми співаємо свої псалми,',
#   'Іноді підспівує.',
#   'Загадка виключно у волі творця.',
#   'він дивиться на нас із космічної пітьми.'},
#  {'На старих фотографіях біло-коричневі дні.',
#   'Темні води розлуки хлюпочуть своїм звичаєм',
#   'кілька правил поводження - заповідей добра.',
#   'лиш сплакнувши. Лишали нам, бо пора, ',
#   'посивілий мій вуйко, а поруч - наопаш - дід.'},
#  {'Как тромб, блуждающий в крови,', 'Певец неведомый и милый'},
#  {'Брать в руки автомат иль вовсе обнищать?',
#   'На паперти сидеть или идти в строю?',
#   'Никто не возвестит, что делать остальным.',
#   'Нисходит благодать на нищих и солдат.'},
#  {'И надпись на земле - не наступайте на',
#   'не вскипятить воды на газовой плите,',
#   'не выйти покурить на лестничную клеть,',
#   'предместья города, задымленные так,',
#   'спины не распрямить в привычной суете.'},
#  {'Конечно она написала ужасные стихи в честь покорения Крыма. Хотел было их процитировать, но... Юнна была прекрасным поэтом в годы моей молодости, одной из самых-самых. И решил я просто опубликовать ее раннее прекрасное стихотворение.',
#   'Потрошить плодоносное лоно, -'},
#  {'беспокойно ворочаясь, далеко за морем спят их родственники без сновидений',
#   'вот уже несколько часов нет никаких новостей в моем фейсбуке',
#   'те, кто замыслил недоброе, и те, кто будут этому противостоять',
#   'уснули диктаторы, законно выбранные и нелегитимные',
#   'уснули пограничники на железных кроватях'},
#  {'а ты вернешься поутру проснешься поутру ',
#   'и сердце сердце разожгут слова слова слова ',
#   'от счастья обладания тобой',
#   'тебе расскажут зеркала кривые зеркала '},
#  {'Если сверху смотреть - атоллы в виде подков',
#   'Иначе - закружится голова.',
#   'истребляющий кулака.',
#   'стриптизерша танцует у всех на виду.'},
#  {'Під приспущеним прапором регочуть сотні хрипких',
#   'хтось уперто вигукує позивний попелища.',
#   'імена залишених солоні й завжди найглибші.'},
#  {'між рядками шукаю непевну дорогу, незриму,',
#   'непосильну, як бабин колгоспний рядок буряка',
#   'хай святі твого вірша – твої архореї, твої хорі ямби'},
#  {'Раптом в темряві доторкаєшся срібла і відчуваєш – зустрінеш.',
#   'а півострів – найдраматичніша форма існування для суходолу,',
#   'знов себе впізнаватиме, уставши вранці голитися:',
#   'послідовне з’єднання і смертельна любов,'},
#  {'В поэзии не стоят ни гроша ',
#   'Поэзия не спорт, поэзия - душа! ',
#   'У Всесвітній день поезії, вже надвечір пригадалися вірші мого вчителя (керівника семінару в Літінституті), російського поета Анатолія Володимировича Жигуліна. '},
#  {'Де в повітрі вечірньому ходять менти,',
#   'Заважають прийнять анестезію.',
#   'Я не можу знаходить поезію, '},
#  {'Лучше быть прозрачным видением, вовлеченным в полет или бег,',
#   'в перспективе - старец, инвалид, дармоед,',
#   'двугорбым верблюдом, входящим в Ноев ковчег,',
#   'молодым, безмозглым - даром, что поседел.',
#   'приведенных в движенье силой твоего воображенья,'},
#  {'Враг это пугало - гимнастерка надета на жердь.',
#   'Что русскому - смерть, немцу - погибель вдвойне.',
#   'что вождь усатый - отец, а не черт рябой,',
#   'что смело идет в атаку бешеный рядовой.'},
#  {'Я підвівся – ударити в дзвони. Та плід був червивий',
#   'пожер обвуглілий сірник.',
#   'що з чорних голів умирущих стягував шкіру зотлілу,'},
#  {'А кого треба - вони не бомблять. ',
#   'Кого не треба - вони бомбили. ',
#   'Риму придумайте, дітки, самі.'},
#  {'Подумав оце, що коли в Росії відімкнуть інтернет і посіють усюди духовність, у який спосіб деякі люди будуть задовольняти свої еротичні потреби?',
#   'Хоть по-прежнему очень хочется.'},
#  {'Уезжаю, мама, в ссылку,',
#   'Я ще в листопаді 2013 року, не знаючи про видачу у Криму російських паспортів із магаданською пропискою у березні 2014, написав віршик.'},
#  {'В місіонерській позі.',
#   'Мене водило в безвісті життя,',
#   'Та раптом на второваній дорозі '},
#  {'В сохранение тела вложен немалый труд:',
#   'восполняют выпады воском, накладывают грим.',
#   'объявивший себя бессмертным,'},
#  {'многоцветному петуху, воду вливает — “Пей,',
#   'чудовищных сцен насилия. Крыльями бьют у стены'},
#  {'бо не все підпорядковане розкладу',
#   'бо рідко хто може вистояти в цьому протистоянні,',
#   'здається, зацвітає? ',
#   'ті, що живуть у пам”яті, носять маленькі дзвіночки',
#   'у ночвах ночі полощеться білий прапор цвіту,'},
#  {'А я – простой бандеровец холёный,',
#   'В орнитологьи знаете вы толк.',
#   'Мне не товарищ вы, позорный волк.'},
#  {'Когда-то я слышал без слухового - как его - аппарата,',
#   'Ох, прижал бы тебя я, Пуська, к постинфарктному сердцу,',
#   'Я нанес ей сотню неисцелимых душевных ран.',
#   'глаза мои были зорки, а зубы - крепки и остры.'},
#  {'Можливо, вона взагалі не вирізняє його.',
#   'Не зрозуміло, що вас тримає, окрім страху',
#   'Смерть не міняє звичок і вподобань.',
#   'можна сказати, що у всьому винен насправді ти,',
#   'невідомо чому, незрозуміло нащо.'},
#  {'Прошло тридцать лет, но я помню шершавый',
#   'звенит фольга золотая.',
#   'неба корыто накрыто.'},
#  {'Выход один - подождать тысячелетия три,',
#   'Пока воевали снаружи, все рухнуло изнутри,',
#   'Рубикон превратился в пересыхающий ручеек.'},
#  {'Мальчик. владелец трехколесного велосипеда,',
#   'всего, что содержит идею вращающегося колеса.'},
#  {"Пам'ятаєте ці рядки? А тепер розумієте, наскільки вони точні у своєму пророцтві?",
#   'Русь летит на крылатом коне в тьмутаракань своей исторической изоляции – к берестяным грамотам, опричнине, пареной репе, лучине, лаптям, тюре (молочка-то нет), жизни без картошки и конфет "Рошен". Но с ядерным оружием.'},
#  set(),
#  {'беззащитной украинской паствой',
#   'потому что он окружен',
#   'почему кричит',
#   'почему молчит патриарх',
#   'предстоятель украинской церкви'},
#  {'з осінніми вогкими поцілунками',
#   'кров’ю фарбованими',
#   'обплутують очі та шлунки',
#   'революція оживає в бензині',
#   'і капілярів водорості'},
#  {'а ті що кожен з нас розпізнає відразу',
#   'в потоках мерехтінь усе здається білим',
#   'що є одним з відлунь і більше не щемить',
#   'і довшає як тінь і загусає вмить',
#   'і я плачу ціну свого спасіння тілом'},
#  {'богдане! сольчанику!',
#   'ключ Божий богдан сольчаник',
#   'майбутнє цілком відчиниться',
#   'одним з милосердь учиниться',
#   'і навіть мале й піщане'},
#  {'Є знаком перетворення в безодні.',
#   'А небо - все весняніше і вище.',
#   'Не відболіло - часу не було.'},
#  {'а в цитате мандельштам',
#   'грубиянцам аз воздам',
#   'из ниоткуда в никуда',
#   'иностранцам шляпы съем'},
#  {'беззащитной украинской паствой',
#   'потому что он окружен',
#   'почему кричит',
#   'почему молчит патриарх',
#   'предстоятель украинской церкви'},
#  {'а сусідські дівчата виносили повні кишені насіння',
#   'у якому вирощували огірки і троянди',
#   'хоче щось розповісти ',
#   'і ми щойно поснідали тими самими вишнями що і в двотисячному'},
#  {'Мого вірша не достойна –', 'П’ю свій келишок до дна...'},
#  {'Любят настолько, что просто не представляют себе,',
#   'Поэтому остается одно - любить и верить.',
#   'потому, что они любят изнасилованную им страну.',
#   'что она может быть кем-то изнасилована.'},
#  {'божеволіють конають',
#   "все гімно до 'дної ями",
#   'трішечки підредагував-осучаснив радянського класика:'},
#  {'в небі намалював ',
#   'ластівку і шуліку',
#   'найсумніше відкриття:',
#   'що не розрізняю, де з них хто'},
#  {'Деякі принци існують задля смертей у вигнанні,',
#   'Мружишся проти сонця, ось твій нагрітий камінь,',
#   'коли дотискатиме їх, скажімо, люта подагра.',
#   'ніжно гладить коліно пазуриськами гострими.'},
#  {'а сміливці брели по зимній ріці',
#   'й відігрітись при кахлевій грубі',
#   'привезуть карамель медівник пластівці',
#   'я б мабуть здогадався: що краще тоді'},
#  {'Жгите, девочки, георгиевские ленты на Вечном огне.',
#   'И вы разойдетесь с обновленной и окрепшей',
#   'Мойте, девочки, плиты героев разорванным флагом УПА.',
#   'Пламя возгорится ярче. Плиты будут чище.',
#   'ненавистью друг к другу.'},
#  {'Как отныне здороваться с теми,', 'Отползает змея в камуфляже,'},
#  {'І це не жарт першоквітневий!'},
#  {'Говорять: всі, кого ти собі впіймаєш,',
#   'будеш ділитися з ними вином і водою.',
#   'до смерті будуть тепер іти за тобою.'},
#  {'з трясцями хворобами',
#   'стінгером гарматою',
#   'трьохсотими двохсотими ',
#   'і земля скловатою'},
#  {'И пиши по теплу некролог.',
#   'И, как будто просроченный вексель,',
#   'Мы в детстве были. много откровенней:',
#   'Промотал свое счастье, гляжу.'},
#  {'Не сумасшедшие вполне,',
#   'Но посвященные в юродство',
#   'О киевских мифах, речках и деревьях, о топонимике и географии, женственности и чувственности в городском пространстве - в программе Читаємо Київ.'},
#  {'а в руках у хвильового ',
#   'електричками поїздами',
#   'електрички поїзди',
#   'заіржавілих карасів та кразів '},
#  {'Шосте квітня, до того ж - неділя,'},
#  {'выше дома встает волна',
#   'где с балкона ревет страна',
#   'но я буду опять одна',
#   'ты конечно вопить сильна',
#   'ты напрасно орешь со дна'},
#  {'перейдеш мости і густі кущі',
#   'розпалювач воєн, викрадач слів',
#   'ти минеш пости і людські кістки',
#   'тої мішури',
#   'тут життя міцне як яйце'},
#  {"Сьогодні нас москаль іще не з'їсть. "},
#  {'У Києві шумить Книжковий Арсенал.'},
#  {'- Росіє! Ну будь ласка, '},
#  {'гаряча вода в холодній',
#   'посміхається',
#   'хочуть злетіти',
#   'це розкриті крильця зозульки',
#   'і твоє обличчя дужками'},
#  {'казали що час не наздожене',
#   'куди вона потече',
#   'сокотИти (гуцульське) - стерегти',
#   'чи буде у жмені той сніг нести'},
#  {'Этой ночью горячей земля до глубин трепещет!',
#   'в этот час пограничный, в мгновенья лихой тоски.',
#   'вас зустрінуть жінки і коханки в садах.',
#   'вспыхивай, падая, на юру!',
#   'повернувсь несподівано чорний сом.'},
#  {'Ти мене шмагала вербою. ', 'Я від церкви ішов за тобою. '},
#  {'Гряде невідворотно!',
#   'Ми всі чекаємо чудес,',
#   'Та, як це зрештою, природно, ',
#   'Три, кома, чотирнадцять, здець'},
#  {'коли ти цілуєш мене',
#   'прямо в твоєму роті',
#   'розбруньковуються сірники',
#   'та розквітають',
#   'у носі калюжі хлюпають'},
#  {'Тебе в майбутнє світле поведе!', 'Ще сорок днів тобі терпіти, ненько. '},
#  {'Але при цьому "Дніпро" - чемпіон!',
#   'Знає професор і пролетар, ',
#   'Той, хто їсть шаурму, й хто жує шампіньйон: '},
#  {'Його зосередженість, коли Він щось піднімає',
#   'басом, підносячи перстень високо і розглядаючи',
#   'посередині райського ластовиння. Перекривлюю'},
#  {'Долго что-то там искал. ', 'Старый мудрый аксакал '},
#  {'Зазвичай я з великою настрогою ставлюся до "актуальних", "злободенних" текстів і оприлюднювати їх не поспішаю - а найчастіше не оприлюднюю взагалі. Тепер ось знайшов цього вірша, перечитав - і подумав, що, певно, його все ж можна показати людям...',
#   'а борги тепер повертають ударом кийка між лопаток',
#   'кров змивається кров’ю – а далі око за око…'},
#  {'"НАТО випустить у море бойових дельфінів." '},
#  {'Але ми самі знаємо своїх ворогів.',
#   'Хай повернеться згодом, щоб врятувати',
#   'всі ті чорні місця, яких не розуміємо ми.',
#   'зранку стоять на зупинках, неприкаяні, як пірати –',
#   'коли ми самі поводимось, як вороги.'},
#  {'Мне хочется болтаться на колготках,',
#   'Но почему, когда мелькнут на фотках',
#   'Чем в девятнадцать или в двадцать два.',
#   'Я в сорок лет счастливее раз в сорок,'},
#  {'в шифері душі дахів вибухають',
#   'дети от сада крадутся с кусками',
#   'доски трухлявые рухлядь и ветошь',
#   'діти з-під саду крадуться з шматками',
#   'завтра ми шкоду на купу зберемо'},
#  {'І світло сонячне тобі навстріч.', 'Отак буває - відгорнеш фіранку, '},
#  {'Мирне хайку (наживо)', 'Притьмом в укриття,', 'покидавши сапи.'},
#  {'вилітають неприкаяні душі',
#   'ми сидимо та оминаємо ці теми',
#   'я нахиляюсь',
#   '– Боже, ти виварюєш душі'},
#  {'до останньої літери, останньої голосної.',
#   'потягнулися люди.',
#   'у віконницю, як у груди?',
#   'і торочиться, і торкається лоба,'},
#  {"Перев'яжи себе туго мотуззям,",
#   'аби не розлетітися.',
#   'розхитується, як маятник.',
#   'сонця бурштиновий токай.',
#   'текст із "Полювання", останніми днями переслідує.'},
#  {'Maria Galina, одна з чесних росіянок, чесних і мудрих. Мене давно так не проймав вірш, серйозно.',
#   'а после того, как благую весть',
#   'нам скажут — вас не стояло здесь.',
#   'таращась во все глаза,',
#   'услышат они с небес,'},
#  {'В царстве рыбацком речном.', 'Кто неподсуден кому?'},
#  {'Але що є іще поза цим нашим правом? Вірно, наша відповідальність. Присутність її, здавалося б, є настільки очевидною, що нагадувати про неї зайвий раз немає жодної потреби. Втім, потреба є. Що мене обурює більше за все? Коли хтось намагається внести корективи в мою – чітку й прозору, як мені видається – картину світу. Коли хтось заперечує мені в праві вважати свої переконання логічними й незаперечними. Сумніви – найгірше що може бути, особливо в дорослому віці, особливо у випадку, коли йдеться про речі, які довго й наполегливо вчився сприймати як беззаперечні. Справді, як можна заперечувати беззаперечне? – думаю я іноді. Відстоювати свою свободу, боротися за неї, трактувати її як найвищу цінність свого буття – здавалося б, що простіше. Сьогодні я розумію, що в більшості випадків всі саме подібними потребами та вимогами й керуються. Ніхто й ніколи, за жодних обставин і найтяжчих «посттоталітарних травм» не буде відмовлятися від своїх свобод. Навіть підтримуючи цензуру й виступаючи за жорстку ієрархічність, людина насправді намагається підтримувати своє уявлення про межі свободи. Себто, про межі, але все таки свободи. І це дуже важливий момент. Скажімо для нас, тих, хто живе в Україні, це справді важливо. Якщо спробувати говорити не так загально й перевести розмову в площину щоденної реальності – що відбувається сьогодні в нашій країні? Чому мешканці одних і тих самих міст не можуть поміж собою порозумітись? Чому політичні розбіжності виявляються такими фатально неподоланними? Особливо якщо припустити, що всіма нами справді рухають ті самі усвідомлені потреби й неусвідомлені інстинкти – потреба свободи, потреба справедливості, інстинкт самозбереження, врешті-решт. Адже він усе одно десь присутній – цей чортів інстинкт самозбереження? І потреба свободи – вона ж теж присутня, хіба не так? Вона присутня принаймні в риториці – незалежно від позиції, незалежно від того, з якого боку барикад у цій ситуації ти знаходишся, на чиєму боці в цій війні опинився. Потреба свободи так чи інакше керує всіма учасниками цієї війни на взаємознищення. Чим би вона не була інспірована: політичною пропагандою, релігійною агітацією чи соціальним антагонізмом – людей виводить на вулиці саме потреба свободи, як би широко й суб’єктивно вони її не трактували. Про необхідність свободи (чи, принаймні, про страх її втратити) говорять усі, говорять голосно й натхненно, себто, говорять, не слухаючи. Можливо, це теж один із виявів свободи – свобода як можливість проговорити, лишившись при цьому цілком не почутим. Так було взимку, в Києві, так, що на перший погляд парадоксально, відбувається сьогодні на Сході країни. Так буде й надалі – говорити, не слухаючи, діяти, не думаючи про наслідки, боронити свободу, беручи заручників.',
# ...
#  {'Вітаємо ми його як визволителя,',
#   'Тільки ми все одно розслабимось.',
#   'Швидко очима район обмальовуємо',
#   'він усміхається'},
#  {'Довгі подробиці — атрибут',
#   'Курс на життя зараз не дорожче',
#   'Наші дві долі малюю на попелі:',
#   'нафти і газу, та я молюсь.',
#   'часом і я наче з ніг валюсь.'},
#  {'але ти відхиляєшся',
#   'доторкнись',
#   'нібито не впізнаєш',
#   'те яке щомиті непереборно',
#   'і ти позбавлений сили відштовхуватися'},
#  {'Ни Рима, ни даже Варны - недостижимая цель,',
#   'гуляем, пьем, вспоминая ебену маму.',
#   'маячил бы пугалом коммунизм за углом,',
#   'раздвинуть прутья и втиснуться в узкую щель,'},
#  {'Ах если бы мама в детстве лечила нас рыбьим жиром!',
#   'в каждой супружеской спальне ночная камера пыток',
#   'и хворь бы нас не скрутила, и смерть бы не унесла.',
#   'молчуны отдают предпочтение пантомиме'},
#  {'Все ищет решение украинского вопроса.',
#   'И, между нами,- хороши ли гимнастки в его постели? ',
#   'Можно было б хоть что-то изменить и исправить.',
#   'Он не от обезьяны.- он гибрид удава и утконоса.'},
#  {'Мабуть, далеко надто сніг відкинув нас –',
#   'Ми заглядали в стовбури дерев, чиїх',
#   'свій нетутешній погляд. Із печальних вирв',
#   'що наздогнало нас нечутно, наче звір'},
#  {'І коли хтось із «медіаторів» зараз говоритиме мені про діалог, гуманізм та примирення - покажу фото з цих міст. Міст, які усіяні трупами моїх співвітчизників, вбитими руками росіян',
#   'Братська могила вбитих містян, розстріляні прямо на дорозі мирні мешканці із зав’язаними руками, зґвалтовані дівчата та жінки...',
#   'Ми воюємо із безчесними, брехливими та боягузливими істотами, які хочуть все і вся поглинути у своїй безпросвітній імперській темряві. ',
#   'Оніміння, пропалюючий біль і ненавість.'},
#  {'молитва и свет', 'обстрелы и бомбардировки', 'отовсюду', 'ты смотришь'},
#  {'Дивні вірші писалися минулоріч.',
#   'змушені дивитись одне одному в очі.',
#   'розколотий смарагд',
#   'срібні кинджали.',
#   'із родинної скриньки з коштовностями,'},
#  {'Взращенный евтушенковским вопросом,',
#   'Для меня это образец российского отношения к войне у людей с признаками совести. В конце концов назвала же она войну войной, а не спецоперацией....',
#   'И молча переглядываясь, нет –',
#   'Стихи на мой взгляд плохие. Но меня интересует не качество поэзии, а сюжет Блицкриг объявили. но фестиваль в Суздале не отменили. В происходящем абсолютно невинны. Войну мы объявили "чужим врагам и нашим малороссам".'},
#  {'ви не розумієте, що чините',
#   'зґвалтовані',
#   'по-батьківські звіщаєте',
#   'це яскравіше за світло',
#   'ієрархи'},
#  {'Вкрийте його тепліше,',
#   'велелюдною вулицею.',
#   'нагодуйте, приспіть.',
#   'розтерзаних нас. Тут і зараз. '},
#  {'але ніколи-ніколи не дістаюся дому',
#   'на таксі добираюсь',
#   'їду на велосипеді'},
#  {'Коло замкнеться, ',
#   'Недобудовані замки піщані.',
#   'та гучномовці зупинять його. '},
#  {'Просим тебя о находящихся в плену и оккупации, сохрани их от пыток, насилия, издевательств и отчаяния, освободи их. Сердца врагов наших смягчи к ним милосердием',
#   'Прости, Господи, нам и нашему народу бесчисленные наши грехи и беззакония. И как золото очищают от примесей в огне, так пусть и испытания этой войны будут нам в очищение, в возрождение веры в Тебя, избавление нашего общества от несправедливости, коррупции, разделений, неправды. И пусть милосердие, взаимовыручка, жертвенность, которые расцвели в наших людях в эти дни, цветут в нас и в мирное время. Пусть суета и беспечность мирного времени не заглушат добро в нас. Господи, пусть в нас победят человечность и великодушие',
#   'Расстрой военные планы врагов наших, их взаимодействие и снабжение, всели малодушие и нежелание воевать, побуждай складывать оружие. Не дай нашим врагам сотворить еще и экологические бедствия в нашей стране и сохрани и защити нас от возможного ядерного удара'},
#  {'громоздя пирамиды расстрелянной бронетехники',
#   'легионерами фашистского люфтваффе',
#   'о садистской бомбардировке Герники ',
#   'прилетают в фейсбук и ютуб'},
#  {'У молитвах своїх не проси зупинити війни,',
#   'не проси нездійсненного нам, а самий лиш мізер:',
#   'повертайся, промовимо їх, наче вирок ночі.'},
#  {'А на соснах – нитки розтріпані,',
#   'Незабуті і невідплакані',
#   'Піднебесні ткалі викохують',
#   'неможливою ваготою.'},
#  {'światełko moje', 'сьвятло маё', '我是你跳舞的', '我的阳光'},
#  {'.собирает друзей', 'вывожу', 'навстречу', 'я хочу'},
#  {'Рядом с муравьями', 'и любуемся боями!', 'не сможет их предать!'},
#  {'Але є і ті, кого, сподіваюся, підтримую і надихаю. ❤️',
#   'Нехай б‘є верба і проганяє нечисть. '},
#  {'беженства и оккупации',
#   'разорванным сердцем',
#   'с напрочь',
#   'с патологоанатомом',
#   'умерла в санатории'},
#  {'І входить дрож підступно і підшкірно.',
#   'І хоч ця ніч липуча як смола,',
#   'Коли на терезах людське життя – ',
#   'На чорне місто випав чорний сніг',
#   'і на повіках білих не розтанув.'},
#  {'Мав за честь перекласти вірш-лист солідарності з українцями, який написала шотландська поетка-лауреатка Kathleen Jamie. ',
#   'Ми поруч, коли ви цілуєте на прощання',
#   'ми любитимемо сусідів своїх як себе самих,',
#   'ми простягнемо руку, прихистимо серед лихоліття,'},
#  {'Ми вдивляємось в бік знерухомленої кінцівки,',
#   'Не у білих халатах — у формі з брудними літерами',
#   'кожен з нас відчуває у тілі фантомні болі.',
#   'тут країну зшивають голками крупнокаліберними.'},
#  {'лифостротон', 'невинноубиенные', 'новопреставленные', 'уничтожающее'},
#  {'А кров моя розквітла', 'У холодній ріллі '},
#  {'Господи заквітчаний трояндами ',
#   'босим по розпатраній землі ',
#   'за пелюстки краплі за шипи ',
#   'запахи людського і горілого ',
#   'поки цифри множаться у матриці '},
#  {'Він був волонтером в останній найгіршій війні.',
#   'Поміж світлом і тьмою міг здорово затягнутися. '},
#  {'* Минулорічний великодній текст. Наш Бог у камуфляжі. Христос воскрес!',
#   'Каже: коли йшов помирати, біснувались людці.',
#   'Я без пам’яті падала в придорожній пил, ',
#   'Як він наважився повернутися — це дивина.'},
#  {'Мама — людське втілення десяти заповідей,',
#   'Як не ударить блискавка?',
#   'роздирає горло нового дня брудними, ',
#   'суворий бог Старого заповіту.'},
#  {'Встала весна. Білим цвітом вишневим, травою,',
#   'Згарищем, димом, вогнем безперервного бою.',
#   'По Великодню умиті дощем цвинтарі,',
#   'Чорна весна. А вона ж білопінна, прекрасна.'},
#  {'бо чомусь коли ти народжуєшся в малому місті, ',
#   'внутрішньою васервагою, еластичним бинтом ',
#   'міняти вчасно лейкопластир на місці зрубаних гілок, ',
#   'ідеальне місцем для втечі'},
#  {'Квіти гордо відкриті до весняного сонця.',
#   'Серця розчавлене яблуко не тримається купи.'},
#  {'з покрученим гіллям чорним',
#   'закликатиме зміїними голосами: ',
#   'любов й милосердя її, безкорисність',
#   'і візьмеш, все, що зможеш'},
#  {'Люди повертаються до будинків,',
#   'Не знаєш,',
#   'Рівне, спокійне дихання часу.',
#   'візьмемо портрети ',
#   'чи вибіжиш із неї.'},
#  {'До укусів тебе цілуватиму,',
#   'обійматиму безкінечно,',
#   'розчинити її клятий запах',
#   'і розчуємо врешті весну,'},
#  {"Акторка Дар'я Творонович прочитала цей мій вірш, точніше — прожила його. Дякую, надзвичайно емоційно",
#   'Довгі подробиці — атрибут',
#   'Курс на життя зараз не дорожче'},
#  {'czy słyszysz świerszcze i cykady,',
#   'swoją wdzięczność za spokój naszych dzieci.',
#   'to nie mów o tym, jak uciekałaś od rakiet,',
#   'всіх, кого зустрінеш на чужині,',
#   'не розказуй, як бігла ти від ракет,'},
#  {'Через це ти, напевно, навідуєш з-за межі',
#   'голе тіло твоє височіє над пагорбом на хресті.',
#   'серед них найвиразніший голос — це голос твій.',
#   'і запитуєш пошепки, як воно — далі жить.'},
#  {'*новий вірш*',
#   'P.S. Волонтери тепер ведуть мій YouTube-канал, щоб допомогати країні на культурно-інформаційному фронті. Будемо вам дуже вдячні за підписку, вподобання та поширення відео звідти',
#   'Відділити би все поокремо',
#   "в різнотрав'я уткнешся лобом,"},
#  {'а роти наші повні цегляного пилу',
#   'бо нема соляного стовпа на який не озирнулися ',
#   'викрикують найтяжчі години. ',
#   'з барабанами і вродженими хворобами ',
#   'яка це скорботна втеча - '},
#  {'не слухай новин і сусідську пані,',
#   'одягнені всі у один прикид.',
#   'у мене все добре, харчуюся досхочу,',
#   'я завжди тверезий, мов чисте скельце,'},
#  {'Має вестись сівба опівнічного звуку,',
#   'Правдоподібно також, що позбавлені голосу, ми не стаємо ',
#   'Так, мовби відмовляємось від права співу в загальному хорі,',
#   'щоби їх відтепер завжди'},
#  {'божьему',
#   'пойду шататься по хуторам',
#   'прислоняться к каждому встречному',
#   'раскрошу тебя птичкам кошкам'},
#  {'А якщо ні, облиш мене, бездухий',
#   'Не шепочи слова зрадливої любові',
#   'Що з вуст летять незлічені рази'},
#  {'на аспида наступить',
#   'раптовим онуцтвом',
#   'якого любитимеш всім серцем своїм',
#   'і бачитимеш його в кутку хати твоєї ',
#   'і на брамах твоїх'},
#  {'висвітленим на вітрі.',
#   'де стискаються зуби понівеченого ландшафту,',
#   'з батьківської бібліотеки,',
#   'наче літери в конституції - засвідчують рівність народжених на кордонах,',
#   'цієї весни, таким зрозумілим, чітким, '},
#  {'Від бурята небось', 'Від кадирівця', 'Лежить у полі кусочок вушка'},
#  {"Із кров'ю, сльозами, у муках",
#   'У коментарях до тексту просили прочитати цей вірш, тож:',
#   'від зірки чи збитих снарядів.',
#   'плетуться волхви ланцюгом',
#   'у ранах, що спробуй загой.'},
#  {'За мить як піти в атаку, ми молимось про спасіння,',
#   'дивіться, як сміємося прямо в обличчя смерті.',
#   'контемпорарі в підвалах для тих, хто лихої вдачі.',
#   'читаєш це українською, значить ми бились гідно.'},
#  {'біжи щоб відтепер вас ніхто не здогнав',
#   'мій фізкультурник',
#   'міцнішим за помсту',
#   'на зрозумілому йому їдиші ',
#   'я вдячний своєму рятівникові'},
#  {'Тому що зустріч буде землетрусом,',
#   'кохали без дзвінків і без листів.',
#   'кохали так, що неможливо дужче,',
#   'якби тоді поглянув нам у душі.'},
#  {'ватка з кров’яною цяточкою',
#   'лікарняне обпісяне простирадло',
#   'обличчям занурений',
#   'сукня яка й досі паморочить запахом',
#   'урочисто пробитого цвяхом'},
#  {'в лютому двадцять другого року',
#   'два крихітні мішечки кісток',
#   'моя прабаба Рахіля згадувала',
#   'що старими синіми губами висмоктував'},
#  {'вона забирає всесвіт,',
#   'здавалось, із теплою досі простінню',
#   'потрібно зустріти інше',
#   'чи з чого там створюють нові всесвіти?',
#   'щасливі моменти, як кінострічку'},
#  {'Вперті равлики беззахисної Європи.',
#   'Ми потребуємо дива, потребуємо льодяників надії,',
#   'Насамперед віру в те, що ти сюди неодмінно повернешся.',
#   'Ось ця дорога – нині позначена безголоссям,',
#   'ви – позбавлені дому, проте не позбавлені серця.'},
#  {'Не жаліюсь, а прошу покірно: пошли нору',
#   'пару днів відпочинку – і знову приєднуй струм.',
#   'певно, краще тобі прислухатись до тих промов,'},
#  {'Сільські ландшафти не вселяли жалість.',
#   'а м‘язи на обличчі посміхались',
#   'такий-то рік, воююча країна.',
#   'тахікардично грюкала в дахи',
#   'якщо ти навіть знов мені напишеш.'},
#  {'втрачає свій масштаб, чим вище вдерся.',
#   'на ювелірно вирізьблені Альпи.',
#   'і вирізьбляла камінь з льодом до тих пір,'},
#  {'І це не вірші, хлопці, це не вірші,',
#   'Війна – найбільш невмілий архітектор,',
#   'врізатиметься хвилями в село',
#   'що має здібність тільки до руїн.'},
#  {'бесплатно и без',
#   'вспоминать ливанские и иорданские диалекты –',
#   'мусульманский рай переполнен, а наш',
#   'наше юлдашевское судно по реке Или –'},
#  {'и разрешает наконец себе заплакать',
#   'иначе замерзнете нажизнь',
#   'ледяной степной ветер проник в малоберцовые кости',
#   'назад это несколько часов до ближайшего города по разбитой дороге ',
#   'потом льдинки с кожей отрывать от лица'},
#  {'боже, я розгубилася, що тут кажуть з хреста знятим - ',
#   'закопаним поміж трьох сосен, залишеним в лісі людському:',
#   'любити тих, кого більше ні торкнутися, ні обійняти.',
#   'ми з тобою одної сльози, одної крові і плоті,'},
#  {'"ще й не встигнеш зогледітись, ось уже й ми"',
#   'де закроєно на..., розплановано до...',
#   'де сто тисяч цілунків, обіймів, зітхань,',
#   'із розкриленим поглядом, де не про біль, '},
#  {'I гавкiт вiвчарок на коже стрiл,',
#   'Земля -- як тельбухи. Ти замастишся.',
#   'на землю з повiтря тече тривога.',
#   'що ми вiдходимо ненадовго.'},
#  {'Звезды Вселенной вращались в толпе бестолковой,',
#   'Звезды в окошке светили неряшливо, как попало.',
#   'И жизнь была проще миниатюры средневековой,',
#   'И на них с укоризной Звезда иная смотрела, сияя.'},
#  {'вухаті зайці, смішні верблюди?',
#   'там, де незламності кігтеточка,',
#   'тягнучи свій караван застуди',
#   'і відчувають нарешті, що втома'},
#  {'варто згадати прізвище - ',
#   'поки ще не звинуватили, ',
#   'сховала попередній пост,',
#   'фанатизм - погана штука.',
#   'що піарюся :))'},
#  {'або збирались на літературні читання (бо що ще робити під час війни поетам!)',
#   'бо ніколи не ясно, які деталі найважливіші, а якими можна знехтувати',
#   'було потужне літературне середовище, ',
#   'внутрішньопереміщених і зовнішньонестабільних, '},
#  {'двозначність ситуацій омонімії, ',
#   'легкість твою, безпосередність,',
#   'посередність, геніальність ',
#   'у передфронтальній корі головного мозку,'},
#  {'Сковорода непійманий - ',
#   'невловимий Сковорода ',
#   'символів повний незрозумілих, ',
#   'та обхОдив мало світ невмолимий, '},
#  {'знаю, людина схильна помилятися,',
#   'зневірюватися, опиратися зневірі,',
#   'непокаране зло повертається злішим',
#   'твоє "не убий" малює нам на грудях мішені',
#   'якої проби? що ти хочеш вивести із нас, '},
#  {'коли робиш боляче й робишся іншим,',
#   'моє, моє, ти вицілюєш те, ',
#   'оббіловане тіло любові насправді не біле',
#   'чужим, ворожим, перевертнем, ',
#   'її логіку побудови фрази, '},
#  {'"Принаймні за одне не переживай, - заспокоюєш жартома, - якщо закінчиться місце для магнітиків, купимо більший холодильник."',
#   'коли все це закінчиться, виріс уже настільки, ',
#   'у холодильник із магнітиками, '},
#  {'а ти пропонуєш їх просто прибрати, щоб нічого ',
#   'від смерті, замаскованої гарним пейзажем',
#   'на якому тиждень пристрілювали зброю,',
#   'ніколи не знаєш, що насправді тягнеться за словом, '},
#  {'вийшла у двір посидіти на лавці,',
#   'ніби оцтова губка, щоб змочувати ',
#   'потріскані обвітрені губи, коли тому,',
#   'таке червонясто крикливе у цьому пейзажі -'},
#  {'вибачте, я не можу писати зараз інших віршів',
#   'душу підібрав',
#   'прихистку любов',
#   'хірургічний шов '},
#  {'- без повідомлень до останнього, де і коли вона відбудеться',
#   '- досвід організації велелюдної літературної події ',
#   'без розповсюдження інформації про подію, ',
#   'бо кінець світу треба зустрічати у вузькому сімейному колі',
#   'літературний менеджер від Бога'},
#  {'Гіацинт і Гвоздика, смертельна неначе гадюка',
#   'каса звуків і букв розлетілась від першого БУКа',
#   'перехресний, як рима, вогонь, охолонь, перестань. '},
#  {'впізнавай по позначках родимих',
#   'з жовтня через випалене літо',
#   'зблискують під мимолітним світлом,',
#   'перехресним. прикриває друга',
#   'погляд пробігає навпрошки '},
#  {'ввійди ж бо нарешті, ',
#   'двозначність ситуації ',
#   'за нерівним стукотом серця',
#   'та, переспівуючи мелодію всоте,',
#   'щоразу опиняєшся '},
#  {'а потім із нерозумінням ті, що призначені для полювання',
#   'вибираючи тепловізор чи прилад нічного бачення,',
#   'що змигне в тепловізорі, розгублене і непевне:',
#   'їх не беруть в розрахунок '},
#  {'війна дбає про наше майбутнє,',
#   'красиві тіла співрозмовників і співрозмовниць',
#   'назад - на знеболювальних',
#   'чулася такою надщербленою,'},
#  {'день такий непрожитий,',
#   'диво чеканки, цікавий такий артефакт',
#   'на сторінці, де дехто спіткнеться, ',
#   'на якому дощі висікатимуть',
#   'як нерозмінну монету'},
#  {'настовбурчиться безлисто',
#   'наїжачиться стернею,',
#   'от і злітувалось літо',
#   'повивітрюється, стерпне',
#   'скоро спекаємось спеки'},
#  {'висохлих, запалих, незнайомих',
#   'з одної клітинки - в іншу,',
#   'зрозумілої, яка починається ось тут',
#   'не знати, як повернутися додому ',
#   'це вийти на незнайомій зупинці,'},
#  {'жарівки груш підсвічують вночі ',
#   'намацуючи у твоїй кишені шпарку, ',
#   'останні метри серпня. крутять порно ',
#   'сюркочуть коники, хихочуть глядачі '},
#  ...]

# %%
len(data)
# Out:
# 1010

# %%
data = data.assign(key_sentences = key_sentences)
data.to_csv('key_sentence_ori_poems.csv')
