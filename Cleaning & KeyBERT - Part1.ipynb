# %%
# !pip3 install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu116

# %%
# !pip3 install git+https://github.com/huggingface/transformers

# %%
# !pip3 install googletrans

# %%
# !pip3 install openpyxl

# %%
# !pip3 install translate-api

# %%
# !pip3 install googletrans==4.0.0-rc1
#!pip3 install translators --upgrade --->doesn't work
# Out:
# Collecting googletrans==4.0.0-rc1
#   Downloading googletrans-4.0.0rc1.tar.gz (20 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting httpx==0.13.3
#   Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#      ---------------------------------------- 0.0/55.1 kB ? eta -:--:--
#      ---------------------------------------- 55.1/55.1 kB 2.8 MB/s eta 0:00:00
# Collecting hstspreload
#   Downloading hstspreload-2023.1.1-py3-none-any.whl (1.5 MB)
#      ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#      ------- -------------------------------- 0.3/1.5 MB 8.6 MB/s eta 0:00:01
#      ----------------------- ---------------- 0.9/1.5 MB 11.3 MB/s eta 0:00:01
#      ---------------------------------------  1.5/1.5 MB 14.0 MB/s eta 0:00:01
#      ---------------------------------------- 1.5/1.5 MB 12.3 MB/s eta 0:00:00
# Collecting idna==2.*
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ---------------------------------------- 0.0/58.8 kB ? eta -:--:--
#      ---------------------------------------- 58.8/58.8 kB 3.0 MB/s eta 0:00:00
# Collecting chardet==3.*
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#      ---------------------------------------- 0.0/133.4 kB ? eta -:--:--
#      ---------------------------------------- 133.4/133.4 kB ? eta 0:00:00
# Collecting rfc3986<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: certifi in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2022.12.7)
# Collecting httpcore==0.9.*
#   Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#      ---------------------------------------- 0.0/42.6 kB ? eta -:--:--
#      ---------------------------------------- 42.6/42.6 kB ? eta 0:00:00
# Requirement already satisfied: sniffio in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.3.0)
# Collecting h2==3.*
#   Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#      ---------------------------------------- 0.0/65.0 kB ? eta -:--:--
#      ---------------------------------------- 65.0/65.0 kB 3.7 MB/s eta 0:00:00
# Collecting h11<0.10,>=0.8
#   Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#      ---------------------------------------- 0.0/53.6 kB ? eta -:--:--
#      ---------------------------------------- 53.6/53.6 kB 2.9 MB/s eta 0:00:00
# Collecting hyperframe<6,>=5.2.0
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Collecting hpack<4,>=3.0
#   Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py): started
#   Building wheel for googletrans (setup.py): finished with status 'done'
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17461 sha256=f38b2db62cdf30121f2fa95f0915a4057fd8d695b9e1d150bd50f385b055d234
#   Stored in directory: c:\users\winfr\appdata\local\pip\cache\wheels\c0\59\9f\7372f0cf70160fe61b528532e1a7c8498c4becd6bcffb022de
# Successfully built googletrans
# Installing collected packages: rfc3986, hyperframe, hpack, h11, chardet, idna, hstspreload, h2, httpcore, httpx, googletrans
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
#     Uninstalling idna-3.4:
#       Successfully uninstalled idna-3.4
# Successfully installed chardet-3.0.4 googletrans-4.0.0rc1 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2023.1.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 idna-2.10 rfc3986-1.5.0

# %%
# !pip3 install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#      ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#      ---- ----------------------------------- 0.2/1.5 MB 4.6 MB/s eta 0:00:01
#      ---------------- ----------------------- 0.6/1.5 MB 6.4 MB/s eta 0:00:01
#      ---------------------------------------  1.5/1.5 MB 12.0 MB/s eta 0:00:01
#      ---------------------------------------- 1.5/1.5 MB 9.6 MB/s eta 0:00:00
# Requirement already satisfied: regex>=2021.8.3 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from nltk) (2022.10.31)
# Collecting click
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      ---------------------------------------- 0.0/96.6 kB ? eta -:--:--
#      ---------------------------------------- 96.6/96.6 kB 5.4 MB/s eta 0:00:00
# Collecting joblib
#   Using cached joblib-1.2.0-py3-none-any.whl (297 kB)
# Requirement already satisfied: tqdm in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from nltk) (4.64.1)
# Requirement already satisfied: colorama in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from click->nltk) (0.4.6)
# Installing collected packages: joblib, click, nltk
# Successfully installed click-8.1.3 joblib-1.2.0 nltk-3.8.1

# %%
# !pip3 install -U pip setuptools wheel
# !pip3 install -U spacy
# !python -m spacy download en_core_web_sm
# !python -m spacy download ru_core_news_sm
# !python -m spacy download uk_core_news_sm
# Out:
# Requirement already satisfied: pip in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (23.0.1)
# Requirement already satisfied: setuptools in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (63.2.0)
# Collecting setuptools
#   Using cached setuptools-67.4.0-py3-none-any.whl (1.1 MB)
# Collecting wheel
#   Using cached wheel-0.38.4-py3-none-any.whl (36 kB)
# Installing collected packages: wheel, setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 63.2.0
#     Uninstalling setuptools-63.2.0:
#       Successfully uninstalled setuptools-63.2.0
# Successfully installed setuptools-67.4.0 wheel-0.38.4
# Collecting spacy
#   Downloading spacy-3.5.0-cp310-cp310-win_amd64.whl (12.2 MB)
#      ---------------------------------------- 0.0/12.2 MB ? eta -:--:--
#       --------------------------------------- 0.2/12.2 MB 7.6 MB/s eta 0:00:02
#      - -------------------------------------- 0.5/12.2 MB 7.9 MB/s eta 0:00:02
#      -- ------------------------------------- 0.9/12.2 MB 7.8 MB/s eta 0:00:02
#      ---- ----------------------------------- 1.2/12.2 MB 7.9 MB/s eta 0:00:02
#      ---- ----------------------------------- 1.5/12.2 MB 7.3 MB/s eta 0:00:02
#      ------ --------------------------------- 1.9/12.2 MB 7.7 MB/s eta 0:00:02
#      -------- ------------------------------- 2.5/12.2 MB 8.3 MB/s eta 0:00:02
#      --------- ------------------------------ 3.0/12.2 MB 9.1 MB/s eta 0:00:02
#      ----------- ---------------------------- 3.5/12.2 MB 9.3 MB/s eta 0:00:01
#      ------------- -------------------------- 4.0/12.2 MB 9.9 MB/s eta 0:00:01
#      --------------- ------------------------ 4.7/12.2 MB 10.3 MB/s eta 0:00:01
#      ----------------- ---------------------- 5.3/12.2 MB 10.5 MB/s eta 0:00:01
#      ------------------- -------------------- 6.1/12.2 MB 11.1 MB/s eta 0:00:01
#      ---------------------- ----------------- 6.7/12.2 MB 11.7 MB/s eta 0:00:01
#      ------------------------- -------------- 7.6/12.2 MB 11.9 MB/s eta 0:00:01
#      ---------------------------- ----------- 8.7/12.2 MB 12.7 MB/s eta 0:00:01
#      ------------------------------- -------- 9.4/12.2 MB 13.1 MB/s eta 0:00:01
#      -------------------------------- ------ 10.2/12.2 MB 13.3 MB/s eta 0:00:01
#      ----------------------------------- --- 11.2/12.2 MB 14.9 MB/s eta 0:00:01
#      --------------------------------------  12.2/12.2 MB 16.8 MB/s eta 0:00:01
#      --------------------------------------  12.2/12.2 MB 16.8 MB/s eta 0:00:01
#      --------------------------------------- 12.2/12.2 MB 14.5 MB/s eta 0:00:00
# Collecting thinc<8.2.0,>=8.1.0
#   Downloading thinc-8.1.7-cp310-cp310-win_amd64.whl (1.3 MB)
#      ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#      ------------------------------ --------- 1.0/1.3 MB 20.7 MB/s eta 0:00:01
#      ---------------------------------------- 1.3/1.3 MB 16.2 MB/s eta 0:00:00
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      ---------------------------------------- 0.0/181.6 kB ? eta -:--:--
#      -------------------------------------- 181.6/181.6 kB 5.4 MB/s eta 0:00:00
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.9-cp310-cp310-win_amd64.whl (18 kB)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy) (2.28.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy) (4.64.1)
# Collecting pathy>=0.10.0
#   Downloading pathy-0.10.1-py3-none-any.whl (48 kB)
#      ---------------------------------------- 0.0/48.9 kB ? eta -:--:--
#      ---------------------------------------- 48.9/48.9 kB 2.4 MB/s eta 0:00:00
# Collecting spacy-legacy<3.1.0,>=3.0.11
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy) (1.24.2)
# Collecting smart-open<7.0.0,>=5.2.1
#   Downloading smart_open-6.3.0-py3-none-any.whl (56 kB)
#      ---------------------------------------- 0.0/56.8 kB ? eta -:--:--
#      ---------------------------------------- 56.8/56.8 kB 2.9 MB/s eta 0:00:00
# Collecting wasabi<1.2.0,>=0.9.1
#   Downloading wasabi-1.1.1-py3-none-any.whl (27 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.7-cp310-cp310-win_amd64.whl (29 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.8-cp310-cp310-win_amd64.whl (94 kB)
#      ---------------------------------------- 0.0/94.7 kB ? eta -:--:--
#      ---------------------------------------- 94.7/94.7 kB 5.3 MB/s eta 0:00:00
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.8-py3-none-any.whl (17 kB)
# Requirement already satisfied: setuptools in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy) (67.4.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy) (23.0)
# Collecting pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4
#   Downloading pydantic-1.10.5-cp310-cp310-win_amd64.whl (2.1 MB)
#      ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#      ------------------------------------ --- 1.9/2.1 MB 40.5 MB/s eta 0:00:01
#      ---------------------------------------- 2.1/2.1 MB 26.5 MB/s eta 0:00:00
# Collecting srsly<3.0.0,>=2.4.3
#   Downloading srsly-2.4.5-cp310-cp310-win_amd64.whl (479 kB)
#      ---------------------------------------- 0.0/479.4 kB ? eta -:--:--
#      ------------------------------------- 479.4/479.4 kB 29.3 MB/s eta 0:00:00
# Collecting typer<0.8.0,>=0.3.0
#   Downloading typer-0.7.0-py3-none-any.whl (38 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.4-py3-none-any.whl (11 kB)
# Requirement already satisfied: jinja2 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.1)
# Collecting confection<1.0.0,>=0.0.1
#   Downloading confection-0.0.4-py3-none-any.whl (32 kB)
# Collecting blis<0.8.0,>=0.7.8
#   Downloading blis-0.7.9-cp310-cp310-win_amd64.whl (7.0 MB)
#      ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#      ------- -------------------------------- 1.3/7.0 MB 41.6 MB/s eta 0:00:01
#      ------------- -------------------------- 2.4/7.0 MB 30.6 MB/s eta 0:00:01
#      ------------------- -------------------- 3.5/7.0 MB 27.5 MB/s eta 0:00:01
#      --------------------------- ------------ 4.8/7.0 MB 25.6 MB/s eta 0:00:01
#      -------------------------------------- - 6.8/7.0 MB 31.3 MB/s eta 0:00:01
#      ---------------------------------------  7.0/7.0 MB 29.9 MB/s eta 0:00:01
#      ---------------------------------------- 7.0/7.0 MB 26.5 MB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from jinja2->spacy) (2.1.2)
# Installing collected packages: cymem, wasabi, spacy-loggers, spacy-legacy, smart-open, pydantic, murmurhash, langcodes, catalogue, blis, typer, srsly, preshed, pathy, confection, thinc, spacy
# Successfully installed blis-0.7.9 catalogue-2.0.8 confection-0.0.4 cymem-2.0.7 langcodes-3.3.0 murmurhash-1.0.9 pathy-0.10.1 preshed-3.0.8 pydantic-1.10.5 smart-open-6.3.0 spacy-3.5.0 spacy-legacy-3.0.12 spacy-loggers-1.0.4 srsly-2.4.5 thinc-8.1.7 typer-0.7.0 wasabi-1.1.1
# Collecting en-core-web-sm==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.5.0/en_core_web_sm-3.5.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB 1.9 MB/s eta 0:00:07
#      --------------------------------------- 0.1/12.8 MB 975.2 kB/s eta 0:00:14
#      ---------------------------------------- 0.1/12.8 MB 1.0 MB/s eta 0:00:13
#       --------------------------------------- 0.2/12.8 MB 1.1 MB/s eta 0:00:12
#       --------------------------------------- 0.2/12.8 MB 1.1 MB/s eta 0:00:12
#       --------------------------------------- 0.3/12.8 MB 1.1 MB/s eta 0:00:12
#      - -------------------------------------- 0.4/12.8 MB 1.2 MB/s eta 0:00:11
#      - -------------------------------------- 0.5/12.8 MB 1.2 MB/s eta 0:00:11
#      - -------------------------------------- 0.6/12.8 MB 1.5 MB/s eta 0:00:09
#      -- ------------------------------------- 0.7/12.8 MB 1.6 MB/s eta 0:00:08
#      -- ------------------------------------- 0.9/12.8 MB 1.9 MB/s eta 0:00:07
#      --- ------------------------------------ 1.2/12.8 MB 2.2 MB/s eta 0:00:06
#      ---- ----------------------------------- 1.5/12.8 MB 2.6 MB/s eta 0:00:05
#      ----- ---------------------------------- 1.7/12.8 MB 2.7 MB/s eta 0:00:05
#      ------ --------------------------------- 2.0/12.8 MB 2.9 MB/s eta 0:00:04
#      ------- -------------------------------- 2.3/12.8 MB 3.2 MB/s eta 0:00:04
#      -------- ------------------------------- 2.6/12.8 MB 3.4 MB/s eta 0:00:04
#      --------- ------------------------------ 3.1/12.8 MB 3.7 MB/s eta 0:00:03
#      ---------- ----------------------------- 3.5/12.8 MB 4.0 MB/s eta 0:00:03
#      ------------ --------------------------- 4.0/12.8 MB 4.4 MB/s eta 0:00:02
#      -------------- ------------------------- 4.6/12.8 MB 4.8 MB/s eta 0:00:02
#      --------------- ------------------------ 5.1/12.8 MB 5.1 MB/s eta 0:00:02
#      ----------------- ---------------------- 5.6/12.8 MB 5.4 MB/s eta 0:00:02
#      ------------------- -------------------- 6.3/12.8 MB 5.8 MB/s eta 0:00:02
#      -------------------- ------------------- 6.6/12.8 MB 6.0 MB/s eta 0:00:02
#      ---------------------- ----------------- 7.3/12.8 MB 6.3 MB/s eta 0:00:01
#      ------------------------- -------------- 8.1/12.8 MB 6.7 MB/s eta 0:00:01
#      --------------------------- ------------ 8.7/12.8 MB 7.1 MB/s eta 0:00:01
#      ------------------------------ --------- 9.7/12.8 MB 7.5 MB/s eta 0:00:01
#      -------------------------------- ------ 10.7/12.8 MB 10.4 MB/s eta 0:00:01
#      ----------------------------------- --- 11.6/12.8 MB 12.4 MB/s eta 0:00:01
#      --------------------------------------  12.8/12.8 MB 14.9 MB/s eta 0:00:01
#      --------------------------------------  12.8/12.8 MB 14.9 MB/s eta 0:00:01
#      --------------------------------------- 12.8/12.8 MB 13.3 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (
5 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from ru-core-news-sm==3.5.0) (3.5.0)
# Collecting pymorphy3>=1.0.0
#   Downloading pymorphy3-1.2.0-py3-none-any.whl (55 kB)
#      ---------------------------------------- 0.0/55.4 kB ? eta -:--:--
#      ---------------------------- --------- 41.0/55.4 kB 991.0 kB/s eta 0:00:01
#      -------------------------------------- 55.4/55.4 kB 728.4 kB/s eta 0:00:00
# Collecting pymorphy3-dicts-ru
#   Downloading pymorphy3_dicts_ru-2.4.417150.4580142-py2.py3-none-any.whl (8.4 MB)
#      ---------------------------------------- 0.0/8.4 MB ? eta -:--:--
#      ---------------------------------------- 0.1/8.4 MB 1.9 MB/s eta 0:00:05
#       --------------------------------------- 0.1/8.4 MB 1.8 MB/s eta 0:00:05
#       --------------------------------------- 0.2/8.4 MB 1.8 MB/s eta 0:00:05
#      - -------------------------------------- 0.3/8.4 MB 1.7 MB/s eta 0:00:05
#      - -------------------------------------- 0.3/8.4 MB 1.7 MB/s eta 0:00:05
#      - -------------------------------------- 0.4/8.4 MB 1.7 MB/s eta 0:00:05
#      -- ------------------------------------- 0.5/8.4 MB 1.7 MB/s eta 0:00:05
#      -- ------------------------------------- 0.6/8.4 MB 1.7 MB/s eta 0:00:05
#      --- ------------------------------------ 0.7/8.4 MB 1.7 MB/s eta 0:00:05
#      --- ------------------------------------ 0.7/8.4 MB 1.7 MB/s eta 0:00:05
#      --- ------------------------------------ 0.8/8.4 MB 1.8 MB/s eta 0:00:05
#      ---- ----------------------------------- 0.9/8.4 MB 1.8 MB/s eta 0:00:05
#      ---- ----------------------------------- 1.0/8.4 MB 1.8 MB/s eta 0:00:05
#      ----- ---------------------------------- 1.1/8.4 MB 1.9 MB/s eta 0:00:04
#      ----- ---------------------------------- 1.2/8.4 MB 1.9 MB/s eta 0:00:04
#      ------ --------------------------------- 1.3/8.4 MB 1.9 MB/s eta 0:00:04
#      ------- -------------------------------- 1.5/8.4 MB 2.0 MB/s eta 0:00:04
#      ------- -------------------------------- 1.6/8.4 MB 2.0 MB/s eta 0:00:04
#      -------- ------------------------------- 1.7/8.4 MB 2.1 MB/s eta 0:00:04
#      -------- ------------------------------- 1.9/8.4 MB 2.1 MB/s eta 0:00:04
#      --------- ------------------------------ 2.0/8.4 MB 2.1 MB/s eta 0:00:04
#      --------- ------------------------------ 2.1/8.4 MB 2.2 MB/s eta 0:00:03
#      ---------- ----------------------------- 2.2/8.4 MB 2.2 MB/s eta 0:00:03
#      ----------- ---------------------------- 2.4/8.4 MB 2.2 MB/s eta 0:00:03
#      ----------- ---------------------------- 2.5/8.4 MB 2.3 MB/s eta 0:00:03
#      ------------ --------------------------- 2.6/8.4 MB 2.3 MB/s eta 0:00:03
#      ------------ --------------------------- 2.7/8.4 MB 2.2 MB/s eta 0:00:03
#      ------------- -------------------------- 2.8/8.4 MB 2.3 MB/s eta 0:00:03
#      ------------- -------------------------- 2.9/8.4 MB 2.3 MB/s eta 0:00:03
#      -------------- ------------------------- 3.0/8.4 MB 2.3 MB/s eta 0:00:03
#      --------------- ------------------------ 3.2/8.4 MB 2.3 MB/s eta 0:00:03
#      --------------- ------------------------ 3.3/8.4 MB 2.4 MB/s eta 0:00:03
#      ---------------- ----------------------- 3.5/8.4 MB 2.4 MB/s eta 0:00:03
#      ----------------- ---------------------- 3.6/8.4 MB 2.4 MB/s eta 0:00:03
#      ----------------- ---------------------- 3.7/8.4 MB 2.4 MB/s eta 0:00:02
#      ------------------ --------------------- 3.9/8.4 MB 2.5 MB/s eta 0:00:02
#      ------------------- -------------------- 4.1/8.4 MB 2.5 MB/s eta 0:00:02
#      ------------------- -------------------- 4.2/8.4 MB 2.5 MB/s eta 0:00:02
#      -------------------- ------------------- 4.4/8.4 MB 2.6 MB/s eta 0:00:02
#      --------------------- ------------------ 4.5/8.4 MB 2.6 MB/s eta 0:00:02
#      --------------------- ------------------ 4.6/8.4 MB 2.5 MB/s eta 0:00:02
#      ---------------------- ----------------- 4.8/8.4 MB 2.6 MB/s eta 0:00:02
#      ----------------------- ---------------- 5.0/8.4 MB 2.6 MB/s eta 0:00:02
#      ------------------------ --------------- 5.1/8.4 MB 2.6 MB/s eta 0:00:02
#      ------------------------- -------------- 5.3/8.4 MB 2.7 MB/s eta 0:00:02
#      -------------------------- ------------- 5.6/8.4 MB 2.7 MB/s eta 0:00:02
#      --------------------------- ------------ 5.7/8.4 MB 2.7 MB/s eta 0:00:01
#      --------------------------- ------------ 5.9/8.4 MB 2.8 MB/s eta 0:00:01
#      ---------------------------- ----------- 6.1/8.4 MB 2.8 MB/s eta 0:00:01
#      ----------------------------- ---------- 6.3/8.4 MB 2.8 MB/s eta 0:00:01
#      ------------------------------ --------- 6.4/8.4 MB 2.9 MB/s eta 0:00:01
#      ------------------------------- -------- 6.7/8.4 MB 2.9 MB/s eta 0:00:01
#      -------------------------------- ------- 6.9/8.4 MB 2.9 MB/s eta 0:00:01
#      --------------------------------- ------ 7.1/8.4 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------- ----- 7.3/8.4 MB 3.0 MB/s eta 0:00:01
#      ----------------------------------- ---- 7.5/8.4 MB 3.0 MB/s eta 0:00:01
#      ------------------------------------ --- 7.7/8.4 MB 3.1 MB/s eta 0:00:01
#      ------------------------------------- -- 8.0/8.4 MB 3.1 MB/s eta 0:00:01
#      -------------------------------------- - 8.1/8.4 MB 3.1 MB/s eta 0:00:01
#      ---------------------------------------  8.3/8.4 MB 3.1 MB/s eta 0:00:01
#      ---------------------------------------  8.4/8.4 MB 3.1 MB/s eta 0:00:01
#      ---------------------------------------  8.4/8.4 MB 3.1 MB/s eta 0:00:01
#      ---------------------------------------- 8.4/8.4 MB 3.1 MB/s eta 0:00:00
# Collecting docopt>=0.6
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting dawg-python>=0.7.1
#   Downloading DAWG_Python-0.7.2-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (3.0.8)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (1.0.9)
# Requirement already satisfied: setuptools in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (67.4.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (3.3.0)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (0.10.1)
# Requirement already satisfied: jinja2 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (3.1.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (4.64.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (8.1.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (3.0.12)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2.4.5)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (1.24.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (1.1.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2.28.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2.0.7)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (6.3.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (23.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (1.0.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (1.10.5)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2.0.8)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (4.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (3.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (0.0.4)
# Requirement already satisfied: colorama in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from jinja2->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2.1.2)
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py): started
#   Building wheel for docopt (setup.py): finished with status 'done'
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13775 sha256=0bf00fd12ebc063a2c00fe56198c9684bf1ba059d7c14755e41e33898e53e12d
#   Stored in directory: c:\users\winfr\appdata\local\pip\cache\wheels\fc\ab\d4\5da2067ac95b36618c629a5f93f809425700506f72c9732fac
# Successfully built docopt
# Installing collected packages: pymorphy3-dicts-ru, docopt, dawg-python, pymorphy3, ru-core-news-sm
# Successfully installed dawg-python-0.7.2 docopt-0.6.2 pymorphy3-1.2.0 pymorphy3-dicts-ru-2.4.417150.4580142 ru-core-news-sm-3.5.0
# [+] Download and installation successful
# You can now load the package via spacy.load('ru_core_news_sm')
# Collecting uk-core-news-sm==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/uk_core_news_sm-3.5.0/uk_core_news_sm-3.5.0-py3-none-any.whl (14.9 MB)
#      ---------------------------------------- 0.0/14.9 MB ? eta -:--:--
#      ---------------------------------------- 0.1/14.9 MB 3.6 MB/s eta 0:00:05
#      - -------------------------------------- 0.5/14.9 MB 6.6 MB/s eta 0:00:03
#      ----- ---------------------------------- 2.0/14.9 MB 16.2 MB/s eta 0:00:01
#      -------- ------------------------------- 3.1/14.9 MB 19.6 MB/s eta 0:00:01
#      ------------- -------------------------- 4.9/14.9 MB 23.9 MB/s eta 0:00:01
#      ----------------- ---------------------- 6.4/14.9 MB 25.7 MB/s eta 0:00:01
#      ---------------------- ----------------- 8.4/14.9 MB 29.7 MB/s eta 0:00:01
#      -------------------------- ------------- 9.8/14.9 MB 29.9 MB/s eta 0:00:01
#      -------------------------------- ------ 12.3/14.9 MB 40.9 MB/s eta 0:00:01
#      --------------------------------------  14.8/14.9 MB 43.7 MB/s eta 0:00:01
#      --------------------------------------  14.9/14.9 MB 40.9 MB/s eta 0:00:01
#      --------------------------------------  14.9/14.9 MB 40.9 MB/s eta 0:00:01
#      --------------------------------------- 14.9/14.9 MB 28.5 MB/s eta 0:00:00
# Collecting pymorphy3-dicts-uk
#   Downloading pymorphy3_dicts_uk-2.4.1.1.1663094765-py2.py3-none-any.whl (8.2 MB)
#      ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#       --------------------------------------- 0.2/8.2 MB 4.1 MB/s eta 0:00:02
#      - -------------------------------------- 0.3/8.2 MB 4.3 MB/s eta 0:00:02
#      --- ------------------------------------ 0.7/8.2 MB 4.9 MB/s eta 0:00:02
#      --------- ------------------------------ 2.0/8.2 MB 10.5 MB/s eta 0:00:01
#      ---------------- ----------------------- 3.3/8.2 MB 14.2 MB/s eta 0:00:01
#      ------------------------ --------------- 5.0/8.2 MB 17.6 MB/s eta 0:00:01
#      ----------------------------- ---------- 6.0/8.2 MB 19.3 MB/s eta 0:00:01
#      ---------------------------------------  8.0/8.2 MB 22.3 MB/s eta 0:00:01
#      ---------------------------------------  8.2/8.2 MB 22.8 MB/s eta 0:00:01
#      ---------------------------------------- 8.2/8.2 MB 19.4 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from uk-core-news-sm==3.5.0) (3.5.0)
# Requirement already satisfied: pymorphy3>=1.0.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from uk-core-news-sm==3.5.0) (1.2.0)
# Requirement already satisfied: dawg-python>=0.7.1 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from pymorphy3>=1.0.0->uk-core-news-sm==3.5.0) (0.7.2)
# Requirement already satisfied: docopt>=0.6 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from pymorphy3>=1.0.0->uk-core-news-sm==3.5.0) (0.6.2)
# Requirement already satisfied: pymorphy3-dicts-ru in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from pymorphy3>=1.0.0->uk-core-news-sm==3.5.0) (2.4.417150.4580142)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->uk-core-news-sm==3.5.0) (3.3.0)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->uk-core-news-sm==3.5.0) (0.7.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->uk-core-news-sm==3.5.0) (2.28.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->uk-core-news-sm==3.5.0) (4.64.1)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->uk-core-news-sm==3.5.0) (0.10.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->uk-core-news-sm==3.5.0) (1.0.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->uk-core-news-sm==3.5.0) (1.10.5)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->uk-core-news-sm==3.5.0) (1.24.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->uk-core-news-sm==3.5.0) (3.0.12)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->uk-core-news-sm==3.5.0) (2.0.8)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->uk-core-news-sm==3.5.0) (6.3.0)
# Requirement already satisfied: jinja2 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->uk-core-news-sm==3.5.0) (3.1.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->uk-core-news-sm==3.5.0) (3.0.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->uk-core-news-sm==3.5.0) (23.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->uk-core-news-sm==3.5.0) (1.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->uk-core-news-sm==3.5.0) (8.1.7)
# Requirement already satisfied: setuptools in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->uk-core-news-sm==3.5.0) (67.4.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->uk-core-news-sm==3.5.0) (2.4.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->uk-core-news-sm==3.5.0) (2.0.7)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->uk-core-news-sm==3.5.0) (1.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->uk-core-news-sm==3.5.0) (4.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->uk-core-news-sm==3.5.0) (1.26.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->uk-core-news-sm==3.5.0) (3.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->uk-core-news-sm==3.5.0) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->uk-core-news-sm==3.5.0) (3.4)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.6.0,>=3.5.0->uk-core-news-sm==3.5.0) (0.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.6.0,>=3.5.0->uk-core-news-sm==3.5.0) (0.7.9)
# Requirement already satisfied: colorama in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.6.0,>=3.5.0->uk-core-news-sm==3.5.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->uk-core-news-sm==3.5.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from jinja2->spacy<3.6.0,>=3.5.0->uk-core-news-sm==3.5.0) (2.1.2)
# Installing collected packages: pymorphy3-dicts-uk, uk-core-news-sm
# Successfully installed pymorphy3-dicts-uk-2.4.1.1.1663094765 uk-core-news-sm-3.5.0
# [+] Download and installation successful
# You can now load the package via spacy.load('uk_core_news_sm')

# %%
# !python -m spacy download en_core_web_lg
# Out:
# Collecting en-core-web-lg==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3
#      - ------------------------------------ 27.8/587.7 MB 10.7 MB/s eta 0:00:53
#      - ------------------------------------ 28.4/587.7 MB 11.1 MB/s eta 0:00:51
#      - ------------------------------------ 28.9/587.7 MB 11.5 MB/s eta 0:00:49
#      - ------------------------------------ 29.5/587.7 MB 11.9 MB/s eta 0:00:47
#      - ------------------------------------ 30.0/587.7 MB 12.4 MB/s eta 0:00:46
#      - ------------------------------------ 30.6/587.7 MB 12.4 MB/s eta 0:00:46
#      -- ----------------------------------- 31.1/587.7 MB 12.4 MB/s eta 0:00:46
#      -- ----------------------------------- 31.4/587.7 MB 12.1 MB/s eta 0:00:46
#      -- ----------------------------------- 31.8/587.7 MB 11.9 MB/s eta 0:00:47
#      -- ----------------------------------- 32.2/587.7 MB 11.7 MB/s eta 0:00:48
#      -- ----------------------------------- 32.7/587.7 MB 11.5 MB/s eta 0:00:49
#      -- ----------------------------------- 33.2/587.7 MB 11.3 MB/s eta 0:00:50
#      -- ----------------------------------- 33.7/587.7 MB 11.1 MB/s eta 0:00:50
#      -- ----------------------------------- 34.2/587.7 MB 11.1 MB/s eta 0:00:50
#      -- ----------------------------------- 34.7/587.7 MB 10.9 MB/s eta 0:00:51
#      -- ----------------------------------- 35.3/587.7 MB 10.9 MB/s eta 0:00:51
#      -- ----------------------------------- 35.8/587.7 MB 10.9 MB/s eta 0:00:51
#      -- ----------------------------------- 36.4/587.7 MB 10.9 MB/s eta 0:00:51
#      -- ----------------------------------- 37.0/587.7 MB 10.9 MB/s eta 0:00:51
#      -- ----------------------------------- 37.6/587.7 MB 10.9 MB/s eta 0:00:51
#      -- ----------------------------------- 38.1/587.7 MB 11.1 MB/s eta 0:00:50
#      -- ----------------------------------- 38.6/587.7 MB 10.9 MB/s eta 0:00:51
#      -- ----------------------------------- 39.1/587.7 MB 10.9 MB/s eta 0:00:51
#      -- ----------------------------------- 39.6/587.7 MB 10.7 MB/s eta 0:00:52
#      -- ----------------------------------- 40.0/587.7 MB 10.6 MB/s eta 0:00:52
#      -- ----------------------------------- 40.4/587.7 MB 10.6 MB/s eta 0:00:52
#      -- ----------------------------------- 40.9/587.7 MB 10.4 MB/s eta 0:00:53
#      -- ----------------------------------- 41.2/587.7 MB 10.4 MB/s eta 0:00:53
#      -- ----------------------------------- 41.6/587.7 MB 10.4 MB/s eta 0:00:53
#      -- ----------------------------------- 42.0/587.7 MB 10.4 MB/s eta 0:00:53
#      -- ----------------------------------- 42.2/587.7 MB 10.2 MB/s eta 0:00:54
#      -- ------------------------------------ 42.3/587.7 MB 9.8 MB/s eta 0:00:56
#      -- ------------------------------------ 42.6/587.7 MB 9.8 MB/s eta 0:00:56
#      -- ------------------------------------ 43.0/587.7 MB 9.6 MB/s eta 0:00:57
#      -- ------------------------------------ 43.4/587.7 MB 9.5 MB/s eta 0:00:58
#      -- ------------------------------------ 43.8/587.7 MB 9.4 MB/s eta 0:00:59
#      -- ------------------------------------ 44.2/587.7 MB 9.4 MB/s eta 0:00:59
#      -- ------------------------------------ 44.7/587.7 MB 9.4 MB/s eta 0:00:59
#      ---------- --------------------------- 161.9/587.7 MB 6.5 MB/s eta 0:01:06
#      ---------- --------------------------- 162.1/587.7 MB 6.5 MB/s eta 0:01:06
#      ---------- --------------------------- 162.3/587.7 MB 6.4 MB/s eta 0:01:07
#      ---------- --------------------------- 162.6/587.7 MB 6.3 MB/s eta 0:01:08
#      ---------- --------------------------- 162.7/587.7 MB 6.2 MB/s eta 0:01:09
#      ---------- --------------------------- 163.0/587.7 MB 6.1 MB/s eta 0:01:10
#      ---------- --------------------------- 163.2/587.7 MB 6.1 MB/s eta 0:01:11
#      ---------- --------------------------- 163.6/587.7 MB 6.1 MB/s eta 0:01:10
#      ---------- --------------------------- 163.8/587.7 MB 6.0 MB/s eta 0:01:11
#      ---------- --------------------------- 164.1/587.7 MB 6.0 MB/s eta 0:01:12
#      ---------- --------------------------- 164.4/587.7 MB 6.0 MB/s eta 0:01:12
#      ---------- --------------------------- 164.6/587.7 MB 5.9 MB/s eta 0:01:12
#      ---------- --------------------------- 164.8/587.7 MB 5.8 MB/s eta 0:01:13
#      ---------- --------------------------- 165.0/587.7 MB 5.8 MB/s eta 0:01:13
#      ---------- --------------------------- 165.3/587.7 MB 5.7 MB/s eta 0:01:14
#      ---------- --------------------------- 165.6/587.7 MB 5.7 MB/s eta 0:01:14
#      ---------- --------------------------- 165.8/587.7 MB 5.7 MB/s eta 0:01:15
#      ---------- --------------------------- 166.1/587.7 MB 5.6 MB/s eta 0:01:16
#      ---------- --------------------------- 166.3/587.7 MB 5.6 MB/s eta 0:01:16
#      ---------- --------------------------- 166.6/587.7 MB 5.5 MB/s eta 0:01:16
#      ---------- --------------------------- 166.9/587.7 MB 5.5 MB/s eta 0:01:17
#      ---------- --------------------------- 167.3/587.7 MB 5.5 MB/s eta 0:01:18
#      ---------- --------------------------- 167.6/587.7 MB 5.5 MB/s eta 0:01:17
#      ---------- --------------------------- 167.9/587.7 MB 5.5 MB/s eta 0:01:17
#      ---------- --------------------------- 168.3/587.7 MB 5.5 MB/s eta 0:01:16
#      ---------- --------------------------- 168.5/587.7 MB 5.5 MB/s eta 0:01:17
#      ---------- --------------------------- 168.7/587.7 MB 5.5 MB/s eta 0:01:17
#      ---------- --------------------------- 168.9/587.7 MB 5.4 MB/s eta 0:01:19
#      ---------- --------------------------- 169.2/587.7 MB 5.4 MB/s eta 0:01:18
#      ---------- --------------------------- 169.3/587.7 MB 5.3 MB/s eta 0:01:20
#      ---------- --------------------------- 169.4/587.7 MB 5.2 MB/s eta 0:01:21
#      ---------- --------------------------- 169.5/587.7 MB 5.1 MB/s eta 0:01:23
#      ---------- --------------------------- 169.6/587.7 MB 5.0 MB/s eta 0:01:24
#      ---------- --------------------------- 169.9/587.7 MB 5.0 MB/s eta 0:01:25
#      ----------- -------------------------- 170.3/587.7 MB 5.0 MB/s eta 0:01:23
#      ----------- -------------------------- 170.6/587.7 MB 5.0 MB/s eta 0:01:23
#      ----------- -------------------------- 171.0/587.7 MB 5.1 MB/s eta 0:01:22
#      ----------- -------------------------- 183.5/587.7 MB 7.3 MB/s eta 0:00:56
#      ----------- -------------------------- 184.0/587.7 MB 7.4 MB/s eta 0:00:55
#      ----------- -------------------------- 184.5/587.7 MB 7.4 MB/s eta 0:00:55
#      ----------- -------------------------- 185.1/587.7 MB 7.8 MB/s eta 0:00:52
#      ------------ ------------------------- 185.6/587.7 MB 8.3 MB/s eta 0:00:49
#      ------------ ------------------------- 186.2/587.7 MB 8.6 MB/s eta 0:00:47
#      ------------ ------------------------- 186.8/587.7 MB 9.0 MB/s eta 0:00:45
#      ------------ ------------------------- 187.3/587.7 MB 9.2 MB/s eta 0:00:44
#      ------------ ------------------------- 188.0/587.7 MB 9.9 MB/s eta 0:00:41
#      ----------- ------------------------- 188.3/587.7 MB 10.4 MB/s eta 0:00:39
#      ------------ ------------------------- 188.3/587.7 MB 9.8 MB/s eta 0:00:41
#      ------------ ------------------------- 188.5/587.7 MB 9.5 MB/s eta 0:00:43
#      ------------ ------------------------- 189.1/587.7 MB 9.9 MB/s eta 0:00:41
#      ------------ ------------------------- 189.5/587.7 MB 9.9 MB/s eta 0:00:41
#      ----------- ------------------------- 190.1/587.7 MB 10.1 MB/s eta 0:00:40
#      ------------ ------------------------ 190.7/587.7 MB 10.4 MB/s eta 0:00:39
#      ------------ ------------------------ 191.4/587.7 MB 10.7 MB/s eta 0:00:37
#      ------------ ------------------------ 192.0/587.7 MB 10.7 MB/s eta 0:00:37
#      ------------ ------------------------ 192.5/587.7 MB 10.9 MB/s eta 0:00:37
#      ------------ ------------------------ 193.0/587.7 MB 10.6 MB/s eta 0:00:38
#      ------------ ------------------------ 193.2/587.7 MB 10.6 MB/s eta 0:00:38
#      ------------ ------------------------ 193.6/587.7 MB 10.2 MB/s eta 0:00:39
#      ------------ ------------------------ 194.0/587.7 MB 10.4 MB/s eta 0:00:38
#      ------------ ------------------------ 194.5/587.7 MB 10.4 MB/s eta 0:00:38
#      ------------ ------------------------ 195.0/587.7 MB 10.1 MB/s eta 0:00:40
#      ------------ ------------------------ 195.5/587.7 MB 10.2 MB/s eta 0:00:39
#      ------------ ------------------------ 195.9/587.7 MB 10.1 MB/s eta 0:00:39
#      ------------ ------------------------ 196.4/587.7 MB 10.1 MB/s eta 0:00:39
#      ------------ ------------------------- 196.9/587.7 MB 9.9 MB/s eta 0:00:40
#      ------------ ------------------------- 197.3/587.7 MB 9.9 MB/s eta 0:00:40
#      ------------ ------------------------- 197.6/587.7 MB 9.6 MB/s eta 0:00:41
#      ------------ ------------------------- 197.8/587.7 MB 9.4 MB/s eta 0:00:42
#      ------------ ------------------------- 198.0/587.7 MB 9.1 MB/s eta 0:00:43
#      ------------ ------------------------- 198.3/587.7 MB 8.8 MB/s eta 0:00:45
#      ------------ ------------------------- 198.5/587.7 MB 9.1 MB/s eta 0:00:43
#      ------------ ------------------------- 198.8/587.7 MB 9.2 MB/s eta 0:00:43
#      ------------ ------------------------- 199.1/587.7 MB 9.0 MB/s eta 0:00:44
#      -------------------------------------  583.1/587.7 MB 2.8 MB/s eta 0:00:02
#      -------------------------------------  583.3/587.7 MB 2.7 MB/s eta 0:00:02
#      -------------------------------------  583.6/587.7 MB 2.7 MB/s eta 0:00:02
#      -------------------------------------  583.8/587.7 MB 2.7 MB/s eta 0:00:02
#      -------------------------------------  584.1/587.7 MB 2.7 MB/s eta 0:00:02
#      -------------------------------------  584.2/587.7 MB 2.7 MB/s eta 0:00:02
#      -------------------------------------  584.5/587.7 MB 2.7 MB/s eta 0:00:02
#      -------------------------------------  584.6/587.7 MB 2.7 MB/s eta 0:00:02
#      -------------------------------------  584.8/587.7 MB 2.6 MB/s eta 0:00:02
#      -------------------------------------  585.0/587.7 MB 2.6 MB/s eta 0:00:02
#      -------------------------------------  585.2/587.7 MB 2.6 MB/s eta 0:00:01
#      -------------------------------------  585.4/587.7 MB 2.6 MB/s eta 0:00:01
#      -------------------------------------  585.6/587.7 MB 2.6 MB/s eta 0:00:01
#      -------------------------------------  585.8/587.7 MB 2.6 MB/s eta 0:00:01
#      -------------------------------------  586.0/587.7 MB 2.5 MB/s eta 0:00:01
#      -------------------------------------  586.2/587.7 MB 2.5 MB/s eta 0:00:01
#      -------------------------------------  586.4/587.7 MB 2.5 MB/s eta 0:00:01
#      -------------------------------------  586.6/587.7 MB 2.5 MB/s eta 0:00:01
#      -------------------------------------  586.8/587.7 MB 2.5 MB/s eta 0:00:01
#      -------------------------------------  587.0/587.7 MB 2.5 MB/s eta 0:00:01
#      -------------------------------------  587.3/587.7 MB 2.5 MB/s eta 0:00:01
#      -------------------------------------  587.5/587.7 MB 2.5 MB/s eta 0:00:01
#      -------------------------------------  587.7/587.7 MB 2.5 MB/s eta 0:00:01
#      -------------------------------------  587.7/587.7 MB 2.5 MB/s eta 0:00:01
#      -------------------------------------  587.7/587.7 MB 2.5 MB/s eta 0:00:01
#      -------------------------------------  587.7/587.7 MB 2.5 MB/s eta 0:00:01
#      -------------------------------------  587.7/587.7 MB 2.5 MB/s eta 0:00:01
#      -------------------------------------  587.7/587.7 MB 2.5 MB/s eta 0:00:01
#      -------------------------------------  587.7/587.7 MB 2.5 MB/s eta 0:00:01
#      -------------------------------------  587.7/587.7 MB 2.5 MB/s eta 0:00:01
#      -------------------------------------  587.7/587.7 MB 2.5 MB/s eta 0:00:01
#      -------------------------------------  587.7/587.7 MB 2.5 MB/s eta 0:00:01
#      -------------------------------------  587.7/587.7 MB 2.5 MB/s eta 0:00:01
#      -------------------------------------  587.7/587.7 MB 2.5 MB/s eta 0:00:01
#      -------------------------------------  587.7/587.7 MB 2.5 MB/s eta 0:00:01
#      -------------------------------------  587.7/587.7 MB 2.5 MB/s eta 0:00:01
#      -------------------------------------  587.7/587.7 MB 2.5 MB/s eta 0:00:01
#      -------------------------------------  587.7/587.7 MB 2.5 MB/s eta 0:00:01
#      -------------------------------------  587.7/587.7 MB 2.5 MB/s eta 0:00:01
#      -------------------------------------  587.7/587.7 MB 2.5 MB/s eta 0:00:01
#      -------------------------------------  587.7/587.7 MB 2.5 MB/s eta 0:00:01
#      -------------------------------------  587.7/587.7 MB 2.5 MB/s eta 0:00:01
#      -------------------------------------  587.7/587.7 MB 2.5 MB/s eta 0:00:01
#      -------------------------------------  587.7/587.7 MB 2.5 MB/s eta 0:00:01
#      -------------------------------------  587.7/587.7 MB 2.5 MB/s eta 0:00:01
#      -------------------------------------  587.7/587.7 MB 2.5 MB/s eta 0:00:01
#      -------------------------------------- 587.7/587.7 MB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from en-core-web-lg==3.5.0) (3.5.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.10.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.0.7)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.1.1)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.24.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (23.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (8.1.7)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.28.2)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.0.4)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.4.5)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.7.0)
# Requirement already satisfied: jinja2 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.1.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.0.8)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.10.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (4.64.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.0.12)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.3.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.0.9)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (6.3.0)
# Requirement already satisfied: setuptools in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (67.4.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.0.8)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (4.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.26.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.7.9)
# Requirement already satisfied: colorama in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.1.2)
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.5.0
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
# !pip install keybert
# Out:
# Collecting keybert
#   Downloading keybert-0.7.0.tar.gz (21 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting sentence-transformers>=0.3.8
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ---------------------------------------- 0.0/86.0 kB ? eta -:--:--
#      ------------------ ------------------- 41.0/86.0 kB 991.0 kB/s eta 0:00:01
#      -------------------------------------- 86.0/86.0 kB 814.1 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting scikit-learn>=0.22.2
#   Downloading scikit_learn-1.2.1-cp310-cp310-win_amd64.whl (8.3 MB)
#      ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#      ---------------------------------------- 0.1/8.3 MB 1.9 MB/s eta 0:00:05
#       --------------------------------------- 0.1/8.3 MB 1.7 MB/s eta 0:00:05
#       --------------------------------------- 0.2/8.3 MB 1.6 MB/s eta 0:00:06
#      - -------------------------------------- 0.3/8.3 MB 1.7 MB/s eta 0:00:05
#      - -------------------------------------- 0.3/8.3 MB 1.6 MB/s eta 0:00:05
#      - -------------------------------------- 0.4/8.3 MB 1.7 MB/s eta 0:00:05
#      -- ------------------------------------- 0.5/8.3 MB 1.6 MB/s eta 0:00:05
#      -- ------------------------------------- 0.5/8.3 MB 1.7 MB/s eta 0:00:05
#      -- ------------------------------------- 0.5/8.3 MB 1.7 MB/s eta 0:00:05
#      -- ------------------------------------- 0.6/8.3 MB 1.4 MB/s eta 0:00:06
#      -- ------------------------------------- 0.6/8.3 MB 1.3 MB/s eta 0:00:06
#      --- ------------------------------------ 0.7/8.3 MB 1.3 MB/s eta 0:00:06
#      --- ------------------------------------ 0.7/8.3 MB 1.3 MB/s eta 0:00:06
#      --- ------------------------------------ 0.8/8.3 MB 1.3 MB/s eta 0:00:06
#      ---------------------- ----------------- 4.6/8.3 MB 2.0 MB/s eta 0:00:02
#      ---------------------- ----------------- 4.7/8.3 MB 2.0 MB/s eta 0:00:02
#      ----------------------- ---------------- 4.9/8.3 MB 2.1 MB/s eta 0:00:02
#      ------------------------ --------------- 5.1/8.3 MB 2.1 MB/s eta 0:00:02
#      ------------------------- -------------- 5.3/8.3 MB 2.1 MB/s eta 0:00:02
#      -------------------------- ------------- 5.4/8.3 MB 2.2 MB/s eta 0:00:02
#      --------------------------- ------------ 5.6/8.3 MB 2.2 MB/s eta 0:00:02
#      ---------------------------- ----------- 5.8/8.3 MB 2.2 MB/s eta 0:00:02
#      ---------------------------- ----------- 5.9/8.3 MB 2.3 MB/s eta 0:00:02
#      ----------------------------- ---------- 6.2/8.3 MB 2.3 MB/s eta 0:00:01
#      ------------------------------ --------- 6.4/8.3 MB 2.3 MB/s eta 0:00:01
#      ------------------------------- -------- 6.5/8.3 MB 2.3 MB/s eta 0:00:01
#      -------------------------------- ------- 6.7/8.3 MB 2.4 MB/s eta 0:00:01
#      --------------------------------- ------ 6.9/8.3 MB 2.4 MB/s eta 0:00:01
#      ---------------------------------- ----- 7.2/8.3 MB 2.5 MB/s eta 0:00:01
#      ----------------------------------- ---- 7.3/8.3 MB 2.5 MB/s eta 0:00:01
#      ------------------------------------ --- 7.6/8.3 MB 2.5 MB/s eta 0:00:01
#      ------------------------------------- -- 7.8/8.3 MB 2.6 MB/s eta 0:00:01
#      ---------------------------------------  8.1/8.3 MB 2.6 MB/s eta 0:00:01
#      ---------------------------------------  8.3/8.3 MB 2.6 MB/s eta 0:00:01
#      ---------------------------------------  8.3/8.3 MB 2.6 MB/s eta 0:00:01
#      ---------------------------------------- 8.3/8.3 MB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.18.5 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from keybert) (1.24.2)
# Collecting rich>=10.4.0
#   Downloading rich-13.3.1-py3-none-any.whl (239 kB)
#      ---------------------------------------- 0.0/239.0 kB ? eta -:--:--
#      -------------------------------------- 239.0/239.0 kB 7.4 MB/s eta 0:00:00
# Collecting markdown-it-py<3.0.0,>=2.1.0
#   Downloading markdown_it_py-2.2.0-py3-none-any.whl (84 kB)
#      ---------------------------------------- 0.0/84.5 kB ? eta -:--:--
#      ---------------------------------------- 84.5/84.5 kB ? eta 0:00:00
# Requirement already satisfied: pygments<3.0.0,>=2.14.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from rich>=10.4.0->keybert) (2.14.0)
# Collecting threadpoolctl>=2.0.0
#   Using cached threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Collecting scipy>=1.3.2
#   Downloading scipy-1.10.1-cp310-cp310-win_amd64.whl (42.5 MB)
#      ---------------------------------------- 0.0/42.5 MB ? eta -:--:--
#      ---------------------------------------- 0.2/42.5 MB 6.9 MB/s eta 0:00:07
#      ---------------------------------------- 0.4/42.5 MB 4.6 MB/s eta 0:00:10
#      ---------------------------------------- 0.5/42.5 MB 4.1 MB/s eta 0:00:11
#       --------------------------------------- 0.7/42.5 MB 4.3 MB/s eta 0:00:10
#       --------------------------------------- 0.9/42.5 MB 4.5 MB/s eta 0:00:10
#      - -------------------------------------- 1.1/42.5 MB 4.3 MB/s eta 0:00:10
#      - -------------------------------------- 1.4/42.5 MB 4.5 MB/s eta 0:00:10
#      - -------------------------------------- 1.6/42.5 MB 4.7 MB/s eta 0:00:09
#      - -------------------------------------- 1.8/42.5 MB 4.7 MB/s eta 0:00:09
#      - -------------------------------------- 2.0/42.5 MB 4.8 MB/s eta 0:00:09
#      -- ------------------------------------- 2.3/42.5 MB 4.8 MB/s eta 0:00:09
#      -- ------------------------------------- 2.5/42.5 MB 4.9 MB/s eta 0:00:09
#      -- ------------------------------------- 2.8/42.5 MB 4.9 MB/s eta 0:00:09
#      -- ------------------------------------- 3.0/42.5 MB 5.0 MB/s eta 0:00:08
#      --- ------------------------------------ 3.2/42.5 MB 5.0 MB/s eta 0:00:08
#      --- ------------------------------------ 3.4/42.5 MB 5.0 MB/s eta 0:00:08
#      --- ------------------------------------ 3.7/42.5 MB 5.0 MB/s eta 0:00:08
#      --- ------------------------------------ 3.9/42.5 MB 5.0 MB/s eta 0:00:08
#      --- ------------------------------------ 4.2/42.5 MB 5.0 MB/s eta 0:00:08
#      ---- ----------------------------------- 4.4/42.5 MB 5.1 MB/s eta 0:00:08
#      ---- ----------------------------------- 4.7/42.5 MB 5.2 MB/s eta 0:00:08
#      ---- ----------------------------------- 4.9/42.5 MB 5.2 MB/s eta 0:00:08
#      ---- ----------------------------------- 5.3/42.5 MB 5.2 MB/s eta 0:00:08
#      ----- ---------------------------------- 5.6/42.5 MB 5.2 MB/s eta 0:00:08
#      ----- ---------------------------------- 5.9/42.5 MB 5.3 MB/s eta 0:00:07
#      ----- ---------------------------------- 6.2/42.5 MB 5.3 MB/s eta 0:00:07
#      ------ --------------------------------- 6.5/42.5 MB 5.4 MB/s eta 0:00:07
#      ------ --------------------------------- 6.7/42.5 MB 5.4 MB/s eta 0:00:07
#      ------ --------------------------------- 7.0/42.5 MB 5.5 MB/s eta 0:00:07
#      ------ --------------------------------- 7.3/42.5 MB 5.5 MB/s eta 0:00:07
#      ------- -------------------------------- 7.6/42.5 MB 5.6 MB/s eta 0:00:07
#      ------- -------------------------------- 7.9/42.5 MB 5.6 MB/s eta 0:00:07
#      ------- -------------------------------- 8.1/42.5 MB 5.6 MB/s eta 0:00:07
#      ------- -------------------------------- 8.4/42.5 MB 5.7 MB/s eta 0:00:07
#      -------- ------------------------------- 8.8/42.5 MB 5.7 MB/s eta 0:00:06
#      -------- ------------------------------- 9.0/42.5 MB 5.7 MB/s eta 0:00:06
#      -------- ------------------------------- 9.3/42.5 MB 5.7 MB/s eta 0:00:06
#      -------- ------------------------------- 9.5/42.5 MB 5.7 MB/s eta 0:00:06
#      --------- ------------------------------ 9.6/42.5 MB 5.7 MB/s eta 0:00:06
#      --------- ------------------------------ 9.7/42.5 MB 5.5 MB/s eta 0:00:07
#      --------- ------------------------------ 9.7/42.5 MB 5.3 MB/s eta 0:00:07
#      --------- ------------------------------ 9.8/42.5 MB 5.3 MB/s eta 0:00:07
#      --------- ------------------------------ 9.9/42.5 MB 5.2 MB/s eta 0:00:07
#      --------- ------------------------------ 10.2/42.5 MB 5.2 MB/s eta 0:00:07
#      --------- ------------------------------ 10.4/42.5 MB 5.2 MB/s eta 0:00:07
#      ---------- ----------------------------- 10.7/42.5 MB 5.3 MB/s eta 0:00:07
#      ---------- ----------------------------- 10.9/42.5 MB 5.3 MB/s eta 0:00:06
#      ---------- ----------------------------- 11.2/42.5 MB 5.3 MB/s eta 0:00:06
#      ---------- ----------------------------- 11.5/42.5 MB 5.3 MB/s eta 0:00:06
#      ----------- ---------------------------- 11.8/42.5 MB 5.3 MB/s eta 0:00:06
#      ----------- ---------------------------- 12.0/42.5 MB 5.4 MB/s eta 0:00:06
#      ----------- ---------------------------- 12.3/42.5 MB 5.4 MB/s eta 0:00:06
#      ----------- ---------------------------- 12.6/42.5 MB 5.4 MB/s eta 0:00:06
#      ------------ --------------------------- 12.8/42.5 MB 5.4 MB/s eta 0:00:06
#      ------------ --------------------------- 13.0/42.5 MB 5.3 MB/s eta 0:00:06
#      ------------ --------------------------- 13.1/42.5 MB 5.3 MB/s eta 0:00:06
#      ------------ --------------------------- 13.4/42.5 MB 5.2 MB/s eta 0:00:06
#      ------------ --------------------------- 13.6/42.5 MB 5.2 MB/s eta 0:00:06
#      ------------ --------------------------- 13.7/42.5 MB 5.2 MB/s eta 0:00:06
#      ------------- -------------------------- 14.1/42.5 MB 5.2 MB/s eta 0:00:06
#      ------------- -------------------------- 14.4/42.5 MB 5.2 MB/s eta 0:00:06
#      ------------- -------------------------- 14.7/42.5 MB 5.3 MB/s eta 0:00:06
#      -------------- ------------------------- 14.9/42.5 MB 5.3 MB/s eta 0:00:06
#      -------------- ------------------------- 15.3/42.5 MB 5.3 MB/s eta 0:00:06
#      -------------- ------------------------- 15.5/42.5 MB 5.3 MB/s eta 0:00:06
#      -------------- ------------------------- 15.6/42.5 MB 5.2 MB/s eta 0:00:06
#      -------------- ------------------------- 15.7/42.5 MB 5.2 MB/s eta 0:00:06
#      --------------- ------------------------ 16.0/42.5 MB 5.2 MB/s eta 0:00:06
#      --------------- ------------------------ 16.1/42.5 MB 5.1 MB/s eta 0:00:06
#      --------------- ------------------------ 16.1/42.5 MB 5.1 MB/s eta 0:00:06
#      --------------- ------------------------ 16.1/42.5 MB 4.9 MB/s eta 0:00:06
#      --------------- ------------------------ 16.2/42.5 MB 4.8 MB/s eta 0:00:06
#      --------------- ------------------------ 16.2/42.5 MB 4.7 MB/s eta 0:00:06
#      --------------- ------------------------ 16.4/42.5 MB 4.6 MB/s eta 0:00:06
#      --------------- ------------------------ 16.6/42.5 MB 4.6 MB/s eta 0:00:06
#      --------------- ------------------------ 16.8/42.5 MB 4.6 MB/s eta 0:00:06
#      ---------------- ----------------------- 17.0/42.5 MB 4.5 MB/s eta 0:00:06
#      ---------------- ----------------------- 17.2/42.5 MB 4.5 MB/s eta 0:00:06
#      ---------------- ----------------------- 17.4/42.5 MB 4.5 MB/s eta 0:00:06
#      ---------------- ----------------------- 17.6/42.5 MB 4.5 MB/s eta 0:00:06
#      ---------------- ----------------------- 17.8/42.5 MB 4.5 MB/s eta 0:00:06
#      ---------------- ----------------------- 18.1/42.5 MB 4.5 MB/s eta 0:00:06
#      ----------------- ---------------------- 18.3/42.5 MB 4.4 MB/s eta 0:00:06
#      -------------------------- ------------- 28.3/42.5 MB 5.7 MB/s eta 0:00:03
#      -------------------------- ------------- 28.5/42.5 MB 5.8 MB/s eta 0:00:03
#      --------------------------- ------------ 28.7/42.5 MB 5.8 MB/s eta 0:00:03
#      --------------------------- ------------ 28.9/42.5 MB 5.9 MB/s eta 0:00:03
#      --------------------------- ------------ 29.2/42.5 MB 6.0 MB/s eta 0:00:03
#      --------------------------- ------------ 29.5/42.5 MB 6.0 MB/s eta 0:00:03
#      ---------------------------- ----------- 29.8/42.5 MB 6.0 MB/s eta 0:00:03
#      ---------------------------- ----------- 30.0/42.5 MB 6.1 MB/s eta 0:00:03
#      ---------------------------- ----------- 30.4/42.5 MB 6.1 MB/s eta 0:00:02
#      ---------------------------- ----------- 30.7/42.5 MB 6.2 MB/s eta 0:00:02
#      ----------------------------- ---------- 31.1/42.5 MB 6.3 MB/s eta 0:00:02
#      ----------------------------- ---------- 31.3/42.5 MB 6.2 MB/s eta 0:00:02
#      ----------------------------- ---------- 31.7/42.5 MB 6.4 MB/s eta 0:00:02
#      ------------------------------ --------- 32.1/42.5 MB 6.4 MB/s eta 0:00:02
#      ------------------------------ --------- 32.3/42.5 MB 6.4 MB/s eta 0:00:02
#      ------------------------------ --------- 32.7/42.5 MB 6.5 MB/s eta 0:00:02
#      ------------------------------- -------- 33.0/42.5 MB 6.5 MB/s eta 0:00:02
#      ------------------------------- -------- 33.4/42.5 MB 6.5 MB/s eta 0:00:02
#      ------------------------------- -------- 33.6/42.5 MB 6.6 MB/s eta 0:00:02
#      ------------------------------- -------- 33.9/42.5 MB 6.5 MB/s eta 0:00:02
#      -------------------------------- ------- 34.3/42.5 MB 6.5 MB/s eta 0:00:02
#      -------------------------------- ------- 34.5/42.5 MB 6.5 MB/s eta 0:00:02
#      -------------------------------- ------- 35.0/42.5 MB 6.7 MB/s eta 0:00:02
#      --------------------------------- ------ 35.3/42.5 MB 6.7 MB/s eta 0:00:02
#      --------------------------------- ------ 35.7/42.5 MB 6.7 MB/s eta 0:00:02
#      ---------------------------------- ----- 36.1/42.5 MB 6.8 MB/s eta 0:00:01
#      ---------------------------------- ----- 36.5/42.5 MB 6.8 MB/s eta 0:00:01
#      ---------------------------------- ----- 36.8/42.5 MB 7.0 MB/s eta 0:00:01
#      ----------------------------------- ---- 37.2/42.5 MB 7.0 MB/s eta 0:00:01
#      ----------------------------------- ---- 37.6/42.5 MB 7.0 MB/s eta 0:00:01
#      ----------------------------------- ---- 38.1/42.5 MB 7.3 MB/s eta 0:00:01
#      ------------------------------------ --- 38.4/42.5 MB 7.3 MB/s eta 0:00:01
#      ------------------------------------ --- 38.7/42.5 MB 7.2 MB/s eta 0:00:01
#      ------------------------------------ --- 39.1/42.5 MB 7.4 MB/s eta 0:00:01
#      ------------------------------------- -- 39.4/42.5 MB 7.4 MB/s eta 0:00:01
#      ------------------------------------- -- 39.8/42.5 MB 7.6 MB/s eta 0:00:01
#      ------------------------------------- -- 40.1/42.5 MB 7.6 MB/s eta 0:00:01
#      -------------------------------------- - 40.4/42.5 MB 7.6 MB/s eta 0:00:01
#      -------------------------------------- - 40.9/42.5 MB 7.6 MB/s eta 0:00:01
#      -------------------------------------- - 41.3/42.5 MB 7.7 MB/s eta 0:00:01
#      ---------------------------------------  41.6/42.5 MB 7.9 MB/s eta 0:00:01
#      ---------------------------------------  42.1/42.5 MB 7.9 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 7.9 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 7.9 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 7.9 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 7.9 MB/s eta 0:00:01
#      ---------------------------------------- 42.5/42.5 MB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=1.1.1 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from scikit-learn>=0.22.2->keybert) (1.2.0)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from sentence-transformers>=0.3.8->keybert) (4.26.1)
# Requirement already satisfied: tqdm in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from sentence-transformers>=0.3.8->keybert) (4.64.1)
# Requirement already satisfied: torch>=1.6.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from sentence-transformers>=0.3.8->keybert) (1.13.1+cu116)
# Requirement already satisfied: torchvision in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from sentence-transformers>=0.3.8->keybert) (0.14.1+cu116)
# Requirement already satisfied: nltk in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from sentence-transformers>=0.3.8->keybert) (3.8.1)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp310-cp310-win_amd64.whl (1.1 MB)
#      ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#      ---------------- ----------------------- 0.5/1.1 MB 14.5 MB/s eta 0:00:01
#      ------------------------ --------------- 0.7/1.1 MB 10.9 MB/s eta 0:00:01
#      --------------------------- ------------ 0.8/1.1 MB 6.1 MB/s eta 0:00:01
#      ---------------------------------------  1.1/1.1 MB 5.9 MB/s eta 0:00:01
#      ---------------------------------------- 1.1/1.1 MB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub>=0.4.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from sentence-transformers>=0.3.8->keybert) (0.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (4.4.0)
# Requirement already satisfied: requests in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (2.28.2)
# Requirement already satisfied: filelock in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (3.9.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (6.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (23.0)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: colorama in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from tqdm->sentence-transformers>=0.3.8->keybert) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (2022.10.31)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (0.13.2)
# Requirement already satisfied: click in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from nltk->sentence-transformers>=0.3.8->keybert) (8.1.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from torchvision->sentence-transformers>=0.3.8->keybert) (9.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (2.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (3.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\winfr\documents\github\bert-project\.env\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (2022.12.7)
# Building wheels for collected packages: keybert, sentence-transformers
#   Building wheel for keybert (setup.py): started
#   Building wheel for keybert (setup.py): finished with status 'done'
#   Created wheel for keybert: filename=keybert-0.7.0-py3-none-any.whl size=23827 sha256=24145561a3e2984f18361735809feac6b0b87d45e1a037998512a75a416d4d67
#   Stored in directory: c:\users\winfr\appdata\local\pip\cache\wheels\66\8d\e6\b0e2f8d883b0fd51819226f67ad9843e04913ce4a97241ff4b
#   Building wheel for sentence-transformers (setup.py): started
#   Building wheel for sentence-transformers (setup.py): finished with status 'done'
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125960 sha256=939065f2450b2351a5f7ec526defb3246f4916b346c5efc2286ce61ff6ed82c2
#   Stored in directory: c:\users\winfr\appdata\local\pip\cache\wheels\62\f2\10\1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built keybert sentence-transformers
# Installing collected packages: sentencepiece, threadpoolctl, scipy, mdurl, scikit-learn, markdown-it-py, rich, sentence-transformers, keybert
# Successfully installed keybert-0.7.0 markdown-it-py-2.2.0 mdurl-0.1.2 rich-13.3.1 scikit-learn-1.2.1 scipy-1.10.1 sentence-transformers-2.2.2 sentencepiece-0.1.97 threadpoolctl-3.1.0

# %%
import pandas as pd
import numpy as np
import re

# %%
data = pd.read_excel("Poems.xlsx")
data.head()
# Out:
#    ID      Author of poem      Author of post  \
# 0   1         Halyna Kruk         Halyna Kruk
# 1   2     Ostap Slyvynsky     Ostap Slyvynsky
# 2   3     Osip Mandelstam     Maria Stepanova
# 3   4    Boris Khersonsky    Boris Khersonsky
# 4   5  Oleksandr Irvanets  Oleksandr Irvanets
#
#                                       Themes curated  \
# 0     {'maidan', 'revolution', 'protest', 'ukraine'}
# 1  {'maidan', 'poetic form', 'haiku', 'revolution...
# 2               {'time', 'war', 'twentieth century'}
# 3                                                NaN
# 4                    {'seasons', 'time', 'new year'}
#
#              Theme(s) (comma separated)    Theme 2 (blank) Theme 3 (blank)  \
# 0                                Maidan            Ukraine             NaN
# 1                         Haiku, Maidan                NaN             NaN
# 2                                   war  twentieth century             NaN
# 3  Soviet Union, food, morphine, anthem                NaN             NaN
# 4                              New year                NaN             NaN
#
#     Language In translation? Original language (if post is a translation)  \
# 0  Ukrainian              No                                          NaN
# 1  Ukrainian              No                                          NaN
# 2    Russian              No                                          NaN
# 3    Russian              No                                          NaN
# 4  Ukrainian              No                                          NaN
#
#                      Poem full text (copy and paste)
# 0  ***\ncказати собі чесно, якомога чесніше,\nтак...
# 1  ХАЙКУ З МАЙДАНУ\nДим у рукавах.\nНіби йдеш з ц...
# 2  (О.М.)\nНе мучнистой бабочкою белой\nВ землю я...
# 3  ***\n"Союз нерушимый" сыграют и хором споют.\n...
# 4  ***\nЦей рік, який почався з середи - \nКуди в...

# %% [markdown]
# ### Cleaning

# %%
## Check percentage of null values
data.isnull().mean(axis=0)*100
# Out:
# ID                                               0.000000
# Author of poem                                   0.000000
# Author of post                                   0.000000
# Themes curated                                  42.489627
# Theme(s) (comma separated)                       6.887967
# Theme 2 (blank)                                 88.713693
# Theme 3 (blank)                                 94.107884
# Language                                         0.331950
# In translation?                                  0.082988
# Original language (if post is a translation)    83.070539
# Poem full text (copy and paste)                  0.000000
# dtype: float64

# %%
data = data.drop(columns=['Author of post', 'In translation?', 'Original language (if post is a translation)'])

# %%
# Let's look at the types of languages we have in our dataset

# There are 4 null values in the Language column, we will drop them
data = data.dropna(subset=['Language'])
data['Language'].str.strip().str.split(", ").apply(set).value_counts()
# Out:
# {Ukrainian}                                                                                      734
# {Russian}                                                                                        364
# {English}                                                                                         31
# {Polish}                                                                                          22
# {Hebrew}                                                                                           9
# {Russian, Ukrainian}                                                                               6
# {Belorusian}                                                                                       5
# {Italian}                                                                                          5
# {Estonian}                                                                                         2
# {Swedish}                                                                                          2
# {Polish, Russian}                                                                                  2
# {Georgian}                                                                                         2
# {Croatian}                                                                                         2
# {Tatar}                                                                                            1
# {English, Russian}                                                                                 1
# {English, Ukrainian}                                                                               1
# {Polish, original Russian with various translations, Ukrainian, English, Russian, Belorusian}      1
# {Vietnamese}                                                                                       1
# {Chinese}                                                                                          1
# {Belorusian, Ukrainian}                                                                            1
# {English, Malayam}                                                                                 1
# {Greek}                                                                                            1
# {Belarusian}                                                                                       1
# {Lithuanian}                                                                                       1
# {Malayalam}                                                                                        1
# {German}                                                                                           1
# {Hungarian}                                                                                        1
# {Czech}                                                                                            1
# Name: Language, dtype: int64

# %%
# Need to clean the following columns: themes, language and poem full text

#### Themes

# Notice that the column "Themes curated" consists of Map object. Here we convert themes-related columns to list type
data['Theme(s) (comma separated)']= data['Theme(s) (comma separated)'].str.split(",")
data['Themes curated']= data['Themes curated'].str.strip('}{').str.split(",")
# Now we combine all themes-related columns. We will skip 'Theme 2 (blank)' and 'Theme 3 (blank)' 
# since they mostly contain copies from other themes columns
data = data.assign(theme_combined=data['Theme(s) (comma separated)']+data['Themes curated'].fillna("").apply(list))

# Dropping all themes-related column, we will only use the "theme_combined" column moving forward
data.drop(columns=['Theme(s) (comma separated)', 'Themes curated', 'Theme 2 (blank)', 'Theme 3 (blank)'], inplace=True)

#### Language

# We only want to look at poems written in Russian or Ukrainian
russian_ukrainian = data.loc[data['Language'].str.split(", ").apply(set).apply(lambda x: ('Ukrainian' in x) or ('Russian' in x)), ]

# Notice that there are 6 poems written in both Russian and Ukrainian (skipping that for now - 15thFeb)

#### Poem text cleaning
def text_cleaning(text):
    text = text.replace("\n", ' ').replace('See less', '')
    text = re.sub('(#[\w\u0400-\u04FF]+)', '', text) #removing hashtags
    text = re.sub('[\[\(][\s\w\u0400-\u04FF\.,@$#!&\*\(\)\~\[\]]*[\]\)]', '', text) #removing brackets and everything inside
    return text

russian_ukrainian = russian_ukrainian.assign(light_clean_poem=russian_ukrainian['Poem full text (copy and paste)'].apply(text_cleaning))

# %%
russian_ukrainian['Language'].value_counts()
# Out:
# Ukrainian                                                                                      734
# Russian                                                                                        364
# Russian, Ukrainian                                                                               6
# Russian, Polish                                                                                  2
# English, Ukrainian                                                                               1
# Ukrainian, Belorusian                                                                            1
# English, Russian                                                                                 1
# English, Russian, Ukrainian, Polish, Belorusian, original Russian with various translations      1
# Name: Language, dtype: int64

# %%
russian_ukrainian.drop_duplicates(subset='Poem full text (copy and paste)')['Language'].value_counts()
# Out:
# Ukrainian                                                                                      718
# Russian                                                                                        357
# Russian, Ukrainian                                                                               6
# Russian, Polish                                                                                  2
# English, Ukrainian                                                                               1
# Ukrainian, Belorusian                                                                            1
# English, Russian                                                                                 1
# English, Russian, Ukrainian, Polish, Belorusian, original Russian with various translations      1
# Name: Language, dtype: int64

# %%
## There are some duplicated poem entries. Let's take a look
check_dup = russian_ukrainian.duplicated(subset='Poem full text (copy and paste)', keep=False) # this returns a boolean series.
russian_ukrainian_dup = russian_ukrainian.loc[check_dup] # getting only duplicated rows
russian_ukrainian_dup
# Out:
#         ID           Author of poem   Language  \
# 39      40         Boris Khersonsky    Russian
# 40      41         Boris Khersonsky    Russian
# 53      54         Boris Khersonsky    Russian
# 54      55         Boris Khersonsky    Russian
# 145    146              Halyna Kruk  Ukrainian
# 146    147            Pavlo Tychyna  Ukrainian
# 173    174           Luba Iakymchuk  Ukrainian
# 174    175           Luba Iakymchuk  Ukrainian
# 203    204            Serhiy Zhadan  Ukrainian
# 204    205            Serhii Zhadan  Ukrainian
# 226    227         Kateryna Kalytko  Ukrainian
# 227    228         Kateryna Kalytko  Ukrainian
# 344    345    Liudmila Khersonskaya    Russian
# 345    346    Liudmila Khersonskaya    Russian
# 356    357      Nathalie Beltchenko  Ukrainian
# 361    362      Nathalie Beltchenko  Ukrainian
# 364    365    Liudmila Khersonskaya    Russian
# 367    368    Liudmila Khersonskaya    Russian
# 555    556            Alex Averbuch  Ukrainian
# 656    657          Dmitry Strotsev    Russian
# 660    661          Dmitry Strotsev    Russian
# 695    696          Dmitry Strotsev    Russian
# 699    700          Dmitry Strotsev    Russian
# 731    732         Kateryna Kalytko  Ukrainian
# 732    733         Kateryna Kalytko  Ukrainian
# 733    734         Kateryna Kalytko  Ukrainian
# 734    735            Serhii Zhadan  Ukrainian
# 735    736            Serhii Zhadan  Ukrainian
# 749    750            Elena Shvarts    Russian
# 750    751  Stanislav Chernilevskyi  Ukrainian
# 756    757   Stanislav Chernilevsky  Ukrainian
# 757    758          Dmitry Strotsev    Russian
# 781    782            Alex Averbuch  Ukrainian
# 802    803         Kateryna Kalytko  Ukrainian
# 816    817         Kateryna Kalytko  Ukrainian
# 862    863         Kateryna Kalytko  Ukrainian
# 863    864         Kateryna Kalytko  Ukrainian
# 868    869              Halyna Kruk  Ukrainian
# 869    870              Halyna Kruk  Ukrainian
# 957    958      Nathalie Beltchenko  Ukrainian
# 958    959      Nathalie Beltchenko  Ukrainian
# 979    980         Kateryna Kalytko  Ukrainian
# 981    982         Kateryna Kalytko  Ukrainian
# 1068  1069              Halyna Kruk  Ukrainian
# 1070  1071              Halyna Kruk  Ukrainian
#
#                         Poem full text (copy and paste)  \
# 39    О.М.\nОн, кто армянское небо назвал близоруким...
# 40    О.М.\nОн, кто армянское небо назвал близоруким...
# 53    ***\nКто не любит свободу, те обычно - плечом ...
# 54    ***\nКто не любит свободу, те обычно - плечом ...
# 145   ранній Тичина - майже сто років тому:\nЗразу ж...
# 146   ранній Тичина - майже сто років тому:\nЗразу ж...
# 173   це місто розлініяне в дощ\nяк тюремна роба\nна...
# 174   це місто розлініяне в дощ\nяк тюремна роба\nна...
# 203   * * * \nПливи, рибо, пливи – \nось твої остров...
# 204   * * * \nПливи, рибо, пливи – \nось твої остров...
# 226   Цю самотність могли би звати Естер або Міріам....
# 227   Цю самотність могли би звати Естер або Міріам....
# 344   в годы войны\nтени перестают быть человеческой...
# 345   в годы войны\nтени перестают быть человеческой...
# 356   Спроба перекладу з російської. Наталя Бєльченк...
# 361   Спроба перекладу з російської. Наталя Бєльченк...
# 364   *** \nНочью ей снилось, что ввели гуманитарный...
# 367   *** \nНочью ей снилось, что ввели гуманитарный...
# 555   Василь Пачовський, 1913\nМайдан без краю. Укра...
# 656   *\nпускай не встретимся уже\nмы встретились уж...
# 660   *\nпускай не встретимся уже\nмы встретились уж...
# 695   * \nговорит Христос\nрусскому богу\nговорит Хр...
# 699   * \nговорит Христос\nрусскому богу\nговорит Хр...
# 731   Артикуляція формує чіткий чи млявий овал\nобли...
# 732   Артикуляція формує чіткий чи млявий овал\nобли...
# 733   Артикуляція формує чіткий чи млявий овал\nобли...
# 734   Час, як шкіра втомленого чоловіка,\nобгорнута ...
# 735   Час, як шкіра втомленого чоловіка,\nобгорнута ...
# 749   УКРАИНСКАЯ ФЛОРА\n1) маки и мальвы в июне\n2) ...
# 750   Вірші мого батька, Станіслава Чернілевського, ...
# 756   Вірші мого батька, Станіслава Чернілевського, ...
# 757   УКРАИНСКАЯ ФЛОРА\n1) маки и мальвы в июне\n2) ...
# 781   Василь Пачовський, 1913\nМайдан без краю. Укра...
# 802   Менше ніж за добу до початку війни\nпосварилис...
# 816   Менше ніж за добу до початку війни\nпосварилис...
# 862   Кожна війна велика. \nОсь і ти доростай до сво...
# 863   Кожна війна велика. \nОсь і ти доростай до сво...
# 868   ***\nправда на твоєму боці, але це твій найтем...
# 869   ***\nправда на твоєму боці, але це твій найтем...
# 957   * *\nІ поки світ блює війною\nІ відступає в по...
# 958   * *\nІ поки світ блює війною\nІ відступає в по...
# 979   Любити серед війни – це,\nпопри все, носити се...
# 981   Любити серед війни – це,\nпопри все, носити се...
# 1068  ми вийдемо з цього інакшими, вийдемо. вий\nсир...
# 1070  ми вийдемо з цього інакшими, вийдемо. вий\nсир...
#
#                                          theme_combined  \
# 39                        [Mandelstam,  poetry,  gulag]
# 40          [Mandelstam,  Armenia,  black sun,  poetry]
# 53                       [freedom,  struggle,  protest]
# 54                        [freedom,  motherland,  fear]
# 145       [Maidan, 'maidan',  'revolution',  'protest']
# 146   [war,  village,  death,  Sich, 'maidan',  'rev...
# 173   [city,  rain, 'maidan',  'seasons',  'revoluti...
# 174   [Kyiv,  Maidan,  Rain,  Music, 'maidan',  'sea...
# 203                        [fish,  life,  love,  death]
# 204   [fish,  island,  words, 'fish',  'bodies of wa...
# 226                                [loneliness,  water]
# 227                                [water,  loneliness]
# 344   [war,  soldiers' mothers, "soldiers' mothers",...
# 345   [war,  soldiers' mothers, "soldiers' mothers",...
# 356   [Ukraine,  mushroom,  environment, 'nature',  ...
# 361   [Ukraine,  environment,  mushrooms, 'plants', ...
# 364   [war,  humanitarian aid, 'war',  'humanitarian...
# 367   [war,  humanitarian aid, 'war',  'humanitarian...
# 555   [twentieth century, 'twentieth century',  'tim...
# 656              [heaven,  relationships,  war,  death]
# 660    [relationships,  alcohol,  war,  heaven,  death]
# 695   [Christ,  Russia, 'christ',  'christianity',  ...
# 699   [Ukraine, 'christ',  'christianity',  'russia'...
# 731                          [body,  language,  memory]
# 732                  [memory,  religion,  death,  fish]
# 733   [war, 'war',  'body',  'night',  'absence',  '...
# 734                                                 NaN
# 735   [memory, 'seasons',  'time',  'winter',  'memo...
# 749   [Ukraine,  flora, 'plants',  'flora',  'ukraine']
# 750   [War,  Russia,  Neo-Messiah,  Legacy,  Governm...
# 756   [War,  Russia,  Government,  Neo-Messiah,  Leg...
# 757           [Ukraine, 'plants',  'flora',  'ukraine']
# 781   [Ukraine, 'twentieth century',  'time',  'war'...
# 802                        [war,  language,  animals, ]
# 816            [war,  time,  language,  body,  animals]
# 862                                 [war,  love,  body]
# 863                               [war,  poetry,  love]
# 868                              [war, 'death',  'war']
# 869                                                 NaN
# 957                                                 NaN
# 958                                                 NaN
# 979             [love,  war,  earrings,  family,  pain]
# 981                  [war, 'sadness',  'war',  'tears']
# 1068  [war,  God,  temples,  underground, 'undergrou...
# 1070  [god,  religion,  war,  love,  geography,  bod...
#
#                                        light_clean_poem
# 39    О.М. Он, кто армянское небо назвал близоруким,...
# 40    О.М. Он, кто армянское небо назвал близоруким,...
# 53    *** Кто не любит свободу, те обычно - плечом к...
# 54    *** Кто не любит свободу, те обычно - плечом к...
# 145   ранній Тичина - майже сто років тому: Зразу ж ...
# 146   ранній Тичина - майже сто років тому: Зразу ж ...
# 173   це місто розлініяне в дощ як тюремна роба на т...
# 174   це місто розлініяне в дощ як тюремна роба на т...
# 203   * * *  Пливи, рибо, пливи –  ось твої острови,...
# 204   * * *  Пливи, рибо, пливи –  ось твої острови,...
# 226   Цю самотність могли би звати Естер або Міріам....
# 227   Цю самотність могли би звати Естер або Міріам....
# 344   в годы войны тени перестают быть человеческой ...
# 345   в годы войны тени перестают быть человеческой ...
# 356   Спроба перекладу з російської. Наталя Бєльченк...
# 361   Спроба перекладу з російської. Наталя Бєльченк...
# 364   ***  Ночью ей снилось, что ввели гуманитарный ...
# 367   ***  Ночью ей снилось, что ввели гуманитарный ...
# 555   Василь Пачовський, 1913 Майдан без краю. Украї...
# 656   * пускай не встретимся уже мы встретились уже ...
# 660   * пускай не встретимся уже мы встретились уже ...
# 695   *  говорит Христос русскому богу говорит Христ...
# 699   *  говорит Христос русскому богу говорит Христ...
# 731   Артикуляція формує чіткий чи млявий овал облич...
# 732   Артикуляція формує чіткий чи млявий овал облич...
# 733   Артикуляція формує чіткий чи млявий овал облич...
# 734   Час, як шкіра втомленого чоловіка, обгорнута д...
# 735   Час, як шкіра втомленого чоловіка, обгорнута д...
# 749   УКРАИНСКАЯ ФЛОРА 1) маки и мальвы в июне 2) по...
# 750   Вірші мого батька, Станіслава Чернілевського, ...
# 756   Вірші мого батька, Станіслава Чернілевського, ...
# 757   УКРАИНСКАЯ ФЛОРА 1) маки и мальвы в июне 2) по...
# 781   Василь Пачовський, 1913 Майдан без краю. Украї...
# 802   Менше ніж за добу до початку війни посварилися...
# 816   Менше ніж за добу до початку війни посварилися...
# 862   Кожна війна велика.  Ось і ти доростай до своє...
# 863   Кожна війна велика.  Ось і ти доростай до своє...
# 868   *** правда на твоєму боці, але це твій найтемн...
# 869   *** правда на твоєму боці, але це твій найтемн...
# 957   * * І поки світ блює війною І відступає в поро...
# 958   * * І поки світ блює війною І відступає в поро...
# 979   Любити серед війни – це, попри все, носити сер...
# 981   Любити серед війни – це, попри все, носити сер...
# 1068  ми вийдемо з цього інакшими, вийдемо. вий сире...
# 1070  ми вийдемо з цього інакшими, вийдемо. вий сире...

# %% [markdown]
# Notice that some of the duplicated entries have different themes entries.

# %%
grouped_dup = russian_ukrainian_dup.groupby('Poem full text (copy and paste)').agg({'theme_combined':'sum'}).reset_index()
russian_ukrainian.drop_duplicates(subset='Poem full text (copy and paste)', inplace=True)
russian_ukrainian = russian_ukrainian.merge(grouped_dup, left_on = 'Poem full text (copy and paste)', right_on = 'Poem full text (copy and paste)', how='left')

# %%
russian_ukrainian['theme_combined_y'] = russian_ukrainian['theme_combined_y'].fillna(russian_ukrainian['theme_combined_x']) 
russian_ukrainian = russian_ukrainian.drop(columns='theme_combined_x')
russian_ukrainian.rename({'Author of poem':'poem_author', 'Language':'language', 'Poem full text (copy and paste)':'original_poem', 'theme_combined_y':'theme_combined'})
# Out:
#         ID      Author of poem   Language  \
# 0        1         Halyna Kruk  Ukrainian
# 1        2     Ostap Slyvynsky  Ukrainian
# 2        3     Osip Mandelstam    Russian
# 3        4    Boris Khersonsky    Russian
# 4        5  Oleksandr Irvanets  Ukrainian
# ...    ...                 ...        ...
# 1082  1201       Oleh Kotsarev  Ukrainian
# 1083  1202     Olena Huseinova  Ukrainian
# 1084  1203     Pavlo Korobchuk  Ukrainian
# 1085  1204    Victoria Amelina  Ukrainian
# 1086  1205            Iya Kiva  Ukrainian
#
#                         Poem full text (copy and paste)  \
# 0     ***\ncказати собі чесно, якомога чесніше,\nтак...
# 1     ХАЙКУ З МАЙДАНУ\nДим у рукавах.\nНіби йдеш з ц...
# 2     (О.М.)\nНе мучнистой бабочкою белой\nВ землю я...
# 3     ***\n"Союз нерушимый" сыграют и хором споют.\n...
# 4     ***\nЦей рік, який почався з середи - \nКуди в...
# ...                                                 ...
# 1082  СВІТ САМШИТ\n\nСвіте!\nХиткий самшите!\nГладжу...
# 1083  Дорога Halyna Kruk :\nале з кожною розповіддю ...
# 1084  - у мене закінчуються сили, я не в ресурсі\n- ...
# 1085  *\nдивне пекуче літо\nповне людей із моря\nїхн...
# 1086  тримати у роті голку мовчання\nзшивати слова б...
#
#                                        light_clean_poem  \
# 0     *** cказати собі чесно, якомога чесніше, так н...
# 1     ХАЙКУ З МАЙДАНУ Дим у рукавах. Ніби йдеш з цим...
# 2      Не мучнистой бабочкою белой В землю я заемный...
# 3     *** "Союз нерушимый" сыграют и хором споют. В ...
# 4     *** Цей рік, який почався з середи -  Куди він...
# ...                                                 ...
# 1082  СВІТ САМШИТ  Світе! Хиткий самшите! Гладжу теб...
# 1083  Дорога Halyna Kruk : але з кожною розповіддю м...
# 1084  - у мене закінчуються сили, я не в ресурсі - а...
# 1085  * дивне пекуче літо повне людей із моря їхні с...
# 1086  тримати у роті голку мовчання зшивати слова бі...
#
#                                        theme_combined_y
# 0     [Maidan, 'maidan',  'revolution',  'protest', ...
# 1     [Haiku,  Maidan, 'maidan',  'poetic form',  'h...
# 2           [war, 'time',  'war',  'twentieth century']
# 3             [Soviet Union,  food,  morphine,  anthem]
# 4           [New year, 'seasons',  'time',  'new year']
# ...                                                 ...
# 1082                                     [nature,  art]
# 1083  [Halyna Kruk,  poetry,  religion,  Ukraine,  w...
# 1084  [war,  Ukraine,  language,  ammunition,  repor...
# 1085  [Mariupol,  war,  summer,  archive,  memory,  ...
# 1086                 [needle,  speech,  silence,  pain]
#
# [1087 rows x 6 columns]

# %%
russian_ukrainian = russian_ukrainian.rename(columns={'Author of poem':'poem_author', 'Language':'language', 'Poem full text (copy and paste)':'original_poem', 'theme_combined_y':'theme'})

# %%
# Notice that there are a lot of duplicated themes in the theme list, e.g. Maidan, 'maidan'
# Here we define a function to clean the lists in the "theme" column
def clean_list(l):
    try:
        for i in range(len(l)):
            l[i] = l[i].lower().replace("'",'').strip()
        return set(l)
    except TypeError:
        return

# %%
russian_ukrainian
# Out:
#         ID         poem_author   language  \
# 0        1         Halyna Kruk  Ukrainian
# 1        2     Ostap Slyvynsky  Ukrainian
# 2        3     Osip Mandelstam    Russian
# 3        4    Boris Khersonsky    Russian
# 4        5  Oleksandr Irvanets  Ukrainian
# ...    ...                 ...        ...
# 1082  1201       Oleh Kotsarev  Ukrainian
# 1083  1202     Olena Huseinova  Ukrainian
# 1084  1203     Pavlo Korobchuk  Ukrainian
# 1085  1204    Victoria Amelina  Ukrainian
# 1086  1205            Iya Kiva  Ukrainian
#
#                                           original_poem  \
# 0     ***\ncказати собі чесно, якомога чесніше,\nтак...
# 1     ХАЙКУ З МАЙДАНУ\nДим у рукавах.\nНіби йдеш з ц...
# 2     (О.М.)\nНе мучнистой бабочкою белой\nВ землю я...
# 3     ***\n"Союз нерушимый" сыграют и хором споют.\n...
# 4     ***\nЦей рік, який почався з середи - \nКуди в...
# ...                                                 ...
# 1082  СВІТ САМШИТ\n\nСвіте!\nХиткий самшите!\nГладжу...
# 1083  Дорога Halyna Kruk :\nале з кожною розповіддю ...
# 1084  - у мене закінчуються сили, я не в ресурсі\n- ...
# 1085  *\nдивне пекуче літо\nповне людей із моря\nїхн...
# 1086  тримати у роті голку мовчання\nзшивати слова б...
#
#                                        light_clean_poem  \
# 0     *** cказати собі чесно, якомога чесніше, так н...
# 1     ХАЙКУ З МАЙДАНУ Дим у рукавах. Ніби йдеш з цим...
# 2      Не мучнистой бабочкою белой В землю я заемный...
# 3     *** "Союз нерушимый" сыграют и хором споют. В ...
# 4     *** Цей рік, який почався з середи -  Куди він...
# ...                                                 ...
# 1082  СВІТ САМШИТ  Світе! Хиткий самшите! Гладжу теб...
# 1083  Дорога Halyna Kruk : але з кожною розповіддю м...
# 1084  - у мене закінчуються сили, я не в ресурсі - а...
# 1085  * дивне пекуче літо повне людей із моря їхні с...
# 1086  тримати у роті голку мовчання зшивати слова бі...
#
#                                                   theme
# 0     [Maidan, 'maidan',  'revolution',  'protest', ...
# 1     [Haiku,  Maidan, 'maidan',  'poetic form',  'h...
# 2           [war, 'time',  'war',  'twentieth century']
# 3             [Soviet Union,  food,  morphine,  anthem]
# 4           [New year, 'seasons',  'time',  'new year']
# ...                                                 ...
# 1082                                     [nature,  art]
# 1083  [Halyna Kruk,  poetry,  religion,  Ukraine,  w...
# 1084  [war,  Ukraine,  language,  ammunition,  repor...
# 1085  [Mariupol,  war,  summer,  archive,  memory,  ...
# 1086                 [needle,  speech,  silence,  pain]
#
# [1087 rows x 6 columns]

# %%
print("Number of null entry in theme column: ", russian_ukrainian['theme'].apply(clean_list).isna().sum())
russian_ukrainian['theme'] = russian_ukrainian['theme'].apply(clean_list)
russian_ukrainian.dropna(subset='theme', inplace=True)
# Out:
# Number of null entry in theme column:  77

# %%
russian_ukrainian.head()
# Out:
#    ID         poem_author   language  \
# 0   1         Halyna Kruk  Ukrainian
# 1   2     Ostap Slyvynsky  Ukrainian
# 2   3     Osip Mandelstam    Russian
# 3   4    Boris Khersonsky    Russian
# 4   5  Oleksandr Irvanets  Ukrainian
#
#                                        original_poem  \
# 0  ***\ncказати собі чесно, якомога чесніше,\nтак...
# 1  ХАЙКУ З МАЙДАНУ\nДим у рукавах.\nНіби йдеш з ц...
# 2  (О.М.)\nНе мучнистой бабочкою белой\nВ землю я...
# 3  ***\n"Союз нерушимый" сыграют и хором споют.\n...
# 4  ***\nЦей рік, який почався з середи - \nКуди в...
#
#                                     light_clean_poem  \
# 0  *** cказати собі чесно, якомога чесніше, так н...
# 1  ХАЙКУ З МАЙДАНУ Дим у рукавах. Ніби йдеш з цим...
# 2   Не мучнистой бабочкою белой В землю я заемный...
# 3  *** "Союз нерушимый" сыграют и хором споют. В ...
# 4  *** Цей рік, який почався з середи -  Куди він...
#
#                                                theme
# 0             {ukraine, maidan, protest, revolution}
# 1  {poetic form, haiku, protest, maidan, revolution}
# 2                     {time, war, twentieth century}
# 3             {morphine, food, soviet union, anthem}
# 4                          {time, seasons, new year}

# %% [markdown]
# ### Let's look at the top 10 most frequently occured themes and the least frequently occured themes

# %%
russian_ukrainian['theme'].explode().value_counts().head(10)
# Out:
# war          322
# religion     125
# ukraine      124
# death        103
# time          96
# russia        85
# geography     84
# seasons       72
# family        62
# language      55
# Name: theme, dtype: int64

# %%
russian_ukrainian['theme'].explode().value_counts()[-10:]
# Out:
# konstadt                 1
# mail                     1
# learning                 1
# expansionism             1
# ithaca                   1
# tatar                    1
# change to “kronstadt”    1
# lots wife                1
# textbook                 1
# needle                   1
# Name: theme, dtype: int64

# %% [markdown]
# #### We can see that the lesser frequently occured themes are usually very specific, e.g. winter-summer vs seasons, bad habits vs habits

# %%
unique_theme = russian_ukrainian['theme'].explode().value_counts().index.tolist()

# %%
unique_theme[:20] # We will generate a list of high-level themes based on the top 20 themes
# Out:
# ['war',
#  'religion',
#  'ukraine',
#  'death',
#  'time',
#  'russia',
#  'geography',
#  'seasons',
#  'family',
#  'language',
#  'animals',
#  'memory',
#  'revolution',
#  'maidan',
#  'nature',
#  'protest',
#  'christianity',
#  'poetry',
#  'love',
#  'poetic form']

# %% [markdown]
# ## Generate high-level themes

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\winfr\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.stem import WordNetLemmatizer

# %%
big_theme = []
lemmatizer = WordNetLemmatizer()
for i in unique_theme[:50]:
    big_theme.append(lemmatizer.lemmatize(i))

# %%
big_theme[:20]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 big_theme[:20]
#
# NameError: name 'big_theme' is not defined

# %%
## Generating our own big theme
big_theme = ['war', 'religion', 'nation', 'death', 'time',
             'protest', 'geography', 'season', 'family', 'language',
             'art', 'memory', 'animal', 'nature', 'love', 'emotion',   
             'relationship', 'politics', 'life', 'food', 'plant', 'fruit', 'ekphrasis'] #

theme_id = {}
for i, t in enumerate(big_theme):
    theme_id[t] = i
theme_id
# Out:
# {'war': 0,
#  'religion': 1,
#  'nation': 2,
#  'death': 3,
#  'time': 4,
#  'protest': 5,
#  'geography': 6,
#  'season': 7,
#  'family': 8,
#  'language': 9,
#  'art': 10,
#  'memory': 11,
#  'animal': 12,
#  'nature': 13,
#  'love': 14,
#  'emotion': 15,
#  'relationship': 16,
#  'politics': 17,
#  'life': 18,
#  'food': 19,
#  'plant': 20}

# %%
' ' in 'the earth'
# Out:
# True

# %%
'the-earth'.split('-')
# Out:
# ['the', 'earth']

# %%
lemmatizer = WordNetLemmatizer()

def get_big_theme(themes, big_themes):
    lemmatizer = WordNetLemmatizer()
    out = []
    for i in themes:
        if ' ' in i:
            i = i.split()
            for j in i:
                if lemmatizer.lemmatize(j) in big_themes:
                    out.append(lemmatizer.lemmatize(j))
        else:
            if lemmatizer.lemmatize(i) in big_themes:
                out.append(lemmatizer.lemmatize(i))
    if len(out) == 0:
        return themes
    return out

# %%
big_theme_ser = russian_ukrainian['theme'].apply(lambda x: get_big_theme(x, theme_id))
big_theme_ser
# Out:
# 0                             [protest]
# 1                             [protest]
# 2                           [time, war]
# 3                                [food]
# 4                        [time, season]
#                      ...
# 1082                      [art, nature]
# 1083                    [war, religion]
# 1084                    [language, war]
# 1085                      [memory, war]
# 1086    {pain, silence, speech, needle}
# Name: theme, Length: 1010, dtype: object

# %%
np.mean(big_theme_ser.apply(lambda x: isinstance(x, set)))*100
# Out:
# 21.18811881188119

# %% [markdown]
# #### Around 21% of the poems do not have a big theme associated to it - possibly due to different naming conventions, i.e. winter-summer to season . We will use similarity scoring to get the most similar big theme

# %%
def find_most_similar_theme(themes, big_themes, model="en_core_web_sm"):
    nlp = spacy.load(model)
    threshold = 0.7
    out = []
    for i in themes:
        max_sim = 0
        max_theme = ''
        #if ('-' in i): i = i.split('-')
        #else: i = i.split()
        #for j in i:
        w1 = nlp(i)
        for k in big_themes:
            if w1.similarity(nlp(k)) > max_sim:
                max_sim = w1.similarity(nlp(k))
                max_theme = k
                term = w1
        if max_sim > threshold:
            out.append((term, max_sim, max_theme))
    return out

# %%
# test
find_most_similar_theme({'morphine', 'food', 'soviet union', 'anthem'},theme_id)

# Would expect the following big theme(s) to be returned: nation, food
# Out:
# C:\Users\winfr\AppData\Local\Temp\ipykernel_34532\2154880614.py:13: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   if w1.similarity(nlp(k)) > max_sim:
# C:\Users\winfr\AppData\Local\Temp\ipykernel_34532\2154880614.py:14: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   max_sim = w1.similarity(nlp(k))
# [(morphine, 0.7699028396023014, 'relationship'), (food, 1.0, 'food')]

# %% [markdown]
# #### Using the small model, en_core_web_sm, does not give accurate scores. This makes sense since the similarity score is computed "based on the tagger, parser and NER" as stated in the warning message above. We will try using larger models

# %%
# test using larger model
find_most_similar_theme({'morphine', 'food', 'soviet union', 'anthem'},theme_id, model="en_core_web_lg")
# Out:
# [(food, 1.0, 'food')]

# %% [markdown]
# #### Hmm.. the large model might be too strict for our use

# %% [markdown]
# ### More about SpaCy Similarity

# %%
import spacy

# %%
nlp = spacy.load("en_core_web_lg")

# %%
lemmatizer.lemmatize('poems')
# Out:
# 'poem'

# %%
w1 = nlp('pain')
w2 = nlp('emotion')
w1.similarity(w2)
# Out:
# 0.5123366181419517

# %%
w1 = nlp('christianity')
w2 = nlp('religion')
w1.similarity(w2)
# Out:
# 0.8092649878089295

# %%
w1 = nlp('childhood')
w2 = nlp('memory')
w1.similarity(w2)
# Out:
# 0.46912996356345144

# %%
w1 = nlp('summer')
w2 = nlp('season')
w1.similarity(w2)
# Out:
# 0.5815415136584059

# %%
w1 = nlp('ukraine')
w2 = nlp('country')
w1.similarity(w2)
# Out:
# 0.34308747469152184

# %%
w1 = nlp('christmas')
w2 = nlp('time')
w1.similarity(w2)
# Out:
# 0.20934955324979118

# %% [markdown]
# ### WordNet Similarity

# %%
from nltk.corpus import wordnet

# %%
test = wordnet.synsets("soviet union")

# %%
for i in wordnet.synsets('nation', pos='n'):
    for j in test:
        print(i, j, i.wup_similarity(j))

# %% [markdown]
# ### Best course of action is to manually annotate the dataset to ensure the correctness in further usage
# #### We will only re-annotate the 24% where none of the entries in the exisiting "themes" column is in the "big_theme" we have identified

# %%
yes_big_theme = russian_ukrainian[big_theme_ser.apply(lambda x: not(isinstance(x, set)))]
no_big_theme = russian_ukrainian[big_theme_ser.apply(lambda x: isinstance(x, set))]
no_big_theme
# Out:
#         ID            poem_author   language  \
# 7        8          Oleh Kotsarev  Ukrainian
# 13      14     Tadeusz Chabrowski  Ukrainian
# 15      16     Oleksandr Irvanets  Ukrainian
# 18      19       Boris Khersonsky    Russian
# 21      22       Boris Khersonsky    Russian
# ...    ...                    ...        ...
# 1055  1169       Boris Khersonsky    Russian
# 1056  1172            Halyna Kruk  Ukrainian
# 1058  1174            Halyna Kruk  Ukrainian
# 1079  1197  Ivanna Skyba-Yakubova  Ukrainian
# 1086  1205               Iya Kiva  Ukrainian
#
#                                           original_poem  \
# 7     ПОВЕРНЕННЯ\n\nМісто L – так близько до міста N...
# 13    Тадеуш Хабровський\nВуді Аллен каже\nбо в злі ...
# 15    А СВЯТО ТРИВАЄ...\n***\nНоворічна пісня рине \...
# 18    ***\n\nПробудитесь, цари! Поднимайтесь скорей!...
# 21    ***\nВолхвы иным путем возвратятся в страну св...
# ...                                                 ...
# 1055  ***\nИх рисовали втроем, спящих в одной постел...
# 1056  ***\nщо там сьогодні в театрі тіней - \nвухаті...
# 1058  точка біфуркації \n\nу Львові часів війни, - п...
# 1079  ***\nВисповідай мене, Апостоле.\nТут, на темно...
# 1086  тримати у роті голку мовчання\nзшивати слова б...
#
#                                        light_clean_poem  \
# 7     ПОВЕРНЕННЯ  Місто L – так близько до міста N, ...
# 13    Тадеуш Хабровський Вуді Аллен каже бо в злі ча...
# 15    А СВЯТО ТРИВАЄ... *** Новорічна пісня рине  Ві...
# 18    ***  Пробудитесь, цари! Поднимайтесь скорей! З...
# 21    *** Волхвы иным путем возвратятся в страну сво...
# ...                                                 ...
# 1055  *** Их рисовали втроем, спящих в одной постели...
# 1056  *** що там сьогодні в театрі тіней -  вухаті з...
# 1058  точка біфуркації   у Львові часів війни, - пот...
# 1079  *** Висповідай мене, Апостоле. Тут, на темному...
# 1086  тримати у роті голку мовчання зшивати слова бі...
#
#                                                   theme
# 7                                      {, city, return}
# 13                          {theater, usa, woody allen}
# 15          {theater, sasha grey, holiday, celebration}
# 18    {imperialism, soviet union, christmas, revolut...
# 21                       {ekphrasis, christmas, christ}
# ...                                                 ...
# 1055               {star, angel, christmas, ekphrastic}
# 1056                {theater, light, shadow, tiredness}
# 1058                {history, ukraine, poetry, lazarus}
# 1079                {christianity, apostle, confession}
# 1086                    {pain, silence, speech, needle}
#
# [214 rows x 6 columns]

# %%
yes_big_theme = yes_big_theme.assign(big_theme=big_theme_ser[big_theme_ser.apply(lambda x: not(isinstance(x, set)))])
yes_big_theme
# Out:
#         ID         poem_author   language  \
# 0        1         Halyna Kruk  Ukrainian
# 1        2     Ostap Slyvynsky  Ukrainian
# 2        3     Osip Mandelstam    Russian
# 3        4    Boris Khersonsky    Russian
# 4        5  Oleksandr Irvanets  Ukrainian
# ...    ...                 ...        ...
# 1081  1199    Kateryna Devdera  Ukrainian
# 1082  1201       Oleh Kotsarev  Ukrainian
# 1083  1202     Olena Huseinova  Ukrainian
# 1084  1203     Pavlo Korobchuk  Ukrainian
# 1085  1204    Victoria Amelina  Ukrainian
#
#                                           original_poem  \
# 0     ***\ncказати собі чесно, якомога чесніше,\nтак...
# 1     ХАЙКУ З МАЙДАНУ\nДим у рукавах.\nНіби йдеш з ц...
# 2     (О.М.)\nНе мучнистой бабочкою белой\nВ землю я...
# 3     ***\n"Союз нерушимый" сыграют и хором споют.\n...
# 4     ***\nЦей рік, який почався з середи - \nКуди в...
# ...                                                 ...
# 1081  Хай це стане молитвою, хай стане твоєю силою,\...
# 1082  СВІТ САМШИТ\n\nСвіте!\nХиткий самшите!\nГладжу...
# 1083  Дорога Halyna Kruk :\nале з кожною розповіддю ...
# 1084  - у мене закінчуються сили, я не в ресурсі\n- ...
# 1085  *\nдивне пекуче літо\nповне людей із моря\nїхн...
#
#                                        light_clean_poem  \
# 0     *** cказати собі чесно, якомога чесніше, так н...
# 1     ХАЙКУ З МАЙДАНУ Дим у рукавах. Ніби йдеш з цим...
# 2      Не мучнистой бабочкою белой В землю я заемный...
# 3     *** "Союз нерушимый" сыграют и хором споют. В ...
# 4     *** Цей рік, який почався з середи -  Куди він...
# ...                                                 ...
# 1081  Хай це стане молитвою, хай стане твоєю силою, ...
# 1082  СВІТ САМШИТ  Світе! Хиткий самшите! Гладжу теб...
# 1083  Дорога Halyna Kruk : але з кожною розповіддю м...
# 1084  - у мене закінчуються сили, я не в ресурсі - а...
# 1085  * дивне пекуче літо повне людей із моря їхні с...
#
#                                                   theme        big_theme
# 0                {ukraine, maidan, protest, revolution}        [protest]
# 1     {poetic form, haiku, protest, maidan, revolution}        [protest]
# 2                        {time, war, twentieth century}      [time, war]
# 3                {morphine, food, soviet union, anthem}           [food]
# 4                             {time, seasons, new year}   [time, season]
# ...                                                 ...              ...
# 1081             {death, god, christmas, jesus, prayer}          [death]
# 1082                                      {art, nature}    [art, nature]
# 1083  {ukraine, poetry, war, literature, religion, h...  [war, religion]
# 1084    {ammunition, ukraine, reportage, language, war}  [language, war]
# 1085  {memory, summer, archive, souvenirs, war, mari...    [memory, war]
#
# [796 rows x 7 columns]

# %%
no_big_theme.to_csv('no_big_theme.csv')

# %% [markdown]
# # KeyBERT

# %%
from keybert import KeyBERT

# %%
kb_model = KeyBERT()

# %% [markdown]
# ### Default KeyBERT uses "all-MiniLM-L6-v2"

# %%
kb_model.extract_keywords(russian_ukrainian['light_clean_poem'].iloc[100])
# Out:
# [('сміятися', 0.3663),
#  ('ніби', 0.3509),
#  ('робила', 0.3446),
#  ('порцеляни', 0.3403),
#  ('вбивця', 0.3375)]

# %%
russian_ukrainian.iloc[100]
# Out:
# ID                                                                108
# poem_author                                             Oleh Kotsarev
# language                                                    Ukrainian
# original_poem       ТАЇНА\n\nВинятково смачна таємниця –\nчас, у я...
# light_clean_poem    ТАЇНА  Винятково смачна таємниця – час, у яком...
# theme                                                 {secrets, time}
# Name: 105, dtype: object

# %%
translate('ніби'), translate('робила'), translate('порцеляни'), translate('вбивця'), translate('сміятися')
# Out:
# ('as if', 'did it', 'porcelain', 'The killer', 'laugh')

# %% [markdown]
# ### Use multilingual BERT

# %%
from transformers.pipelines import pipeline

multilingual_model = pipeline("feature-extraction", model="bert-base-multilingual-uncased")
# Out:
# Some weights of the model checkpoint at bert-base-multilingual-uncased were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
kb_model2 = KeyBERT(model=multilingual_model)

# %%
key2 = kb_model2.extract_keywords(russian_ukrainian['light_clean_poem'].iloc[100])
key2

# %%
kw = [i[0] for i in key2]
kw
# Out:
# ['таємниць', 'різдвяна', 'починаємо', 'перевернуте', 'оголошення']

# %%
for i in kw:
    print(translate(i))
# Out:
# secrets
# Christmas
# We start
# Turn it over
# advertisement

# %%
text = russian_ukrainian['light_clean_poem'].iloc[100]
text
# Out:
# 'ТАЇНА  Винятково смачна таємниця – час, у якому всі переконані, що таємниць більше нема.  Я зараз дістану одне таке суспільство з шухлядки, яка ледь тримається знизу старого стола –  Обережно. Не розбити б. Ну, починаємо!  Пальцем об долоню тієї ж руки вибиваю те, що здається мені фламенко, люди в шухляді так гарно танцюють, що хочеться з’їсти їх розпалений мозок!  А зараз будуть мої улюблені персонажі цієї шухляди: перевернуте обличчя з двома яйцями ротів із порцеляни та одним зубатим оком, різдвяна ялинка-вбивця, що засліплює кордиор нічної лікарні, чоловік із діркою в шиї, крізь яку з шипінням виходить повітря, скліщені мурахи й ті, хто тремтить уві сні!  Всім іншим героям лишається тільки сміятися, вигадуючи їм дотепні прізвиська.  Я просто катаюсь підлогою з радості – й, мабуть, ось зараз почну їсти мізки в момент оголошення чергового прогнозу.  Та щось мене зупиняє, ховаю шухляду назад, танці тривають у темряві, як і решта ритуалів, замаскованих під торгівлю, ніби магма під оболонку Київського торта, не такого, як продається, а такого, як моя бабуся робила – темного, з гострим адреналіновим поглядом…  А танець і далі триває у темряві, вже по пояс у кремі.'

# %%
import time

# %%
def extract_keyword(model, text):
    return model.extract_keywords(text)

# %%
start = time.time()
kw = extract_keyword(kb_model2, text)
end = time.time()
end-start
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 2
#       1 start = time.time()
# ----> 2 kw = extract_keyword(kb_model2, text)
#       3 end = time.time()
#       4 end-start
#
# NameError: name 'text' is not defined

# %% [markdown]
# #### Takes around 10 seconds to extract keywords from a roughly 182 words poem

# %%
kw_series = russian_ukrainian.head(10)['light_clean_poem'].apply(lambda x: extract_keyword(kb_model2, x))

# %%
kw_series
# Out:
# 0    [(покладаючись, 0.3382), (патріотичних, 0.2455...
# 1    [(пообіцяти, 0.4741), (пустимо, 0.3054), (вист...
# 2    [(восклицанья, 0.381), (мыслящее, 0.3004), (мо...
# 3    [(проснусь, 0.3366), (нерушимый, 0.331), (скры...
# 4    [(наступний, 0.4395), (четверга, 0.2653), (коч...
# 5    [(сніданок, 0.3952), (віршик, 0.3494), (дєдушк...
# 6    [(вдихаєш, 0.4907), (найглухішої, 0.4699), (на...
# 7    [(насправді, 0.3842), (ренесансовий, 0.3441), ...
# 8    [(європоньці, 0.3633), (краще, 0.262), (сидіти...
# 9    [(встигнемо, 0.419), (тиждень, 0.3152), (втоми...
# Name: light_clean_poem, dtype: object

# %% [markdown]
# #### Around 1-2 minutes to extract keywords of the first 10 rows. Now let's try extracting keywords for the rest of our poems

# %%
start = time.time()
kw_series = russian_ukrainian['light_clean_poem'].apply(lambda x: extract_keyword(kb_model2, x))
end = time.time()
end-start
# Out:
# 8730.577914953232

# %%
russian_ukrainian = russian_ukrainian.assign(keywords=kw_series)

# %%
russian_ukrainian.to_csv('keyword_poems.csv')

# %% [markdown]
# #### 8730.58 seconds to extract keywords of the entire dataset

# %% [markdown]
# # Archived

# %%
# get only Ukrainian
ukrainian = russian_ukrainian.loc[russian_ukrainian['Language'].str.split(", ").apply(lambda x: (len(x) == 1) and ('Ukrainian' in x) and ('Russian' not in x)), ]
ukrainian.shape[0]
# Out:
# 718

# %%
# get only Russian
russian = russian_ukrainian.loc[russian_ukrainian['Language'].str.split(", ").apply(lambda x: (len(x) == 1) and ('Ukrainian' not in x) and ('Russian' in x)), ]
russian.shape[0]
# Out:
# 357
